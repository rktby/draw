# %%
import numpy as np
from queue import PriorityQueue as queue
from collections import defaultdict
from faker import Faker
from tabulate import tabulate

fake = Faker()

# %% [markdown]
# ## Draw Simulation Methods

# %%
def init_players(num_players):
    """
    Create a collection of players in the form [player_id, player_name, player_ranking]
    Arguments:
        num_players: Number of players to add to the draw
    Returns:
        players: Array of player details
            (n x 3) list containing [player_id, player_name, player_ranking]
    """
    players = []
    id_to_name, id_to_rank = {}, {}
    for n in range(num_players):
        p_id, p_name, p_rank = np.random.randint(1000000, 9999999), fake.name(), np.random.randint(1600, 2000)
        players.append([p_id, p_name, p_rank])
        id_to_name[p_id] = p_name
        id_to_rank[p_id] = p_rank
    return players, id_to_name, id_to_rank

# %%
def init_pairings(players):
    """
    Randomly create results for the first round
    Arguments:
        players: (n x 3) numpy array containing [player_id, player_name, player_ranking]
    Returns:
        results: Randomly generated results table
            (n x 3) list containing [player_a_id, player_b_id, match_winner_id]
    """
    results = []
    for n in range(0, len(players), 2):
        a, b = players[n][0], players[n+1][0]
        result = [a, b, np.random.choice([a, b, None], 1, p=(0.45, 0.45, 0.1))[0]]
        results.append(result)
    return results

# %%
def run_round(pairings, p_draw=0):
    """
    Randomly create results for a round
    Arguments:
        pairings: List of pairings for the round to be simulated
            (n x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    Returns:
        results: Randomly generated results table
            (n x 3) list containing [player_a_id, player_b_id, match_winner_id]
    """
    results = []
    p_win = (1 - p_draw) / 2
    for pairing in pairings:
        a, b = pairing[0][1], pairing[1][1]
        result = [a, b, np.random.choice([a, b, None], 1, p=(p_win, p_win, p_draw))[0]]
        results.append(result)
        
    return results

# %% [markdown]
# ## Draw Calculation Methods

# %%
def create_draw(players, pairs):
    """
    Create draw for the round
    Agruments:
        players: Array of player details
            (n x 3) list containing [player_id, player_name, player_ranking]
        pairs: List of pairings for all rounds to date
            (m x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    Returns:
        standings: List of standings for all players still in the tournament
            (n x 2) list containing [player_id, player_wins]
        splits: List of index points where each points bracket finishes
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
        alloc: The matrix form pairing allocations
            (n x n) matrix of integers
        pairings: The list form of pairing allocations
            (n / 2 x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    """
    n_players = len(players)

    rankings = defaultdict(int)
    if len(pairs) > 0:
        for pair in pairs:
            rankings[pair[0]] += (pair[0] == pair[2])
            rankings[pair[1]] += (pair[1] == pair[2])
    else:
        for player in players:
            rankings[player[0]] = 0

    standings = np.transpose([list(rankings.keys()), list(rankings.values())])
    standings = np.array(sorted(standings, key=lambda x: x[1], reverse=True))
    
    scores, splits  = get_scores(standings, pairs)
    alloc, pairings = get_allocations(standings, scores)
    
    return standings, splits, scores, alloc, pairings

# %%
def get_scores(standings, pairs):
    """
    Assign scores to each possible pairing
    A higher score means that the pairing is more strongly preferred
    Arguments:
        standings: List of standings for all players still in the tournament
            (n x 2) list containing [player_id, player_wins]
        pairs: List of pairings for all rounds to date
            (m x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    Returns:
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
        splits: List of index points where each points bracket finishes
    """
    n_players = len(standings)
    ix = {player_id: pos for pos, player_id in enumerate(standings[:,0])}
    splits = [n for n in range(n_players) if standings[n,1] != standings[n-1,1]]
    
    # Calculate scores for pairings
    scores = np.full((n_players, n_players), -100)
    
    split_1, split_2 = 0, 0
    for split in splits + [n_players]:
        # Assign points for players in same bracket
        scores[split_1:split, split_1:split] = 4
        # Assign points for pull-up bracket
        if split_1 %2 == 1:
            scores[split_2:split_1, split_1:split] = 1
            scores[split_1:split, split_2:split_1] = 1
        split_1, split_2 = split, split_1
    
    # Reset self vs self to -inf
    np.fill_diagonal(scores, -100)

    # Subtract points for prior matchup
    for pair in pairs:
        a, b = ix[pair[0]], ix[pair[1]]
        scores[a,b] -= 1
        scores[b,a] -= 1
        
    return scores, splits

# %%
def get_allocations(standings, scores):
    """
    Allocate player pairings
    Arguments:
        standings: List of standings for all players still in the tournament
            (n x 2) list containing [player_id, player_wins]
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
    Returns:
        alloc: The matrix form pairing allocations
            (n x n) matrix of integers
        pairs: The list form of pairing allocations
            (n / 2 x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    """
    n_players = scores.shape[0]
    ix = {pos: player_id for pos, player_id in enumerate(standings[:,0])}
    alloc = np.zeros((n_players, n_players), dtype=int)

    for _ in range(int(n_players / 2)):
        mask = (1 - alloc.sum(axis=1))
        #p = 1 - alloc.sum(axis=1)
        #a = np.random.choice(range(n_players),p=p/p.sum())
        # Choose Player A
        p = scores.max() - scores.sum(axis=1)
        p = p * mask
        a = p.argmax()
        # Choose Player B
        p = np.exp(scores[a])
        p = np.maximum(p * mask, 0)
        b = np.random.choice(range(n_players),p=p/p.sum())
        
        alloc[a, b] = 1
        alloc[b, a] = 1
    
    alloc_ = alloc * np.tri(*alloc.shape)

    pairs = []
    for n in range(n_players):
        if alloc_[n].max() == 1:
            a, b = n, alloc_[n].argmax()
            pairs.append([(a, ix[a]), (b, ix[b])])

    return alloc, pairs

# %% [markdown]
# ## Draw Printing Methods

# %%
def print_standings(standings, id_to_name):
    """
    Print standings for the round in table form
    """
    table = []
    for rank, player in enumerate(standings):
        table.append([int(player[0]), id_to_name[player[0]], player[1], rank+1])
    print('\n', tabulate(table, headers=['ID', 'Name', 'Wins', 'Rank']), '\n')
    

def print_pairings(pairs, id_to_name):
    """
    Print pairings for the round in table form
    """
    table = []
    for table_num, pair in enumerate(pairs):
        b, a = pair[0], pair[1]
        row = [table_num+1, id_to_name[a[1]], int(a[1]), int(a[0])+1, id_to_name[b[1]], int(b[1]), int(b[0])+1]
        table.append(row)
    headers = ['Table #', 'Player 1 - Name', 'ID', 'Rank', 'Player 2 - Name', 'ID', 'Rank']
    print('\n', tabulate(table, headers=headers), '\n')

# %% [markdown]
# ## Run a sample Tournament
# Create a list of players then run through a multi-round tournament and print the results
# Each round prints:
# - Goodness of fit score: Score for the pairings allocated in the round. The maximum possible score is 4. If a number < 0 comes out, something has probably gone wrong
# - Standings: A table of standings of the players (based only on # of wins, no accounting for draws, op wins etc)
# - Pairings: A table of pairings for the following round (including player name and standing so you can check if players are being paired with others nearby)
#
# To show all the standings and pairings at once, make sure to select the cell, click on the "Cell" menu, select -> "Current Outputs" and then select "Toggle Scrolling"
#
# The entire history of "standings", "splits", "scores", "allocations", and "pairs" is recorded in the lists *standings_h, splits_h, scores_h, alloc_h, pairs_h*
#
# Note: Early stage demo only. This does not support:
# - Odd numbers of players and byes
# - Allocating pods
# - Iterative sampling methods to improve draw quality
# - etc

# %%
NUMBER_OF_PLAYERS = 24
NUMBER_OF_ROUNDS  = 6
PROBABILITY_OF_DRAW = 0.0001

# %%
# Create players
players, id_to_name, id_to_rank = init_players(NUMBER_OF_PLAYERS)
pairings = init_pairings(players)

players
# Out:
# [[3937741, 'Jason Hall', 1823],
#  [7972739, 'Emily Schneider', 1825],
#  [9872395, 'Roger Carter', 1872],
#  [4687534, 'Gregg Davidson', 1953],
#  [8331071, 'Carrie Williams', 1732],
#  [4796091, 'Jessica Thomas', 1820],
#  [4381341, 'Vanessa Horne', 1793],
#  [9880995, 'James Richmond', 1641],
#  [8615615, 'Jonathan Sanchez', 1614],
#  [3328623, 'John Lane', 1807],
#  [7370910, 'Joel Stone', 1784],
#  [4001196, 'Kari Scott', 1668],
#  [6513985, 'Tina Ali', 1772],
#  [7726112, 'Kim Lawrence', 1645],
#  [9825557, 'Sandra Rogers', 1905],
#  [2032664, 'Gloria Hall', 1674],
#  [7604785, 'Jade Thomas', 1703],
#  [1859136, 'James Williams', 1721],
#  [8133299, 'Jose Miller', 1684],
#  [9593827, 'Melissa Wang', 1752],
#  [4538277, 'Elizabeth Patterson', 1894],
#  [4428978, 'Linda Smith', 1865],
#  [8407828, 'Karen Martinez', 1739],
#  [9311395, 'Robert Mitchell', 1974]]

# %%
results = []
standings_h, splits_h, scores_h, alloc_h, pairs_h = [], [], [], [], []

for rnd in range(NUMBER_OF_ROUNDS):
    standings, splits, scores, alloc, pairs = create_draw(players, results)
    for collection, value in zip([standings_h, splits_h, scores_h, alloc_h, pairs_h],
                                 [standings,   splits,   scores,   alloc,   pairs]):
        collection.append(value)
    print('----- Round', rnd + 1, '-----', )
    print('Goodness of Fit:', (scores * alloc).sum() / NUMBER_OF_PLAYERS)
    print_standings(standings, id_to_name)
    print_pairings(pairs, id_to_name)
    result = run_round(pairs, p_draw=PROBABILITY_OF_DRAW)
    results += result
# Out:
# ----- Round 1 -----
# Goodness of Fit: 4.0
#
#       ID  Name                   Wins    Rank
# -------  -------------------  ------  ------
# 3937741  Jason Hall                0       1
# 7972739  Emily Schneider           0       2
# 9872395  Roger Carter              0       3
# 4687534  Gregg Davidson            0       4
# 8331071  Carrie Williams           0       5
# 4796091  Jessica Thomas            0       6
# 4381341  Vanessa Horne             0       7
# 9880995  James Richmond            0       8
# 8615615  Jonathan Sanchez          0       9
# 3328623  John Lane                 0      10
# 7370910  Joel Stone                0      11
# 4001196  Kari Scott                0      12
# 6513985  Tina Ali                  0      13
# 7726112  Kim Lawrence              0      14
# 9825557  Sandra Rogers             0      15
# 2032664  Gloria Hall               0      16
# 7604785  Jade Thomas               0      17
# 1859136  James Williams            0      18
# 8133299  Jose Miller               0      19
# 9593827  Melissa Wang              0      20
# 4538277  Elizabeth Patterson       0      21
# 4428978  Linda Smith               0      22
# 8407828  Karen Martinez            0      23
# 9311395  Robert Mitchell           0      24
#
#
#    Table #  Player 1 - Name           ID    Rank  Player 2 - Name         ID    Rank
# ---------  -------------------  -------  ------  -----------------  -------  ------
#         1  Jason Hall           3937741       1  Vanessa Horne      4381341       7
#         2  Jessica Thomas       4796091       6  James Richmond     9880995       8
#         3  Jonathan Sanchez     8615615       9  Kari Scott         4001196      12
#         4  Emily Schneider      7972739       2  Sandra Rogers      9825557      15
#         5  Roger Carter         9872395       3  Gloria Hall        2032664      16
#         6  Joel Stone           7370910      11  Jade Thomas        7604785      17
#         7  Kim Lawrence         7726112      14  James Williams     1859136      18
#         8  John Lane            3328623      10  Jose Miller        8133299      19
#         9  Tina Ali             6513985      13  Melissa Wang       9593827      20
#        10  Elizabeth Patterson  4538277      21  Linda Smith        4428978      22
#        11  Carrie Williams      8331071       5  Karen Martinez     8407828      23
#        12  Gregg Davidson       4687534       4  Robert Mitchell    9311395      24
#
# ----- Round 2 -----
# Goodness of Fit: 4.0
#
#       ID  Name                   Wins    Rank
# -------  -------------------  ------  ------
# 4381341  Vanessa Horne             1       1
# 9880995  James Richmond            1       2
# 4001196  Kari Scott                1       3
# 9825557  Sandra Rogers             1       4
# 9872395  Roger Carter              1       5
# 7604785  Jade Thomas               1       6
# 7726112  Kim Lawrence              1       7
# 3328623  John Lane                 1       8
# 9593827  Melissa Wang              1       9
# 4428978  Linda Smith               1      10
# 8407828  Karen Martinez            1      11
# 9311395  Robert Mitchell           1      12
# 3937741  Jason Hall                0      13
# 4796091  Jessica Thomas            0      14
# 8615615  Jonathan Sanchez          0      15
# 7972739  Emily Schneider           0      16
# 2032664  Gloria Hall               0      17
# 7370910  Joel Stone                0      18
# 1859136  James Williams            0      19
# 8133299  Jose Miller               0      20
# 6513985  Tina Ali                  0      21
# 4538277  Elizabeth Patterson       0      22
# 8331071  Carrie Williams           0      23
# 4687534  Gregg Davidson            0      24
#
#
#    Table #  Player 1 - Name         ID    Rank  Player 2 - Name           ID    Rank
# ---------  -----------------  -------  ------  -------------------  -------  ------
#         1  James Richmond     9880995       2  Roger Carter         9872395       5
#         2  Jade Thomas        7604785       6  Kim Lawrence         7726112       7
#         3  Sandra Rogers      9825557       4  John Lane            3328623       8
#         4  Vanessa Horne      4381341       1  Melissa Wang         9593827       9
#         5  Kari Scott         4001196       3  Linda Smith          4428978      10
#         6  Karen Martinez     8407828      11  Robert Mitchell      9311395      12
#         7  Jessica Thomas     4796091      14  Emily Schneider      7972739      16
#         8  Gloria Hall        2032664      17  Joel Stone           7370910      18
#         9  Jason Hall         3937741      13  Jose Miller          8133299      20
#        10  Tina Ali           6513985      21  Elizabeth Patterson  4538277      22
#        11  Jonathan Sanchez   8615615      15  Carrie Williams      8331071      23
#        12  James Williams     1859136      19  Gregg Davidson       4687534      24
#
# ----- Round 3 -----
# Goodness of Fit: 4.0
#
#       ID  Name                   Wins    Rank
# -------  -------------------  ------  ------
# 4381341  Vanessa Horne             2       1
# 9872395  Roger Carter              2       2
# 7604785  Jade Thomas               2       3
# 3328623  John Lane                 2       4
# 4428978  Linda Smith               2       5
# 9311395  Robert Mitchell           2       6
# 9880995  James Richmond            1       7
# 4796091  Jessica Thomas            1       8
# 4001196  Kari Scott                1       9
# 8615615  Jonathan Sanchez          1      10
# 9825557  Sandra Rogers             1      11
# 2032664  Gloria Hall               1      12
# 1859136  James Williams            1      13
# 7726112  Kim Lawrence              1      14
# 8133299  Jose Miller               1      15
# 9593827  Melissa Wang              1      16
# 4538277  Elizabeth Patterson       1      17
# 8407828  Karen Martinez            1      18
# 3937741  Jason Hall                0      19
# 7972739  Emily Schneider           0      20
# 7370910  Joel Stone                0      21
# 6513985  Tina Ali                  0      22
# 8331071  Carrie Williams           0      23
# 4687534  Gregg Davidson            0      24
#
#
#    Table #  Player 1 - Name         ID    Rank  Player 2 - Name           ID    Rank
# ---------  -----------------  -------  ------  -------------------  -------  ------
#         1  Vanessa Horne      4381341       1  Roger Carter         9872395       2
#         2  John Lane          3328623       4  Linda Smith          4428978       5
#         3  Jade Thomas        7604785       3  Robert Mitchell      9311395       6
#         4  Jessica Thomas     4796091       8  Jonathan Sanchez     8615615      10
#         5  James Richmond     9880995       7  Sandra Rogers        9825557      11
#         6  Kari Scott         4001196       9  James Williams       1859136      13
#         7  Gloria Hall        2032664      12  Kim Lawrence         7726112      14
#         8  Jose Miller        8133299      15  Elizabeth Patterson  4538277      17
#         9  Melissa Wang       9593827      16  Karen Martinez       8407828      18
#        10  Jason Hall         3937741      19  Tina Ali             6513985      22
#        11  Emily Schneider    7972739      20  Carrie Williams      8331071      23
#        12  Joel Stone         7370910      21  Gregg Davidson       4687534      24
#
# ----- Round 4 -----
# Goodness of Fit: 3.5
#
#       ID  Name                   Wins    Rank
# -------  -------------------  ------  ------
# 9872395  Roger Carter              3       1
# 7604785  Jade Thomas               3       2
# 3328623  John Lane                 3       3
# 4381341  Vanessa Horne             2       4
# 4796091  Jessica Thomas            2       5
# 9825557  Sandra Rogers             2       6
# 1859136  James Williams            2       7
# 7726112  Kim Lawrence              2       8
# 8133299  Jose Miller               2       9
# 9593827  Melissa Wang              2      10
# 4428978  Linda Smith               2      11
# 9311395  Robert Mitchell           2      12
# 9880995  James Richmond            1      13
# 4001196  Kari Scott                1      14
# 8615615  Jonathan Sanchez          1      15
# 7972739  Emily Schneider           1      16
# 2032664  Gloria Hall               1      17
# 7370910  Joel Stone                1      18
# 6513985  Tina Ali                  1      19
# 4538277  Elizabeth Patterson       1      20
# 8407828  Karen Martinez            1      21
# 3937741  Jason Hall                0      22
# 8331071  Carrie Williams           0      23
# 4687534  Gregg Davidson            0      24
#
#
#    Table #  Player 1 - Name           ID    Rank  Player 2 - Name         ID    Rank
# ---------  -------------------  -------  ------  -----------------  -------  ------
#         1  Roger Carter         9872395       1  John Lane          3328623       3
#         2  Jessica Thomas       4796091       5  Sandra Rogers      9825557       6
#         3  Jade Thomas          7604785       2  James Williams     1859136       7
#         4  Kim Lawrence         7726112       8  Melissa Wang       9593827      10
#         5  Vanessa Horne        4381341       4  Linda Smith        4428978      11
#         6  Jose Miller          8133299       9  Robert Mitchell    9311395      12
#         7  James Richmond       9880995      13  Kari Scott         4001196      14
#         8  Jonathan Sanchez     8615615      15  Gloria Hall        2032664      17
#         9  Emily Schneider      7972739      16  Tina Ali           6513985      19
#        10  Joel Stone           7370910      18  Karen Martinez     8407828      21
#        11  Elizabeth Patterson  4538277      20  Carrie Williams    8331071      23
#        12  Jason Hall           3937741      22  Gregg Davidson     4687534      24
#
# ----- Round 5 -----
# Goodness of Fit: 3.5
#
#       ID  Name                   Wins    Rank
# -------  -------------------  ------  ------
# 9872395  Roger Carter              4       1
# 9825557  Sandra Rogers             3       2
# 7604785  Jade Thomas               3       3
# 1859136  James Williams            3       4
# 8133299  Jose Miller               3       5
# 3328623  John Lane                 3       6
# 9593827  Melissa Wang              3       7
# 4428978  Linda Smith               3       8
# 4381341  Vanessa Horne             2       9
# 4796091  Jessica Thomas            2      10
# 4001196  Kari Scott                2      11
# 7972739  Emily Schneider           2      12
# 2032664  Gloria Hall               2      13
# 7726112  Kim Lawrence              2      14
# 4538277  Elizabeth Patterson       2      15
# 8407828  Karen Martinez            2      16
# 9311395  Robert Mitchell           2      17
# 3937741  Jason Hall                1      18
# 9880995  James Richmond            1      19
# 8615615  Jonathan Sanchez          1      20
# 7370910  Joel Stone                1      21
# 6513985  Tina Ali                  1      22
# 8331071  Carrie Williams           0      23
# 4687534  Gregg Davidson            0      24
#
#
#    Table #  Player 1 - Name           ID    Rank  Player 2 - Name         ID    Rank
# ---------  -------------------  -------  ------  -----------------  -------  ------
#         1  Jade Thomas          7604785       3  Jose Miller        8133299       5
#         2  James Williams       1859136       4  John Lane          3328623       6
#         3  Roger Carter         9872395       1  Melissa Wang       9593827       7
#         4  Sandra Rogers        9825557       2  Linda Smith        4428978       8
#         5  Jessica Thomas       4796091      10  Kari Scott         4001196      11
#         6  Vanessa Horne        4381341       9  Gloria Hall        2032664      13
#         7  Elizabeth Patterson  4538277      15  Karen Martinez     8407828      16
#         8  Kim Lawrence         7726112      14  Robert Mitchell    9311395      17
#         9  Emily Schneider      7972739      12  James Richmond     9880995      19
#        10  Jason Hall           3937741      18  Joel Stone         7370910      21
#        11  Jonathan Sanchez     8615615      20  Tina Ali           6513985      22
#        12  Carrie Williams      8331071      23  Gregg Davidson     4687534      24
#
# ----- Round 6 -----
# Goodness of Fit: 3.4166666666666665
#
#       ID  Name                   Wins    Rank
# -------  -------------------  ------  ------
# 9872395  Roger Carter              5       1
# 9825557  Sandra Rogers             4       2
# 7604785  Jade Thomas               4       3
# 3328623  John Lane                 4       4
# 4381341  Vanessa Horne             3       5
# 4796091  Jessica Thomas            3       6
# 1859136  James Williams            3       7
# 7726112  Kim Lawrence              3       8
# 8133299  Jose Miller               3       9
# 9593827  Melissa Wang              3      10
# 4428978  Linda Smith               3      11
# 4538277  Elizabeth Patterson       3      12
# 9880995  James Richmond            2      13
# 4001196  Kari Scott                2      14
# 8615615  Jonathan Sanchez          2      15
# 7972739  Emily Schneider           2      16
# 2032664  Gloria Hall               2      17
# 7370910  Joel Stone                2      18
# 8407828  Karen Martinez            2      19
# 9311395  Robert Mitchell           2      20
# 3937741  Jason Hall                1      21
# 6513985  Tina Ali                  1      22
# 4687534  Gregg Davidson            1      23
# 8331071  Carrie Williams           0      24
#
#
#    Table #  Player 1 - Name         ID    Rank  Player 2 - Name           ID    Rank
# ---------  -----------------  -------  ------  -------------------  -------  ------
#         1  Roger Carter       9872395       1  Jade Thomas          7604785       3
#         2  Sandra Rogers      9825557       2  John Lane            3328623       4
#         3  Jessica Thomas     4796091       6  James Williams       1859136       7
#         4  Vanessa Horne      4381341       5  Kim Lawrence         7726112       8
#         5  Jose Miller        8133299       9  Linda Smith          4428978      11
#         6  Melissa Wang       9593827      10  Elizabeth Patterson  4538277      12
#         7  James Richmond     9880995      13  Jonathan Sanchez     8615615      15
#         8  Emily Schneider    7972739      16  Gloria Hall          2032664      17
#         9  Kari Scott         4001196      14  Karen Martinez       8407828      19
#        10  Joel Stone         7370910      18  Robert Mitchell      9311395      20
#        11  Tina Ali           6513985      22  Gregg Davidson       4687534      23
#        12  Jason Hall         3937741      21  Carrie Williams      8331071      24
