# %%
import numpy as np
from queue import PriorityQueue as queue
from collections import defaultdict
from faker import Faker
from tabulate import tabulate

fake = Faker()

# %% [markdown]
# ## Draw Simulation Methods

# %%
def init_players(num_players):
    """
    Create a collection of players in the form [player_id, player_name, player_ranking]
    Arguments:
        num_players: Number of players to add to the draw
    Returns:
        players: Array of player details
            (n x 3) list containing [player_id, player_name, player_ranking]
    """
    players = []
    id_to_name, id_to_rank = {}, {}
    for n in range(num_players):
        p_id, p_name, p_rank = np.random.randint(1000000, 9999999), fake.name(), np.random.randint(1600, 2000)
        players.append([p_id, p_name, p_rank])
        id_to_name[p_id] = p_name
        id_to_rank[p_id] = p_rank
    return players, id_to_name, id_to_rank

# %%
def init_pairings(players):
    """
    Randomly create results for the first round
    Arguments:
        players: (n x 3) numpy array containing [player_id, player_name, player_ranking]
    Returns:
        results: Randomly generated results table
            (n x 3) list containing [player_a_id, player_b_id, match_winner_id]
    """
    results = []
    for n in range(0, len(players), 2):
        a, b = players[n][0], players[n+1][0]
        result = [a, b, np.random.choice([a, b, None], 1, p=(0.45, 0.45, 0.1))[0]]
        results.append(result)
    return results

# %%
def run_round(pairings, p_draw=0):
    """
    Randomly create results for a round
    Arguments:
        pairings: List of pairings for the round to be simulated
            (n x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    Returns:
        results: Randomly generated results table
            (n x 3) list containing [player_a_id, player_b_id, match_winner_id]
    """
    results = []
    p_win = (1 - p_draw) / 2
    for pairing in pairings:
        a, b = pairing[0][1], pairing[1][1]
        result = [a, b, np.random.choice([a, b, None], 1, p=(p_win, p_win, p_draw))[0]]
        results.append(result)
        
    return results

# %% [markdown]
# ## Draw Calculation Methods

# %%
def create_draw(players, pairs):
    """
    Create draw for the round
    Agruments:
        players: Array of player details
            (n x 3) list containing [player_id, player_name, player_ranking]
        pairs: List of pairings for all rounds to date
            (m x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    Returns:
        standings: List of standings for all players still in the tournament
            (n x 2) list containing [player_id, player_wins]
        splits: List of index points where each points bracket finishes
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
        alloc: The matrix form pairing allocations
            (n x n) matrix of integers
        pairings: The list form of pairing allocations
            (n / 2 x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    """
    n_players = len(players)

    rankings = defaultdict(int)
    if len(pairs) > 0:
        for pair in pairs:
            rankings[pair[0]] += (pair[0] == pair[2])
            rankings[pair[1]] += (pair[1] == pair[2])
    else:
        for player in players:
            rankings[player[0]] = 0

    standings = np.transpose([list(rankings.keys()), list(rankings.values())])
    standings = np.array(sorted(standings, key=lambda x: x[1], reverse=True))
    
    scores, splits  = get_scores(standings, pairs)
    alloc, pairings = get_allocations(standings, scores)
    
    return standings, splits, scores, alloc, pairings

# %%
def get_scores(standings, pairs):
    """
    Assign scores to each possible pairing
    A higher score means that the pairing is more strongly preferred
    Arguments:
        standings: List of standings for all players still in the tournament
            (n x 2) list containing [player_id, player_wins]
        pairs: List of pairings for all rounds to date
            (m x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    Returns:
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
        splits: List of index points where each points bracket finishes
    """
    n_players = len(standings)
    ix = {player_id: pos for pos, player_id in enumerate(standings[:,0])}
    splits = [n for n in range(n_players) if standings[n,1] != standings[n-1,1]]
    
    # Calculate scores for pairings
    scores = np.full((n_players, n_players), -100)
    
    split_1, split_2 = 0, 0
    for split in splits + [n_players]:
        # Assign points for players in same bracket
        scores[split_1:split, split_1:split] = 4
        # Assign points for pull-up bracket
        if split_1 %2 == 1:
            scores[split_2:split_1, split_1:split] = 1
            scores[split_1:split, split_2:split_1] = 1
        split_1, split_2 = split, split_1
    
    # Reset self vs self to -inf
    np.fill_diagonal(scores, -100)

    # Subtract points for prior matchup
    for pair in pairs:
        a, b = ix[pair[0]], ix[pair[1]]
        scores[a,b] -= 1
        scores[b,a] -= 1
        
    return scores, splits

# %%
def get_allocations(standings, scores):
    """
    Allocate player pairings
    Arguments:
        standings: List of standings for all players still in the tournament
            (n x 2) list containing [player_id, player_wins]
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
    Returns:
        alloc: The matrix form pairing allocations
            (n x n) matrix of integers
        pairs: The list form of pairing allocations
            (n / 2 x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    """
    n_players = len(standings)
    ix = {pos: player_id for pos, player_id in enumerate(standings[:,0])}
    alloc = np.zeros((n_players, n_players), dtype=int)

    for _ in range(int(n_players / 2)):
        mask = (1 - alloc.sum(axis=1))
        # Choose Player A
        p = scores.max() - scores.mean(axis=1)
        p = p * mask
        a = p.argmax()
        # Choose Player B
        p = np.exp(scores[a])
        p = np.maximum(p * mask, 0)
        b = np.random.choice(range(n_players),p=p/p.sum())
        
        alloc[a, b] = 1
        alloc[b, a] = 1
    
    alloc_ = alloc * np.tri(*alloc.shape)

    pairs = []
    for n in range(n_players):
        if alloc_[n].max() == 1:
            a, b = n, alloc_[n].argmax()
            pairs.append([(a, ix[a]), (b, ix[b])])

    return alloc, pairs

# %% [markdown]
# ## Draw Printing Methods

# %%
def print_standings(standings, id_to_name):
    """
    Print standings for the round in table form
    """
    table = []
    for rank, player in enumerate(standings):
        table.append([int(player[0]), id_to_name[player[0]], player[1], rank+1])
    print('\n', tabulate(table, headers=['ID', 'Name', 'Wins', 'Rank']), '\n')
    

def print_pairings(pairs, id_to_name, scores):
    """
    Print pairings for the round in table form
    """
    table = []
    for table_num, pair in enumerate(pairs):
        b, a = pair[0], pair[1]
        score = scores[b[0], a[0]]
        row = [table_num+1, id_to_name[a[1]], int(a[1]), int(a[0])+1, id_to_name[b[1]], int(b[1]), int(b[0])+1, score]
        table.append(row)
    headers = ['Table #', 'Player 1 - Name', 'ID', 'Rank', 'Player 2 - Name', 'ID', 'Rank', 'GOF']
    print('\n', tabulate(table, headers=headers), '\n')

# %% [markdown]
# ## Run a sample Tournament
# Create a list of players then run through a multi-round tournament and print the results
# Each round prints:
# - Goodness of fit score: Score for the pairings allocated in the round. The maximum possible score is 4. If a number < 0 comes out, something has probably gone wrong
# - Standings: A table of standings of the players (based only on # of wins, no accounting for draws, op wins etc)
# - Pairings: A table of pairings for the following round (including player name and standing so you can check if players are being paired with others nearby)
#
# To show all the standings and pairings at once, make sure to select the cell, click on the "Cell" menu, select -> "Current Outputs" and then select "Toggle Scrolling"
#
# The entire history of "standings", "splits", "scores", "allocations", and "pairs" is recorded in the lists *standings_h, splits_h, scores_h, alloc_h, pairs_h*
#
# Note: Early stage demo only. This does not support:
# - Odd numbers of players and byes
# - Allocating pods
# - Iterative sampling methods to improve draw quality
# - etc

# %%
NUMBER_OF_PLAYERS = 26
NUMBER_OF_ROUNDS  = 6
PROBABILITY_OF_DRAW = 0.0001

# %%
# Create players
players, id_to_name, id_to_rank = init_players(NUMBER_OF_PLAYERS)
pairings = init_pairings(players)

players
# Out:
# [[4251003, 'Ryan Gardner', 1758],
#  [2691285, 'Jeremy Warren', 1809],
#  [9671019, 'Justin Smith', 1650],
#  [3057559, 'Danielle Smith', 1940],
#  [8240785, 'Debra Hicks', 1834],
#  [3566567, 'Carl Dunn', 1632],
#  [5212050, 'Elizabeth Moore', 1736],
#  [1087335, 'Katrina Ellis', 1991],
#  [7143183, 'Amy Davis', 1967],
#  [7739437, 'Angel Vargas', 1803],
#  [1552168, 'Juan Dawson', 1928],
#  [3355891, 'Crystal Robles', 1849],
#  [5290223, 'Melissa Duncan', 1706],
#  [4499392, 'Patricia Washington', 1740],
#  [9391179, 'Sarah Ayala', 1628],
#  [1314658, 'Marcia Hopkins', 1992],
#  [7653239, 'Christopher Powell', 1942],
#  [7145093, 'Theresa Walker', 1897],
#  [5966735, 'Heidi Hudson', 1668],
#  [5605543, 'Megan Clark', 1970],
#  [8660972, 'Robert Holland', 1774],
#  [5801320, 'Christine Thompson', 1896],
#  [3465991, 'Amy Parker', 1803],
#  [5979078, 'Kelly Martin', 1702],
#  [5461385, 'Evelyn Powell', 1799],
#  [2518561, 'Mary Lam', 1837]]

# %%
results = []
standings_h, splits_h, scores_h, alloc_h, pairs_h = [], [], [], [], []

for rnd in range(NUMBER_OF_ROUNDS):
    standings, splits, scores, alloc, pairs = create_draw(players, results)
    for collection, value in zip([standings_h, splits_h, scores_h, alloc_h, pairs_h],
                                 [standings,   splits,   scores,   alloc,   pairs]):
        collection.append(value)
    print('----- Round', rnd + 1, '-----', )
    print('Goodness of Fit:', (scores * alloc).sum() / NUMBER_OF_PLAYERS)
    print_standings(standings, id_to_name, )
    print_pairings(pairs, id_to_name, scores)
    result = run_round(pairs, p_draw=PROBABILITY_OF_DRAW)
    results += result
# Out:
# ----- Round 1 -----
# Goodness of Fit: 4.0
#
#       ID  Name                   Wins    Rank
# -------  -------------------  ------  ------
# 4251003  Ryan Gardner              0       1
# 2691285  Jeremy Warren             0       2
# 9671019  Justin Smith              0       3
# 3057559  Danielle Smith            0       4
# 8240785  Debra Hicks               0       5
# 3566567  Carl Dunn                 0       6
# 5212050  Elizabeth Moore           0       7
# 1087335  Katrina Ellis             0       8
# 7143183  Amy Davis                 0       9
# 7739437  Angel Vargas              0      10
# 1552168  Juan Dawson               0      11
# 3355891  Crystal Robles            0      12
# 5290223  Melissa Duncan            0      13
# 4499392  Patricia Washington       0      14
# 9391179  Sarah Ayala               0      15
# 1314658  Marcia Hopkins            0      16
# 7653239  Christopher Powell        0      17
# 7145093  Theresa Walker            0      18
# 5966735  Heidi Hudson              0      19
# 5605543  Megan Clark               0      20
# 8660972  Robert Holland            0      21
# 5801320  Christine Thompson        0      22
# 3465991  Amy Parker                0      23
# 5979078  Kelly Martin              0      24
# 5461385  Evelyn Powell             0      25
# 2518561  Mary Lam                  0      26
#
#
#    Table #  Player 1 - Name           ID    Rank  Player 2 - Name          ID    Rank    GOF
# ---------  -------------------  -------  ------  ------------------  -------  ------  -----
#         1  Jeremy Warren        2691285       2  Justin Smith        9671019       3      4
#         2  Juan Dawson          1552168      11  Crystal Robles      3355891      12      4
#         3  Elizabeth Moore      5212050       7  Melissa Duncan      5290223      13      4
#         4  Danielle Smith       3057559       4  Sarah Ayala         9391179      15      4
#         5  Debra Hicks          8240785       5  Marcia Hopkins      1314658      16      4
#         6  Amy Davis            7143183       9  Heidi Hudson        5966735      19      4
#         7  Carl Dunn            3566567       6  Megan Clark         5605543      20      4
#         8  Patricia Washington  4499392      14  Robert Holland      8660972      21      4
#         9  Theresa Walker       7145093      18  Christine Thompson  5801320      22      4
#        10  Christopher Powell   7653239      17  Amy Parker          3465991      23      4
#        11  Katrina Ellis        1087335       8  Kelly Martin        5979078      24      4
#        12  Ryan Gardner         4251003       1  Evelyn Powell       5461385      25      4
#        13  Angel Vargas         7739437      10  Mary Lam            2518561      26      4
#
# ----- Round 2 -----
# Goodness of Fit: 3.769230769230769
#
#       ID  Name                   Wins    Rank
# -------  -------------------  ------  ------
# 2691285  Jeremy Warren             1       1
# 3355891  Crystal Robles            1       2
# 5290223  Melissa Duncan            1       3
# 3057559  Danielle Smith            1       4
# 8240785  Debra Hicks               1       5
# 7143183  Amy Davis                 1       6
# 3566567  Carl Dunn                 1       7
# 4499392  Patricia Washington       1       8
# 5801320  Christine Thompson        1       9
# 7653239  Christopher Powell        1      10
# 1087335  Katrina Ellis             1      11
# 4251003  Ryan Gardner              1      12
# 2518561  Mary Lam                  1      13
# 9671019  Justin Smith              0      14
# 1552168  Juan Dawson               0      15
# 5212050  Elizabeth Moore           0      16
# 9391179  Sarah Ayala               0      17
# 1314658  Marcia Hopkins            0      18
# 5966735  Heidi Hudson              0      19
# 5605543  Megan Clark               0      20
# 8660972  Robert Holland            0      21
# 7145093  Theresa Walker            0      22
# 3465991  Amy Parker                0      23
# 5979078  Kelly Martin              0      24
# 5461385  Evelyn Powell             0      25
# 7739437  Angel Vargas              0      26
#
#
#    Table #  Player 1 - Name           ID    Rank  Player 2 - Name          ID    Rank    GOF
# ---------  -------------------  -------  ------  ------------------  -------  ------  -----
#         1  Amy Davis            7143183       6  Carl Dunn           3566567       7      4
#         2  Danielle Smith       3057559       4  Christine Thompson  5801320       9      4
#         3  Patricia Washington  4499392       8  Christopher Powell  7653239      10      4
#         4  Crystal Robles       3355891       2  Katrina Ellis       1087335      11      4
#         5  Melissa Duncan       5290223       3  Ryan Gardner        4251003      12      4
#         6  Jeremy Warren        2691285       1  Mary Lam            2518561      13      4
#         7  Debra Hicks          8240785       5  Juan Dawson         1552168      15      1
#         8  Marcia Hopkins       1314658      18  Megan Clark         5605543      20      4
#         9  Sarah Ayala          9391179      17  Robert Holland      8660972      21      4
#        10  Theresa Walker       7145093      22  Amy Parker          3465991      23      4
#        11  Heidi Hudson         5966735      19  Kelly Martin        5979078      24      4
#        12  Justin Smith         9671019      14  Evelyn Powell       5461385      25      4
#        13  Elizabeth Moore      5212050      16  Angel Vargas        7739437      26      4
#
# ----- Round 3 -----
# Goodness of Fit: 3.5384615384615383
#
#       ID  Name                   Wins    Rank
# -------  -------------------  ------  ------
# 2691285  Jeremy Warren             2       1
# 5290223  Melissa Duncan            2       2
# 8240785  Debra Hicks               2       3
# 3566567  Carl Dunn                 2       4
# 4499392  Patricia Washington       2       5
# 5801320  Christine Thompson        2       6
# 1087335  Katrina Ellis             2       7
# 3355891  Crystal Robles            1       8
# 3057559  Danielle Smith            1       9
# 1314658  Marcia Hopkins            1      10
# 5966735  Heidi Hudson              1      11
# 7143183  Amy Davis                 1      12
# 8660972  Robert Holland            1      13
# 7145093  Theresa Walker            1      14
# 7653239  Christopher Powell        1      15
# 5461385  Evelyn Powell             1      16
# 4251003  Ryan Gardner              1      17
# 2518561  Mary Lam                  1      18
# 7739437  Angel Vargas              1      19
# 9671019  Justin Smith              0      20
# 1552168  Juan Dawson               0      21
# 5212050  Elizabeth Moore           0      22
# 9391179  Sarah Ayala               0      23
# 5605543  Megan Clark               0      24
# 3465991  Amy Parker                0      25
# 5979078  Kelly Martin              0      26
#
#
#    Table #  Player 1 - Name         ID    Rank  Player 2 - Name           ID    Rank    GOF
# ---------  -----------------  -------  ------  -------------------  -------  ------  -----
#         1  Jeremy Warren      2691285       1  Debra Hicks          8240785       3      4
#         2  Carl Dunn          3566567       4  Patricia Washington  4499392       5      4
#         3  Melissa Duncan     5290223       2  Christine Thompson   5801320       6      4
#         4  Crystal Robles     3355891       8  Amy Davis            7143183      12      4
#         5  Danielle Smith     3057559       9  Robert Holland       8660972      13      4
#         6  Heidi Hudson       5966735      11  Christopher Powell   7653239      15      4
#         7  Katrina Ellis      1087335       7  Ryan Gardner         4251003      17      1
#         8  Evelyn Powell      5461385      16  Mary Lam             2518561      18      4
#         9  Theresa Walker     7145093      14  Angel Vargas         7739437      19      4
#        10  Juan Dawson        1552168      21  Sarah Ayala          9391179      23      4
#        11  Elizabeth Moore    5212050      22  Megan Clark          5605543      24      4
#        12  Marcia Hopkins     1314658      10  Amy Parker           3465991      25      1
#        13  Justin Smith       9671019      20  Kelly Martin         5979078      26      4
#
# ----- Round 4 -----
# Goodness of Fit: 3.6923076923076925
#
#       ID  Name                   Wins    Rank
# -------  -------------------  ------  ------
# 2691285  Jeremy Warren             3       1
# 5290223  Melissa Duncan            3       2
# 3566567  Carl Dunn                 3       3
# 1087335  Katrina Ellis             3       4
# 1314658  Marcia Hopkins            2       5
# 8240785  Debra Hicks               2       6
# 7143183  Amy Davis                 2       7
# 8660972  Robert Holland            2       8
# 4499392  Patricia Washington       2       9
# 5801320  Christine Thompson        2      10
# 7653239  Christopher Powell        2      11
# 5461385  Evelyn Powell             2      12
# 7739437  Angel Vargas              2      13
# 3355891  Crystal Robles            1      14
# 5212050  Elizabeth Moore           1      15
# 9391179  Sarah Ayala               1      16
# 3057559  Danielle Smith            1      17
# 5966735  Heidi Hudson              1      18
# 7145093  Theresa Walker            1      19
# 5979078  Kelly Martin              1      20
# 4251003  Ryan Gardner              1      21
# 2518561  Mary Lam                  1      22
# 9671019  Justin Smith              0      23
# 1552168  Juan Dawson               0      24
# 5605543  Megan Clark               0      25
# 3465991  Amy Parker                0      26
#
#
#    Table #  Player 1 - Name           ID    Rank  Player 2 - Name          ID    Rank    GOF
# ---------  -------------------  -------  ------  ------------------  -------  ------  -----
#         1  Jeremy Warren        2691285       1  Melissa Duncan      5290223       2      4
#         2  Carl Dunn            3566567       3  Katrina Ellis       1087335       4      4
#         3  Marcia Hopkins       1314658       5  Amy Davis           7143183       7      4
#         4  Debra Hicks          8240785       6  Christine Thompson  5801320      10      4
#         5  Patricia Washington  4499392       9  Evelyn Powell       5461385      12      4
#         6  Robert Holland       8660972       8  Angel Vargas        7739437      13      4
#         7  Christopher Powell   7653239      11  Elizabeth Moore     5212050      15      1
#         8  Sarah Ayala          9391179      16  Theresa Walker      7145093      19      4
#         9  Heidi Hudson         5966735      18  Kelly Martin        5979078      20      3
#        10  Crystal Robles       3355891      14  Ryan Gardner        4251003      21      4
#        11  Danielle Smith       3057559      17  Mary Lam            2518561      22      4
#        12  Juan Dawson          1552168      24  Megan Clark         5605543      25      4
#        13  Justin Smith         9671019      23  Amy Parker          3465991      26      4
#
# ----- Round 5 -----
# Goodness of Fit: 4.0
#
#       ID  Name                   Wins    Rank
# -------  -------------------  ------  ------
# 5290223  Melissa Duncan            4       1
# 3566567  Carl Dunn                 4       2
# 2691285  Jeremy Warren             3       3
# 8240785  Debra Hicks               3       4
# 7143183  Amy Davis                 3       5
# 8660972  Robert Holland            3       6
# 4499392  Patricia Washington       3       7
# 1087335  Katrina Ellis             3       8
# 3355891  Crystal Robles            2       9
# 5212050  Elizabeth Moore           2      10
# 1314658  Marcia Hopkins            2      11
# 5801320  Christine Thompson        2      12
# 7145093  Theresa Walker            2      13
# 7653239  Christopher Powell        2      14
# 5979078  Kelly Martin              2      15
# 5461385  Evelyn Powell             2      16
# 2518561  Mary Lam                  2      17
# 7739437  Angel Vargas              2      18
# 9391179  Sarah Ayala               1      19
# 3057559  Danielle Smith            1      20
# 5966735  Heidi Hudson              1      21
# 5605543  Megan Clark               1      22
# 3465991  Amy Parker                1      23
# 4251003  Ryan Gardner              1      24
# 9671019  Justin Smith              0      25
# 1552168  Juan Dawson               0      26
#
#
#    Table #  Player 1 - Name         ID    Rank  Player 2 - Name           ID    Rank    GOF
# ---------  -----------------  -------  ------  -------------------  -------  ------  -----
#         1  Melissa Duncan     5290223       1  Carl Dunn            3566567       2      4
#         2  Jeremy Warren      2691285       3  Robert Holland       8660972       6      4
#         3  Amy Davis          7143183       5  Patricia Washington  4499392       7      4
#         4  Debra Hicks        8240785       4  Katrina Ellis        1087335       8      4
#         5  Elizabeth Moore    5212050      10  Christine Thompson   5801320      12      4
#         6  Crystal Robles     3355891       9  Christopher Powell   7653239      14      4
#         7  Marcia Hopkins     1314658      11  Evelyn Powell        5461385      16      4
#         8  Theresa Walker     7145093      13  Mary Lam             2518561      17      4
#         9  Kelly Martin       5979078      15  Angel Vargas         7739437      18      4
#        10  Heidi Hudson       5966735      21  Megan Clark          5605543      22      4
#        11  Danielle Smith     3057559      20  Amy Parker           3465991      23      4
#        12  Sarah Ayala        9391179      19  Ryan Gardner         4251003      24      4
#        13  Justin Smith       9671019      25  Juan Dawson          1552168      26      4
#
# ----- Round 6 -----
# Goodness of Fit: 2.8461538461538463
#
#       ID  Name                   Wins    Rank
# -------  -------------------  ------  ------
# 3566567  Carl Dunn                 5       1
# 5290223  Melissa Duncan            4       2
# 8240785  Debra Hicks               4       3
# 8660972  Robert Holland            4       4
# 4499392  Patricia Washington       4       5
# 2691285  Jeremy Warren             3       6
# 3355891  Crystal Robles            3       7
# 5212050  Elizabeth Moore           3       8
# 1314658  Marcia Hopkins            3       9
# 7143183  Amy Davis                 3      10
# 7145093  Theresa Walker            3      11
# 1087335  Katrina Ellis             3      12
# 7739437  Angel Vargas              3      13
# 5605543  Megan Clark               2      14
# 5801320  Christine Thompson        2      15
# 3465991  Amy Parker                2      16
# 7653239  Christopher Powell        2      17
# 5979078  Kelly Martin              2      18
# 5461385  Evelyn Powell             2      19
# 4251003  Ryan Gardner              2      20
# 2518561  Mary Lam                  2      21
# 1552168  Juan Dawson               1      22
# 9391179  Sarah Ayala               1      23
# 3057559  Danielle Smith            1      24
# 5966735  Heidi Hudson              1      25
# 9671019  Justin Smith              0      26
#
#
#    Table #  Player 1 - Name           ID    Rank  Player 2 - Name          ID    Rank    GOF
# ---------  -------------------  -------  ------  ------------------  -------  ------  -----
#         1  Carl Dunn            3566567       1  Debra Hicks         8240785       3      1
#         2  Melissa Duncan       5290223       2  Robert Holland      8660972       4      4
#         3  Patricia Washington  4499392       5  Jeremy Warren       2691285       6      1
#         4  Crystal Robles       3355891       7  Theresa Walker      7145093      11      4
#         5  Elizabeth Moore      5212050       8  Katrina Ellis       1087335      12      4
#         6  Marcia Hopkins       1314658       9  Angel Vargas        7739437      13      4
#         7  Megan Clark          5605543      14  Christine Thompson  5801320      15      4
#         8  Amy Davis            7143183      10  Evelyn Powell       5461385      19      1
#         9  Christopher Powell   7653239      17  Ryan Gardner        4251003      20      4
#        10  Kelly Martin         5979078      18  Mary Lam            2518561      21      4
#        11  Juan Dawson          1552168      22  Danielle Smith      3057559      24      4
#        12  Amy Parker           3465991      16  Heidi Hudson        5966735      25      1
#        13  Sarah Ayala          9391179      23  Justin Smith        9671019      26      1
