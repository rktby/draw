# %%
import numpy as np
from queue import PriorityQueue as queue
from collections import defaultdict
from faker import Faker
from tabulate import tabulate
from collections import deque

fake = Faker()

# %% [markdown]
# ## Draw Simulation Methods

# %%
def init_players(num_players):
    """
    Create a collection of players in the form [player_id, player_name, player_ranking]
    Arguments:
        num_players: Number of players to add to the draw
    Returns:
        players: Array of player details
            (n x 3) list containing [player_id, player_name, player_ranking]
    """
    players = []
    id_to_name, id_to_rank = {}, {}
    for n in range(num_players):
        p_id, p_name, p_rank = np.random.randint(1000000, 9999999), fake.name(), np.random.randint(1600, 2000)
        players.append([p_id, p_name, p_rank])
        id_to_name[p_id] = p_name
        id_to_rank[p_id] = p_rank
    return players, id_to_name, id_to_rank

# %%
def init_pairings(players):
    """
    Randomly create results for the first round
    Arguments:
        players: (n x 3) numpy array containing [player_id, player_name, player_ranking]
    Returns:
        results: Randomly generated results table
            (n x 3) list containing [player_a_id, player_b_id, match_winner_id]
    """
    results = []
    for n in range(0, len(players), 2):
        a, b = players[n][0], players[n+1][0]
        result = [a, b, np.random.choice([a, b, None], 1, p=(0.45, 0.45, 0.1))[0]]
        results.append(result)
    return results

# %%
def run_round(pairings, p_draw=0):
    """
    Randomly create results for a round
    Arguments:
        pairings: List of pairings for the round to be simulated
            (n x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    Returns:
        results: Randomly generated results table
            (n x 3) list containing [player_a_id, player_b_id, match_winner_id]
    """
    results = []
    p_win = (1 - p_draw) / 2
    for pairing in pairings:
        a, b = pairing[0][1], pairing[1][1]
        result = [a, b, np.random.choice([a, b, None], 1, p=(p_win, p_win, p_draw))[0]]
        results.append(result)
        
    return results

# %% [markdown]
# ## Draw Calculation Methods

# %%
def create_draw(players, pairs):
    """
    Create draw for the round
    Agruments:
        players: Array of player details
            (n x 3) list containing [player_id, player_name, player_ranking]
        pairs: List of pairings for all rounds to date
            (m x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    Returns:
        standings: List of standings for all players still in the tournament
            (n x 2) list containing [player_id, player_wins]
        splits: List of index points where each points bracket finishes
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
        alloc: The matrix form pairing allocations
            (n x n) matrix of integers
        pairings: The list form of pairing allocations
            (n / 2 x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    """
    n_players = len(players)

    rankings = defaultdict(int)
    if len(pairs) > 0:
        for pair in pairs:
            rankings[pair[0]] += (pair[0] == pair[2])
            rankings[pair[1]] += (pair[1] == pair[2])
    else:
        for player in players:
            rankings[player[0]] = 0

    standings = np.transpose([list(rankings.keys()), list(rankings.values())])
    standings = np.array(sorted(standings, key=lambda x: x[1], reverse=True))
    
    scores, splits  = get_scores(standings, pairs)
    alloc, pairings = get_allocations(standings, scores)
    
    return standings, splits, scores, alloc, pairings

# %%
def get_scores(standings, pairs):
    """
    Assign scores to each possible pairing
    A higher score means that the pairing is more strongly preferred
    Arguments:
        standings: List of standings for all players still in the tournament
            (n x 2) list containing [player_id, player_wins]
        pairs: List of pairings for all rounds to date
            (m x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    Returns:
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
        splits: List of index points where each points bracket finishes
    """
    n_players = len(standings)
    ix = {player_id: pos for pos, player_id in enumerate(standings[:,0])}
    splits = [n for n in range(n_players) if standings[n,1] != standings[n-1,1]]
    
    # Calculate scores for pairings
    scores = np.full((n_players, n_players), -100)
    
    split_1, split_2 = 0, 0
    for split in splits + [n_players]:
        # Assign points for players in same bracket
        scores[split_1:split, split_1:split] = 4
        # Assign points for pull-up bracket
        if split_1 %2 == 1:
            scores[split_2:split_1, split_1:split] = 1
            scores[split_1:split, split_2:split_1] = 1
        split_1, split_2 = split, split_1
    
    # Reset self vs self to -inf
    np.fill_diagonal(scores, -100)

    # Subtract points for prior matchup
    for pair in pairs:
        a, b = ix[pair[0]], ix[pair[1]]
        scores[a,b] -= 1
        scores[b,a] -= 1
        
    return scores, splits

# %%
def swap_pairs(pair_1, pair_2, alloc):
    """
    Swap players between two pairings
    Original pairing of (a,b) and (c,d) becomes (a,c) and (b,d)
    Arguments:
        pair_1: Tuple containing first pair to swap (a,b)
        pair_2: Tuple containing first pair to swap (c,d)
        alloc: The matrix form pairing allocations
            (n x n) matrix of integers
    Returns:
        alloc: The matrix form pairing allocations with [(a,b), (c,d)] -> [(a,c), (b,d)]
            (n x n) matrix of integers        
    """
    a, b = pair_1
    c, d = pair_2

    alloc[a, b] = 0
    alloc[b, a] = 0
    alloc[c, d] = 0
    alloc[d, c] = 0
    alloc[a, c] = 1
    alloc[c, a] = 1
    alloc[b, d] = 1
    alloc[d, b] = 1
    
    return alloc

# %%
def get_allocations(standings, scores):
    """
    Allocate player pairings
    Arguments:
        standings: List of standings for all players still in the tournament
            (n x 2) list containing [player_id, player_wins]
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
    Returns:
        alloc: The matrix form pairing allocations
            (n x n) matrix of integers
        pairs: The list form of pairing allocations
            (n / 2 x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    """
    n_players = len(standings)
    ix = {pos: player_id for pos, player_id in enumerate(standings[:,0])}
    alloc = np.zeros((n_players, n_players), dtype=int)

    # Construct initial draw
    for _ in range(int(n_players / 2)):
        mask = (1 - alloc.sum(axis=1))
        # Choose Player A
        p = scores.max() - scores.mean(axis=1)
        p = p * mask
        a = p.argmax()
        # Choose Player B
        p = np.exp(scores[a])
        p = np.maximum(p * mask, 0)
        b = np.random.choice(range(n_players),p=p/p.sum())
        
        alloc[a, b] = 1
        alloc[b, a] = 1

    # Run Metropolis-Hastings to iteratively improve draw
    prob = np.exp(scores)
    prob /= prob.sum(axis=1, keepdims=True)

    score = (alloc*scores).sum()/len(prob)
    score_q = deque([-100, -100, score], 3)
    best_alloc = alloc.copy()
    while score != min(score_q):
        for a, p in enumerate(prob):
            b = alloc[a].argmax()
            c = np.random.choice(range(len(p)),p=p)
            d = alloc[c].argmax()
            p_change = prob[a,c]*prob[b,d]/(prob[a,b]*prob[c,d] + prob[a,c]*prob[b,d])
            if np.random.random() < p_change:
                alloc = swap_pairs((a,b), (c,d), alloc)

        score = (alloc*scores).sum()/len(prob)
        if score > max(score_q):
            best_alloc = alloc.copy()
        score_q.append(score)
    
    alloc = best_alloc
    del(best_alloc)
    
    # Create list form of pairings
    alloc_ = alloc * np.tri(*alloc.shape)

    pairs = []
    for n in range(n_players):
        if alloc_[n].max() == 1:
            a, b = n, alloc_[n].argmax()
            pairs.append([(a, ix[a]), (b, ix[b])])

    return alloc, pairs

# %% [markdown]
# ## Draw Printing Methods

# %%
def print_standings(standings, id_to_name):
    """
    Print standings for the round in table form
    """
    table = []
    for rank, player in enumerate(standings):
        table.append([int(player[0]), id_to_name[player[0]], player[1], rank+1])
    print('\n', tabulate(table, headers=['ID', 'Name', 'Wins', 'Rank']), '\n')
    

def print_pairings(pairs, id_to_name, scores):
    """
    Print pairings for the round in table form
    """
    table = []
    for table_num, pair in enumerate(pairs):
        b, a = pair[0], pair[1]
        score = scores[b[0], a[0]]
        row = [table_num+1, id_to_name[a[1]], int(a[1]), int(a[0])+1, id_to_name[b[1]], int(b[1]), int(b[0])+1, score]
        table.append(row)
    headers = ['Table #', 'Player 1 - Name', 'ID', 'Rank', 'Player 2 - Name', 'ID', 'Rank', 'GOF']
    print('\n', tabulate(table, headers=headers), '\n')

# %% [markdown]
# ## Run a sample Tournament
# Create a list of players then run through a multi-round tournament and print the results
# Each round prints:
# - Goodness of fit score: Score for the pairings allocated in the round. The maximum possible score is 4. If a number < 0 comes out, something has probably gone wrong
# - Standings: A table of standings of the players (based only on # of wins, no accounting for draws, op wins etc)
# - Pairings: A table of pairings for the following round (including player name and standing so you can check if players are being paired with others nearby)
#
# To show all the standings and pairings at once, make sure to select the cell, click on the "Cell" menu, select -> "Current Outputs" and then select "Toggle Scrolling"
#
# The entire history of "standings", "splits", "scores", "allocations", and "pairs" is recorded in the lists *standings_h, splits_h, scores_h, alloc_h, pairs_h*
#
# Note: Early stage demo only. This does not support:
# - Odd numbers of players and byes
# - Allocating pods
# - Iterative sampling methods to improve draw quality
# - etc

# %%
NUMBER_OF_PLAYERS = 26
NUMBER_OF_ROUNDS  = 6
PROBABILITY_OF_DRAW = 0.0001

# %%
# Create players
players, id_to_name, id_to_rank = init_players(NUMBER_OF_PLAYERS)
pairings = init_pairings(players)

#players

# %%
results = []
standings_h, splits_h, scores_h, alloc_h, pairs_h = [], [], [], [], []

for rnd in range(NUMBER_OF_ROUNDS):
    standings, splits, scores, alloc, pairs = create_draw(players, results)
    for collection, value in zip([standings_h, splits_h, scores_h, alloc_h, pairs_h],
                                 [standings,   splits,   scores,   alloc,   pairs]):
        collection.append(value)
    print('----- Round', rnd + 1, '-----', )
    print('Goodness of Fit:', (scores * alloc).sum() / NUMBER_OF_PLAYERS)
    print_standings(standings, id_to_name, )
    print_pairings(pairs, id_to_name, scores)
    result = run_round(pairs, p_draw=PROBABILITY_OF_DRAW)
    results += result
# Out:
# ----- Round 1 -----
# Goodness of Fit: 4.0
#
#       ID  Name                       Wins    Rank
# -------  -----------------------  ------  ------
# 6647878  Jennifer Hayes                0       1
# 2374253  Dawn Martin                   0       2
# 3317725  Caleb Reyes                   0       3
# 1698462  Rebecca Hamilton              0       4
# 1240654  Timothy Hess                  0       5
# 4062633  Sandra Yang                   0       6
# 2708757  April Lee                     0       7
# 3850883  Mr. Peter Richardson II       0       8
# 6724236  Christopher Scott             0       9
# 1381997  Kristen Garrison              0      10
# 4495722  Michael Lee                   0      11
# 6009545  Jeffrey Wright                0      12
# 3984681  Danielle Navarro              0      13
# 4311220  Pamela Lowe                   0      14
# 2591711  Denise Ward                   0      15
# 3643808  William Powers                0      16
# 4249005  Bryan Walsh                   0      17
# 5585646  Jesus Mcdonald                0      18
# 4091424  Dr. Brandy Aguirre            0      19
# 4577606  Pamela Sanders                0      20
# 7086981  Sharon Potts                  0      21
# 9465238  Sheri Crosby MD               0      22
# 5287743  Jeffrey Patterson             0      23
# 6819520  Desiree Doyle                 0      24
# 1352771  Courtney Garcia               0      25
# 7074818  Nicole Williams               0      26
#
#
#    Table #  Player 1 - Name               ID    Rank  Player 2 - Name          ID    Rank    GOF
# ---------  -----------------------  -------  ------  ------------------  -------  ------  -----
#         1  Sandra Yang              4062633       6  Kristen Garrison    1381997      10      4
#         2  Jennifer Hayes           6647878       1  Danielle Navarro    3984681      13      4
#         3  Mr. Peter Richardson II  3850883       8  Pamela Lowe         4311220      14      4
#         4  Dawn Martin              2374253       2  William Powers      3643808      16      4
#         5  Timothy Hess             1240654       5  Bryan Walsh         4249005      17      4
#         6  Caleb Reyes              3317725       3  Jesus Mcdonald      5585646      18      4
#         7  Christopher Scott        6724236       9  Dr. Brandy Aguirre  4091424      19      4
#         8  April Lee                2708757       7  Pamela Sanders      4577606      20      4
#         9  Denise Ward              2591711      15  Sharon Potts        7086981      21      4
#        10  Jeffrey Wright           6009545      12  Sheri Crosby MD     9465238      22      4
#        11  Michael Lee              4495722      11  Desiree Doyle       6819520      24      4
#        12  Rebecca Hamilton         1698462       4  Courtney Garcia     1352771      25      4
#        13  Jeffrey Patterson        5287743      23  Nicole Williams     7074818      26      4
#
# ----- Round 2 -----
# Goodness of Fit: 3.769230769230769
#
#       ID  Name                       Wins    Rank
# -------  -----------------------  ------  ------
# 1381997  Kristen Garrison              1       1
# 3984681  Danielle Navarro              1       2
# 4311220  Pamela Lowe                   1       3
# 3643808  William Powers                1       4
# 1240654  Timothy Hess                  1       5
# 5585646  Jesus Mcdonald                1       6
# 4091424  Dr. Brandy Aguirre            1       7
# 4577606  Pamela Sanders                1       8
# 2591711  Denise Ward                   1       9
# 9465238  Sheri Crosby MD               1      10
# 6819520  Desiree Doyle                 1      11
# 1352771  Courtney Garcia               1      12
# 7074818  Nicole Williams               1      13
# 4062633  Sandra Yang                   0      14
# 6647878  Jennifer Hayes                0      15
# 3850883  Mr. Peter Richardson II       0      16
# 2374253  Dawn Martin                   0      17
# 4249005  Bryan Walsh                   0      18
# 3317725  Caleb Reyes                   0      19
# 6724236  Christopher Scott             0      20
# 2708757  April Lee                     0      21
# 7086981  Sharon Potts                  0      22
# 6009545  Jeffrey Wright                0      23
# 4495722  Michael Lee                   0      24
# 1698462  Rebecca Hamilton              0      25
# 5287743  Jeffrey Patterson             0      26
#
#
#    Table #  Player 1 - Name          ID    Rank  Player 2 - Name               ID    Rank    GOF
# ---------  ------------------  -------  ------  -----------------------  -------  ------  -----
#         1  Pamela Lowe         4311220       3  Jesus Mcdonald           5585646       6      4
#         2  William Powers      3643808       4  Denise Ward              2591711       9      4
#         3  Danielle Navarro    3984681       2  Sheri Crosby MD          9465238      10      4
#         4  Pamela Sanders      4577606       8  Desiree Doyle            6819520      11      4
#         5  Timothy Hess        1240654       5  Courtney Garcia          1352771      12      4
#         6  Dr. Brandy Aguirre  4091424       7  Nicole Williams          7074818      13      4
#         7  Kristen Garrison    1381997       1  Mr. Peter Richardson II  3850883      16      1
#         8  Dawn Martin         2374253      17  Bryan Walsh              4249005      18      4
#         9  Jennifer Hayes      6647878      15  Caleb Reyes              3317725      19      4
#        10  Christopher Scott   6724236      20  Sharon Potts             7086981      22      4
#        11  April Lee           2708757      21  Michael Lee              4495722      24      4
#        12  Jeffrey Wright      6009545      23  Rebecca Hamilton         1698462      25      4
#        13  Sandra Yang         4062633      14  Jeffrey Patterson        5287743      26      4
#
# ----- Round 3 -----
# Goodness of Fit: 4.0
#
#       ID  Name                       Wins    Rank
# -------  -----------------------  ------  ------
# 3643808  William Powers                2       1
# 5585646  Jesus Mcdonald                2       2
# 4577606  Pamela Sanders                2       3
# 9465238  Sheri Crosby MD               2       4
# 1352771  Courtney Garcia               2       5
# 7074818  Nicole Williams               2       6
# 1381997  Kristen Garrison              1       7
# 3984681  Danielle Navarro              1       8
# 4311220  Pamela Lowe                   1       9
# 3850883  Mr. Peter Richardson II       1      10
# 4249005  Bryan Walsh                   1      11
# 1240654  Timothy Hess                  1      12
# 3317725  Caleb Reyes                   1      13
# 4091424  Dr. Brandy Aguirre            1      14
# 6724236  Christopher Scott             1      15
# 2708757  April Lee                     1      16
# 2591711  Denise Ward                   1      17
# 6009545  Jeffrey Wright                1      18
# 6819520  Desiree Doyle                 1      19
# 5287743  Jeffrey Patterson             1      20
# 4062633  Sandra Yang                   0      21
# 6647878  Jennifer Hayes                0      22
# 2374253  Dawn Martin                   0      23
# 7086981  Sharon Potts                  0      24
# 4495722  Michael Lee                   0      25
# 1698462  Rebecca Hamilton              0      26
#
#
#    Table #  Player 1 - Name               ID    Rank  Player 2 - Name          ID    Rank    GOF
# ---------  -----------------------  -------  ------  ------------------  -------  ------  -----
#         1  William Powers           3643808       1  Pamela Sanders      4577606       3      4
#         2  Jesus Mcdonald           5585646       2  Sheri Crosby MD     9465238       4      4
#         3  Courtney Garcia          1352771       5  Nicole Williams     7074818       6      4
#         4  Bryan Walsh              4249005      11  Caleb Reyes         3317725      13      4
#         5  Timothy Hess             1240654      12  Dr. Brandy Aguirre  4091424      14      4
#         6  Pamela Lowe              4311220       9  Christopher Scott   6724236      15      4
#         7  Kristen Garrison         1381997       7  April Lee           2708757      16      4
#         8  Mr. Peter Richardson II  3850883      10  Denise Ward         2591711      17      4
#         9  Danielle Navarro         3984681       8  Desiree Doyle       6819520      19      4
#        10  Jeffrey Wright           6009545      18  Jeffrey Patterson   5287743      20      4
#        11  Jennifer Hayes           6647878      22  Sharon Potts        7086981      24      4
#        12  Dawn Martin              2374253      23  Michael Lee         4495722      25      4
#        13  Sandra Yang              4062633      21  Rebecca Hamilton    1698462      26      4
#
# ----- Round 4 -----
# Goodness of Fit: 3.3076923076923075
#
#       ID  Name                       Wins    Rank
# -------  -----------------------  ------  ------
# 4577606  Pamela Sanders                3       1
# 9465238  Sheri Crosby MD               3       2
# 7074818  Nicole Williams               3       3
# 1381997  Kristen Garrison              2       4
# 3643808  William Powers                2       5
# 5585646  Jesus Mcdonald                2       6
# 3317725  Caleb Reyes                   2       7
# 4091424  Dr. Brandy Aguirre            2       8
# 6724236  Christopher Scott             2       9
# 2591711  Denise Ward                   2      10
# 6819520  Desiree Doyle                 2      11
# 1352771  Courtney Garcia               2      12
# 5287743  Jeffrey Patterson             2      13
# 3984681  Danielle Navarro              1      14
# 6647878  Jennifer Hayes                1      15
# 4311220  Pamela Lowe                   1      16
# 3850883  Mr. Peter Richardson II       1      17
# 4249005  Bryan Walsh                   1      18
# 1240654  Timothy Hess                  1      19
# 2708757  April Lee                     1      20
# 6009545  Jeffrey Wright                1      21
# 4495722  Michael Lee                   1      22
# 1698462  Rebecca Hamilton              1      23
# 4062633  Sandra Yang                   0      24
# 2374253  Dawn Martin                   0      25
# 7086981  Sharon Potts                  0      26
#
#
#    Table #  Player 1 - Name          ID    Rank  Player 2 - Name               ID    Rank    GOF
# ---------  ------------------  -------  ------  -----------------------  -------  ------  -----
#         1  Pamela Sanders      4577606       1  Nicole Williams          7074818       3      4
#         2  Sheri Crosby MD     9465238       2  Kristen Garrison         1381997       4      1
#         3  William Powers      3643808       5  Christopher Scott        6724236       9      4
#         4  Jesus Mcdonald      5585646       6  Denise Ward              2591711      10      4
#         5  Dr. Brandy Aguirre  4091424       8  Courtney Garcia          1352771      12      4
#         6  Caleb Reyes         3317725       7  Jeffrey Patterson        5287743      13      4
#         7  Desiree Doyle       6819520      11  Mr. Peter Richardson II  3850883      17      1
#         8  Pamela Lowe         4311220      16  Bryan Walsh              4249005      18      4
#         9  Jennifer Hayes      6647878      15  Timothy Hess             1240654      19      4
#        10  April Lee           2708757      20  Jeffrey Wright           6009545      21      4
#        11  Michael Lee         4495722      22  Rebecca Hamilton         1698462      23      4
#        12  Danielle Navarro    3984681      14  Dawn Martin              2374253      25      1
#        13  Sandra Yang         4062633      24  Sharon Potts             7086981      26      4
#
# ----- Round 5 -----
# Goodness of Fit: 3.5384615384615383
#
#       ID  Name                       Wins    Rank
# -------  -----------------------  ------  ------
# 9465238  Sheri Crosby MD               4       1
# 7074818  Nicole Williams               4       2
# 5585646  Jesus Mcdonald                3       3
# 4091424  Dr. Brandy Aguirre            3       4
# 6724236  Christopher Scott             3       5
# 4577606  Pamela Sanders                3       6
# 6819520  Desiree Doyle                 3       7
# 5287743  Jeffrey Patterson             3       8
# 1381997  Kristen Garrison              2       9
# 3643808  William Powers                2      10
# 4249005  Bryan Walsh                   2      11
# 1240654  Timothy Hess                  2      12
# 3317725  Caleb Reyes                   2      13
# 2708757  April Lee                     2      14
# 2591711  Denise Ward                   2      15
# 1352771  Courtney Garcia               2      16
# 1698462  Rebecca Hamilton              2      17
# 4062633  Sandra Yang                   1      18
# 3984681  Danielle Navarro              1      19
# 6647878  Jennifer Hayes                1      20
# 4311220  Pamela Lowe                   1      21
# 3850883  Mr. Peter Richardson II       1      22
# 2374253  Dawn Martin                   1      23
# 6009545  Jeffrey Wright                1      24
# 4495722  Michael Lee                   1      25
# 7086981  Sharon Potts                  0      26
#
#
#    Table #  Player 1 - Name               ID    Rank  Player 2 - Name         ID    Rank    GOF
# ---------  -----------------------  -------  ------  -----------------  -------  ------  -----
#         1  Sheri Crosby MD          9465238       1  Nicole Williams    7074818       2      4
#         2  Christopher Scott        6724236       5  Pamela Sanders     4577606       6      4
#         3  Jesus Mcdonald           5585646       3  Desiree Doyle      6819520       7      4
#         4  Dr. Brandy Aguirre       4091424       4  Jeffrey Patterson  5287743       8      4
#         5  Kristen Garrison         1381997       9  Timothy Hess       1240654      12      4
#         6  William Powers           3643808      10  Caleb Reyes        3317725      13      4
#         7  April Lee                2708757      14  Denise Ward        2591711      15      4
#         8  Bryan Walsh              4249005      11  Rebecca Hamilton   1698462      17      4
#         9  Sandra Yang              4062633      18  Jennifer Hayes     6647878      20      4
#        10  Danielle Navarro         3984681      19  Pamela Lowe        4311220      21      4
#        11  Mr. Peter Richardson II  3850883      22  Dawn Martin        2374253      23      4
#        12  Courtney Garcia          1352771      16  Michael Lee        4495722      25      1
#        13  Jeffrey Wright           6009545      24  Sharon Potts       7086981      26      1
#
# ----- Round 6 -----
# Goodness of Fit: 3.3076923076923075
#
#       ID  Name                       Wins    Rank
# -------  -----------------------  ------  ------
# 7074818  Nicole Williams               5       1
# 5585646  Jesus Mcdonald                4       2
# 6724236  Christopher Scott             4       3
# 9465238  Sheri Crosby MD               4       4
# 5287743  Jeffrey Patterson             4       5
# 1240654  Timothy Hess                  3       6
# 3317725  Caleb Reyes                   3       7
# 4091424  Dr. Brandy Aguirre            3       8
# 4577606  Pamela Sanders                3       9
# 2708757  April Lee                     3      10
# 6819520  Desiree Doyle                 3      11
# 1352771  Courtney Garcia               3      12
# 1698462  Rebecca Hamilton              3      13
# 1381997  Kristen Garrison              2      14
# 6647878  Jennifer Hayes                2      15
# 4311220  Pamela Lowe                   2      16
# 3850883  Mr. Peter Richardson II       2      17
# 3643808  William Powers                2      18
# 4249005  Bryan Walsh                   2      19
# 2591711  Denise Ward                   2      20
# 4062633  Sandra Yang                   1      21
# 3984681  Danielle Navarro              1      22
# 2374253  Dawn Martin                   1      23
# 7086981  Sharon Potts                  1      24
# 6009545  Jeffrey Wright                1      25
# 4495722  Michael Lee                   1      26
#
#
#    Table #  Player 1 - Name               ID    Rank  Player 2 - Name         ID    Rank    GOF
# ---------  -----------------------  -------  ------  -----------------  -------  ------  -----
#         1  Nicole Williams          7074818       1  Jesus Mcdonald     5585646       2      1
#         2  Christopher Scott        6724236       3  Jeffrey Patterson  5287743       5      4
#         3  Caleb Reyes              3317725       7  Pamela Sanders     4577606       9      4
#         4  Sheri Crosby MD          9465238       4  Desiree Doyle      6819520      11      1
#         5  April Lee                2708757      10  Courtney Garcia    1352771      12      4
#         6  Dr. Brandy Aguirre       4091424       8  Rebecca Hamilton   1698462      13      4
#         7  Jennifer Hayes           6647878      15  Pamela Lowe        4311220      16      4
#         8  Mr. Peter Richardson II  3850883      17  William Powers     3643808      18      4
#         9  Kristen Garrison         1381997      14  Bryan Walsh        4249005      19      4
#        10  Timothy Hess             1240654       6  Denise Ward        2591711      20      1
#        11  Sandra Yang              4062633      21  Danielle Navarro   3984681      22      4
#        12  Dawn Martin              2374253      23  Sharon Potts       7086981      24      4
#        13  Jeffrey Wright           6009545      25  Michael Lee        4495722      26      4
