# %%
import numpy as np
from queue import PriorityQueue as queue
from collections import defaultdict
from faker import Faker
from tabulate import tabulate
from collections import deque, Counter

fake = Faker()

# %% [markdown]
# ## Draw Simulation Methods

# %%
def init_players(num_players):
    """
    Create a collection of players in the form [player_id, player_name, player_ranking]
    Arguments:
        num_players: Number of players to add to the draw
    Returns:
        players: Array of player details
            (n x 3) list containing [player_id, player_name, player_ranking]
    """
    players = []
    id_to_name, id_to_rank = defaultdict(lambda: 'Bye'), defaultdict(lambda: 1600)
    for n in range(num_players):
        p_id, p_name, p_rank = np.random.randint(1000000, 9999999), fake.name(), np.random.randint(1600, 2000)
        players.append([p_id, p_name, p_rank])
        id_to_name[p_id] = p_name
        id_to_rank[p_id] = p_rank
    return players, id_to_name, id_to_rank

# %%
def init_pairings(players):
    """
    Randomly create results for the first round
    Arguments:
        players: (n x 3) numpy array containing [player_id, player_name, player_ranking]
    Returns:
        results: Randomly generated results table
            (n x 3) list containing [player_a_id, player_b_id, match_winner_id]
    """
    results = []
    for n in range(0, len(players), 2):
        a, b = players[n][0], players[n+1][0]
        result = [a, b, np.random.choice([a, b, None], 1, p=(0.45, 0.45, 0.1))[0]]
        results.append(result)
    return results

# %%
def run_round(pairings, rnd, p_draw=0):
    """
    Randomly create results for a round
    Arguments:
        pairings: List of pairings for the round to be simulated
            (n x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    Returns:
        results: Randomly generated results table
            (n x 3) list containing [player_a_id, player_b_id, match_winner_id]
    """
    results = []
    p_win = (1 - p_draw) / 2
    BYE = 0
    for pairing in pairings:
        a, b, pod = pairing[0][1], pairing[1][1], pairing[2]
        if a <= BYE:
            result = [a,b,b]
        elif b <= BYE:
            result = [a,b,a]
        else:
            result = [a, b, np.random.choice([a, b, None], 1, p=(p_win, p_win, p_draw))[0]]
        results.append(result + [rnd, pod])
        
    return results

# %% [markdown]
# ## Draw Calculation Methods

# %%
def create_draw(players, results, rounds):
    """
    Create draw for the round
    Arguments:
        players: Array of player details
            (n x 3) list containing [player_id, player_name, player_ranking]
        results: List of pairings and results for all rounds to date
            (m x 2) list containing [player_a_id, player_b_id, winner_id]
    Returns:
        standings: List of standings for all players still in the tournament
            (n x 2) list containing [player_id, player_wins]
        splits: List of index points where each points bracket finishes
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
        alloc: The matrix form pairing allocations
            (n x n) matrix of integers
        pairings: The list form of pairing allocations
            (n / 2 x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    """
    n_players = len(players)
    
    standings       = get_standings(players, results, rounds)
    scores, splits  = get_scores(standings, results)
    alloc, pairings = get_allocations(standings, scores)
    
    return standings, splits, scores, alloc, pairings

# %%
def get_standings(players, results, rounds):
    """
    Calculate player standings at start of round
    Arguments:
        results: List of pairings and results for all rounds to date
            (m x 2) list containing [player_a_id, player_b_id, winner_id]
    Returns:
        standings: List of standings for all players still in the tournament
            (n x 3) list containing [player_id, player_wins, player_pod]
    """
    standings, rankings, pods = defaultdict(int), defaultdict(int), defaultdict(lambda: 1)
    active_players  = set([player[0] for player in players])
    this_round = 0 if len(results) == 0 else np.array(results)[:,3].max() + 1
    last_round = this_round - 1
    
    # Use all rounds for ranking if 'swiss', or just pod results if 'pod'
    if rounds[this_round] == 'swiss':
        ranked_rounds = set(range(this_round))
    else:
        ranked_rounds = set([n for n, rnd in enumerate(rounds) if rnd == rounds[this_round]])
        
    # Calculate player standings
    if len(results) > 0:
        for a, b, winner, rnd, pod in results:
            standings[a] += (a == winner)
            standings[b] += (b == winner)
            if rnd in ranked_rounds:
                rankings[a] += (a == winner)
                rankings[b] += (b == winner)
            if rnd == last_round:
                if a in active_players: pods[a] = pod
                if b in active_players: pods[b] = pod
    
    standings = [[p, standings[p]] for p in active_players]
    standings = sorted(standings, key=lambda x: x[1], reverse=True)
    
    # Determine whether to create, reuse or ignore pods
    if rounds[this_round][:3] == 'pod':
        if this_round == 0 or rounds[this_round] != rounds[last_round]:
            method = 'create pod'
        else:
            method = 'reuse pod'
    else:
        method = 'bracket'
        
    # Allocate players to pods
    for pos, standing in enumerate(standings):
        if method == 'create pod':
            standing += [pos // 8 + 1]
        elif method == 'reuse pod':
            standing += [pods[standing[0]]]
        else:
            standing += [1]
        standing += [rankings[standing[0]]]
    
    standings = np.array(standings)
            
    # Add byes into the largest bracket in each of the pods
    pod_sizes = Counter(standings[:,2])
    byes = []
    for pod_num in range(1, len(pod_sizes) + 1):
        if pod_sizes[pod_num] % 2 == 1:
            mode_ranking  = np.bincount(standings[standings[:,2]==pod_num][:,1]).argmax()
            mode_standing = np.bincount(standings[standings[:,2]==pod_num][:,3]).argmax()
            byes.append([-pod_num, mode_ranking, pod_num, mode_standing])
    
    if len(byes) > 0:
        standings = np.vstack([standings, byes])
        standings = sorted(standings, key=lambda x: x[3], reverse=True)
        standings = sorted(standings, key=lambda x: x[2])
        standings = np.array(standings)

    return standings

# %%
def get_scores(standings, results):
    """
    Assign scores to each possible pairing
    A higher score means that the pairing is more strongly preferred
    Arguments:
        standings: List of standings for all players still in the tournament
            (n x 2) list containing [player_id, player_wins]
        pairs: List of pairings for all rounds to date
            (m x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    Returns:
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
        splits: List of index points where each points bracket finishes
    """
    n_players = len(standings)
    ix = {player_id: pos for pos, player_id in enumerate(standings[:,0])}
    active_players = set(ix.keys())
    splits = get_splits(standings)
    
    # Calculate scores for pairings
    scores = np.full((n_players, n_players), -100)
    
    split_1, split_2 = 0, 0
    for split in splits + [n_players]:
        # Assign points for players in same bracket
        scores[split_1:split, split_1:split] = 16
        # Assign points for pull-up bracket
        if split_1 %2 == 1:
            scores[split_2:split_1, split_1:split] = 1
            scores[split_1:split, split_2:split_1] = 1
        split_1, split_2 = split, split_1
    
    # Reset self vs self to -inf
    np.fill_diagonal(scores, -100)

    # Subtract points for prior matchup
    BYE = 0
    for result in results:
        if result[0] in active_players and result[1] in active_players:
            a, b = ix[result[0]], ix[result[1]]
            penalty = 32 if min(result) < BYE else 4
            scores[a,b] -= penalty
            scores[b,a] -= penalty
        
    return scores, splits

# %%
def swap_pairs(pair_1, pair_2, alloc):
    """
    Helper function to swap players between two pairings
    Original pairing of (a,b) and (c,d) becomes (a,c) and (b,d)
    Arguments:
        pair_1: Tuple containing first pair to swap (a,b)
        pair_2: Tuple containing first pair to swap (c,d)
        alloc: The matrix form pairing allocations
            (n x n) matrix of integers
    Returns:
        alloc: The matrix form pairing allocations with [(a,b), (c,d)] -> [(a,c), (b,d)]
            (n x n) matrix of integers        
    """
    a, b = pair_1
    c, d = pair_2

    alloc[a, b] = 0
    alloc[b, a] = 0
    alloc[c, d] = 0
    alloc[d, c] = 0
    alloc[a, c] = 1
    alloc[c, a] = 1
    alloc[b, d] = 1
    alloc[d, b] = 1
    
    return alloc

# %%
def get_splits(standings):
    """
    Helper method to find the points at which the brackets split
    Arguments:
        standings: List of standings for all players still in the tournament
            (n x 3) list containing [player_id, player_wins, bracket]
    """
    n_players = len(standings)
    
    # Sort standings by bracket and player wins
    standings = sorted(standings, key=lambda x: x[3], reverse=True)
    standings = sorted(standings, key=lambda x: x[2])
    standings = np.array(standings)
    
    # Calculate splits
    splits = [n for n in range(n_players) if (standings[n,[3,2]] != standings[n-1,[3,2]]).any()] + [n_players]

    return splits

# %%
def get_allocations(standings, scores):
    """
    Split table down into even length brackets and sub-allocate
    Arguments:
        standings: List of standings for all players still in the tournament
            (n x 2) list containing [player_id, player_wins]
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
    Returns:
        alloc: The matrix form pairing allocations
            (n x n) matrix of integers
        pairs: The list form of pairing allocations
            (n / 2 x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    """
    n_players = len(standings)
    splits = get_splits(standings)

    # Allocate entire table if there is no split
    if len(splits) == 1:
        return _get_allocations(standings, scores)

    allocs = np.zeros((n_players, n_players))
    pairs = []

    # Split into sub-tables at even numbered index split points
    ixs = np.array(splits)
    ixs = ixs[ixs % 2 == 0]
    for ix1, ix2 in zip(ixs[:-1], ixs[1:]):
        alloc, pair = _get_allocations(standings[ix1:ix2], scores[ix1:ix2,ix1:ix2], start=ix1)

        allocs[ix1:ix2,ix1:ix2] = alloc
        pairs += pair

    return allocs, pairs

def _get_allocations(standings, scores, start=0):
    """
    Allocate player pairings
    Arguments:
        standings: List of standings for all players still in the tournament
            (n x 2) list containing [player_id, player_wins]
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
    Returns:
        alloc: The matrix form pairing allocations
            (n x n) matrix of integers
        pairs: The list form of pairing allocations
            (n / 2 x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    """
    n_players = len(standings)
    ix = {pos+start: player_id for pos, player_id in enumerate(standings[:,0])}
    alloc = np.zeros((n_players, n_players), dtype=int)
    splits = get_splits(standings)
    pods = {player[0]: player[2] for player in standings}

    # Construct initial draw
    for _ in range(int(n_players / 2)):
        mask = (1 - alloc.sum(axis=1))
        # Choose Player A
        p = scores.max() - scores.mean(axis=1)
        p = p * mask
        a = p.argmax()
        # Choose Player B
        p = np.exp(scores[a])
        p = np.maximum(p * mask, 0)
        b = np.random.choice(range(n_players),p=p/p.sum())
        
        alloc[a, b] = 1
        alloc[b, a] = 1

    score_q = [(alloc*scores).sum()/len(scores)]
    max_score = 16 - 15 * (np.array(splits) % 2).sum() * 2 / len(scores)
    
    # Run Metropolis-Hastings to iteratively improve draw
    if score_q[0] != max_score:
        prob = np.exp(scores)
        prob /= prob.sum(axis=1, keepdims=True)

        best_alloc = alloc.copy()
        while len(score_q) < 10 or np.mean(score_q[-5:]) > np.mean(score_q[-10:-5]):        
            if max(score_q) == max_score:
                break
            for a, p in enumerate(prob):
                b = alloc[a].argmax()
                c = np.random.choice(range(len(p)),p=p)
                d = alloc[c].argmax()
                p_change = prob[a,c]*prob[b,d]/(prob[a,b]*prob[c,d] + prob[a,c]*prob[b,d])
                if np.random.random() < p_change:
                    alloc = swap_pairs((a,b), (c,d), alloc)

            score = (alloc*scores).sum()/len(prob)
            if score > max(score_q):
                best_alloc = alloc.copy()
            score_q.append(score)

        alloc = best_alloc
        del(best_alloc)
    
    # Create list form of pairings
    alloc_ = alloc * np.tri(*alloc.shape)

    pairs = []
    for n in range(n_players):
        if alloc_[n].max() == 1:
            a, b = n + start, alloc_[n].argmax() + start
            pairs.append([(a, ix[a]), (b, ix[b]), pods[ix[a]]])
            
    return alloc, pairs

# %% [markdown]
# ## Draw Printing Methods

# %%
def print_standings(standings, id_to_name):
    """
    Print standings for the round in table form
    """
    table = []
    for rank, player in enumerate(standings):
        table.append([int(player[0]), id_to_name[player[0]], player[1], player[2], player[3]])
    print('\n', tabulate(table, headers=['ID', 'Name', 'Wins', 'Pod', 'Pod Rank']), '\n')
    

def print_pairings(pairs, id_to_name, scores):
    """
    Print pairings for the round in table form
    """
    table = []
    for table_num, pair in enumerate(pairs):
        b, a, pod = pair[0], pair[1], pair[2]
        score = scores[b[0], a[0]]
        row = [table_num+1, pod, id_to_name[a[1]], int(a[1]), int(a[0])+1, id_to_name[b[1]], int(b[1]), int(b[0])+1, score]
        table.append(row)
    headers = ['Table', 'Pod', 'Player 1 - Name', 'ID', 'Rank', 'Player 2 - Name', 'ID', 'Rank', 'GOF']
    print('\n', tabulate(table, headers=headers), '\n')

def print_byes(pairs):
    byes = []
    for pairs in pairs_h:
        for pair in pairs:
            a, b = pair[0][1], pair[1][1]
            if min(a, b) < 0:
                byes += [max(a, -1), max(b, -1)]
    byes = Counter(np.reshape(byes, -1))

    print('----- BYES -----')
    for k, v in byes.items():
        if k < 0:
            print('Byes', ': ', v)
        else:
            print(k, ': ', v)

# %% [markdown]
# ## Run a sample Tournament
# Create a list of players then run through a multi-round tournament and print the results
# Each round prints:
# - Goodness of fit score: Score for the pairings allocated in the round. The maximum possible score is 4. If a number < 0 comes out, something has probably gone wrong
# - Standings: A table of standings of the players (based only on # of wins, no accounting for draws, op wins etc)
# - Pairings: A table of pairings for the following round (including player name and standing so you can check if players are being paired with others nearby)
#
# To show all the standings and pairings at once, make sure to select the cell, click on the "Cell" menu, select -> "Current Outputs" and then select "Toggle Scrolling"
#
# The entire history of "standings", "splits", "scores", "allocations", and "pairs" is recorded in the lists *standings_h, splits_h, scores_h, alloc_h, pairs_h*
#
# Note: Early stage demo only. This does not support:
# - Odd numbers of players and byes [Done]
# - Allocating pods [Done]
# - Iterative sampling methods to improve draw quality [Done]
# - Balancing tail end pod sizes
# - Variable size pods
# - etc

# %%
NUMBER_OF_PLAYERS = 63
ROUNDS  = ['swiss', 'swiss', 'swiss',
           'pod1', 'pod1', 'pod1',
           'pod2', 'pod2', 'pod2']
NUMBER_OF_ROUNDS = len(ROUNDS)
PROBABILITY_OF_DRAW = 0.0001

# %%
# Create players
players, id_to_name, id_to_rank = init_players(NUMBER_OF_PLAYERS)

# %%
results = []
standings_h, splits_h, scores_h, alloc_h, pairs_h = [], [], [], [], []
number_of_players = NUMBER_OF_PLAYERS + NUMBER_OF_PLAYERS % 2

for rnd in range(NUMBER_OF_ROUNDS):
    standings, splits, scores, alloc, pairs = create_draw(players, results, ROUNDS)
    for collection, value in zip([standings_h, splits_h, scores_h, alloc_h, pairs_h],
                                 [standings,   splits,   scores,   alloc,   pairs]):
        collection.append(value)
    print('----- Round', rnd + 1, '-----', )
    print('Goodness of Fit:', (scores * alloc).sum() / number_of_players)
    print('Maximum GOF:', 16 - 15 * (np.array(splits) % 2).sum() * 2 / number_of_players)
    print("Frequencies: " + ', '.join([str(int(k)) + "pts: " + str(int(v / 2)) 
                                 for k, v in Counter((scores * alloc).reshape(-1)).items() if k != 0]) )
    print_standings(standings, id_to_name, )
    print_pairings(pairs, id_to_name, scores)
    result = run_round(pairs, rnd, p_draw=PROBABILITY_OF_DRAW)
    results += result

print('Overall Pairing Score Frequency: ', ', '.join([str(int(k)) + "pts: " + str(int(v / 2))
   for k, v in Counter((np.array(scores_h)*np.array(alloc_h))[-NUMBER_OF_ROUNDS:].reshape(-1)).items() if k != 0]))
print_byes(pairs_h)
# Out:
# ----- Round 1 -----
# Goodness of Fit: 16.0
# Maximum GOF: 16.0
# Frequencies: 16pts: 32
#
#       ID  Name                    Wins    Pod    Pod Rank
# -------  --------------------  ------  -----  ----------
# 7985280  Grant Clark                0      1           0
# 2962691  Mark Crane                 0      1           0
# 7934341  Alicia Moore               0      1           0
# 8953992  Kimberly Stewart           0      1           0
# 2994698  Daniel Lewis               0      1           0
# 6118794  James White                0      1           0
# 1482256  Linda Gonzales             0      1           0
# 7278224  Anthony Murillo            0      1           0
# 7957778  Wayne Garcia               0      1           0
# 6179987  Zachary Hughes             0      1           0
# 9577620  Patricia Davis             0      1           0
# 1588501  Denise Hernandez           0      1           0
# 8054419  Kelly Graham               0      1           0
# 1106070  David Smith                0      1           0
# 6551961  Catherine Knox             0      1           0
# 6096921  Debbie Woods               0      1           0
# 8980761  Aaron Johnson              0      1           0
# 3825948  Colleen Bartlett           0      1           0
# 7094940  Amanda Franklin            0      1           0
# 9248926  Jacqueline Mcknight        0      1           0
# 3153945  Debra Calhoun              0      1           0
# 6433181  Valerie Gallegos           0      1           0
# 3876005  Melissa Cardenas           0      1           0
# 1276839  Matthew West               0      1           0
# 1451175  Carlos Luna                0      1           0
# 9020464  Amy Howard                 0      1           0
# 4179639  Shannon Aguilar            0      1           0
# 7335098  Dennis Carter              0      1           0
# 6172479  Tracey Richardson          0      1           0
# 5813185  Jennifer Giles             0      1           0
# 3625027  Brandon Robles             0      1           0
# 7840580  Lindsay Harris             0      1           0
# 3985861  Mark Kim                   0      1           0
# 8696131  Courtney Salinas           0      1           0
# 9353287  Megan Aguilar              0      1           0
# 5865079  John Beard                 0      1           0
# 2138695  Erika Carr                 0      1           0
# 8474571  Susan Mcbride              0      1           0
# 1887311  Joshua Hampton Jr.         0      1           0
# 8550868  Mr. Robert Moore DVM       0      1           0
# 8986072  Travis Matthews            0      1           0
# 8788188  Donald Garcia              0      1           0
# 5850845  Victor Clark               0      1           0
# 9458784  Tina Moran                 0      1           0
# 9103585  Jacob Carson               0      1           0
# 1284066  Cynthia Moran              0      1           0
# 6192229  Richard Torres             0      1           0
# 4382055  Derek Braun                0      1           0
# 5112040  Jordan Rivera              0      1           0
# 3056874  Hannah Bush                0      1           0
# 4518507  Mary Barry                 0      1           0
# 9835244  Kyle Lucas                 0      1           0
# 5252460  Sergio Harrison            0      1           0
# 6057454  Jason Stevens              0      1           0
# 7245807  Priscilla Peterson         0      1           0
# 6894705  Jason Jacobs               0      1           0
# 3407474  Amanda Berger              0      1           0
# 8333043  Maria Pollard              0      1           0
# 7952630  Stephanie Foley            0      1           0
# 7543030  John Martin                0      1           0
# 3428214  Samuel Robinson            0      1           0
# 2486908  Derek Chambers             0      1           0
# 6929021  Nicholas Olson DVM         0      1           0
#      -1  Bye                        0      1           0
#
#
#    Table    Pod  Player 1 - Name            ID    Rank  Player 2 - Name          ID    Rank    GOF
# -------  -----  --------------------  -------  ------  ------------------  -------  ------  -----
#       1      1  Mark Crane            2962691       2  Kimberly Stewart    8953992       4     16
#       2      1  Daniel Lewis          2994698       5  Melissa Cardenas    3876005      23     16
#       3      1  Catherine Knox        6551961      15  Amy Howard          9020464      26     16
#       4      1  Colleen Bartlett      3825948      18  Tracey Richardson   6172479      29     16
#       5      1  Wayne Garcia          7957778       9  Jennifer Giles      5813185      30     16
#       6      1  Kelly Graham          8054419      13  Brandon Robles      3625027      31     16
#       7      1  David Smith           1106070      14  Mark Kim            3985861      33     16
#       8      1  Amanda Franklin       7094940      19  Megan Aguilar       9353287      35     16
#       9      1  Grant Clark           7985280       1  John Beard          5865079      36     16
#      10      1  Zachary Hughes        6179987      10  Susan Mcbride       8474571      38     16
#      11      1  Anthony Murillo       7278224       8  Travis Matthews     8986072      41     16
#      12      1  Linda Gonzales        1482256       7  Donald Garcia       8788188      42     16
#      13      1  Patricia Davis        9577620      11  Victor Clark        5850845      43     16
#      14      1  Dennis Carter         7335098      28  Tina Moran          9458784      44     16
#      15      1  Carlos Luna           1451175      25  Jacob Carson        9103585      45     16
#      16      1  Shannon Aguilar       4179639      27  Cynthia Moran       1284066      46     16
#      17      1  James White           6118794       6  Derek Braun         4382055      48     16
#      18      1  Denise Hernandez      1588501      12  Jordan Rivera       5112040      49     16
#      19      1  Valerie Gallegos      6433181      22  Hannah Bush         3056874      50     16
#      20      1  Matthew West          1276839      24  Mary Barry          4518507      51     16
#      21      1  Mr. Robert Moore DVM  8550868      40  Kyle Lucas          9835244      52     16
#      22      1  Courtney Salinas      8696131      34  Sergio Harrison     5252460      53     16
#      23      1  Lindsay Harris        7840580      32  Jason Stevens       6057454      54     16
#      24      1  Erika Carr            2138695      37  Priscilla Peterson  7245807      55     16
#      25      1  Debbie Woods          6096921      16  Amanda Berger       3407474      57     16
#      26      1  Debra Calhoun         3153945      21  Maria Pollard       8333043      58     16
#      27      1  Jason Jacobs          6894705      56  Stephanie Foley     7952630      59     16
#      28      1  Jacqueline Mcknight   9248926      20  John Martin         7543030      60     16
#      29      1  Aaron Johnson         8980761      17  Samuel Robinson     3428214      61     16
#      30      1  Joshua Hampton Jr.    1887311      39  Derek Chambers      2486908      62     16
#      31      1  Richard Torres        6192229      47  Nicholas Olson DVM  6929021      63     16
#      32      1  Alicia Moore          7934341       3  Bye                      -1      64     16
#
# ----- Round 2 -----
# Goodness of Fit: 15.53125
# Maximum GOF: 15.53125
# Frequencies: 16pts: 31, 1pts: 1
#
#       ID  Name                    Wins    Pod    Pod Rank
# -------  --------------------  ------  -----  ----------
# 7934341  Alicia Moore               1      1           1
# 8953992  Kimberly Stewart           1      1           1
# 6118794  James White                1      1           1
# 1482256  Linda Gonzales             1      1           1
# 7278224  Anthony Murillo            1      1           1
# 7957778  Wayne Garcia               1      1           1
# 6179987  Zachary Hughes             1      1           1
# 6551961  Catherine Knox             1      1           1
# 8980761  Aaron Johnson              1      1           1
# 3825948  Colleen Bartlett           1      1           1
# 7094940  Amanda Franklin            1      1           1
# 9248926  Jacqueline Mcknight        1      1           1
# 3153945  Debra Calhoun              1      1           1
# 3876005  Melissa Cardenas           1      1           1
# 1276839  Matthew West               1      1           1
# 1451175  Carlos Luna                1      1           1
# 7335098  Dennis Carter              1      1           1
# 3625027  Brandon Robles             1      1           1
# 3985861  Mark Kim                   1      1           1
# 5865079  John Beard                 1      1           1
# 5850845  Victor Clark               1      1           1
# 1284066  Cynthia Moran              1      1           1
# 5112040  Jordan Rivera              1      1           1
# 3056874  Hannah Bush                1      1           1
# 9835244  Kyle Lucas                 1      1           1
# 5252460  Sergio Harrison            1      1           1
# 6057454  Jason Stevens              1      1           1
# 7245807  Priscilla Peterson         1      1           1
# 3407474  Amanda Berger              1      1           1
# 7952630  Stephanie Foley            1      1           1
# 2486908  Derek Chambers             1      1           1
# 6929021  Nicholas Olson DVM         1      1           1
#      -1  Bye                        1      1           1
# 7985280  Grant Clark                0      1           0
# 2962691  Mark Crane                 0      1           0
# 2994698  Daniel Lewis               0      1           0
# 9577620  Patricia Davis             0      1           0
# 1588501  Denise Hernandez           0      1           0
# 8054419  Kelly Graham               0      1           0
# 1106070  David Smith                0      1           0
# 6096921  Debbie Woods               0      1           0
# 6433181  Valerie Gallegos           0      1           0
# 9020464  Amy Howard                 0      1           0
# 4179639  Shannon Aguilar            0      1           0
# 6172479  Tracey Richardson          0      1           0
# 5813185  Jennifer Giles             0      1           0
# 7840580  Lindsay Harris             0      1           0
# 8696131  Courtney Salinas           0      1           0
# 9353287  Megan Aguilar              0      1           0
# 2138695  Erika Carr                 0      1           0
# 8474571  Susan Mcbride              0      1           0
# 1887311  Joshua Hampton Jr.         0      1           0
# 8550868  Mr. Robert Moore DVM       0      1           0
# 8986072  Travis Matthews            0      1           0
# 8788188  Donald Garcia              0      1           0
# 9458784  Tina Moran                 0      1           0
# 9103585  Jacob Carson               0      1           0
# 6192229  Richard Torres             0      1           0
# 4382055  Derek Braun                0      1           0
# 4518507  Mary Barry                 0      1           0
# 6894705  Jason Jacobs               0      1           0
# 8333043  Maria Pollard              0      1           0
# 7543030  John Martin                0      1           0
# 3428214  Samuel Robinson            0      1           0
#
#
#    Table    Pod  Player 1 - Name          ID    Rank  Player 2 - Name            ID    Rank    GOF
# -------  -----  ------------------  -------  ------  --------------------  -------  ------  -----
#       1      1  Linda Gonzales      1482256       4  Wayne Garcia          7957778       6     16
#       2      1  Alicia Moore        7934341       1  Jacqueline Mcknight   9248926      12     16
#       3      1  Amanda Franklin     7094940      11  Dennis Carter         7335098      17     16
#       4      1  Zachary Hughes      6179987       7  Brandon Robles        3625027      18     16
#       5      1  Carlos Luna         1451175      16  John Beard            5865079      20     16
#       6      1  Victor Clark        5850845      21  Cynthia Moran         1284066      22     16
#       7      1  Anthony Murillo     7278224       5  Jordan Rivera         5112040      23     16
#       8      1  Debra Calhoun       3153945      13  Hannah Bush           3056874      24     16
#       9      1  Catherine Knox      6551961       8  Sergio Harrison       5252460      26     16
#      10      1  Melissa Cardenas    3876005      14  Jason Stevens         6057454      27     16
#      11      1  Kimberly Stewart    8953992       2  Priscilla Peterson    7245807      28     16
#      12      1  Aaron Johnson       8980761       9  Amanda Berger         3407474      29     16
#      13      1  Kyle Lucas          9835244      25  Stephanie Foley       7952630      30     16
#      14      1  Matthew West        1276839      15  Derek Chambers        2486908      31     16
#      15      1  Colleen Bartlett    3825948      10  Nicholas Olson DVM    6929021      32     16
#      16      1  Mark Kim            3985861      19  Bye                        -1      33     16
#      17      1  Grant Clark         7985280      34  Daniel Lewis          2994698      36     16
#      18      1  David Smith         1106070      40  Amy Howard            9020464      43     16
#      19      1  Kelly Graham        8054419      39  Jennifer Giles        5813185      46     16
#      20      1  Patricia Davis      9577620      37  Megan Aguilar         9353287      49     16
#      21      1  Tracey Richardson   6172479      45  Mr. Robert Moore DVM  8550868      53     16
#      22      1  Lindsay Harris      7840580      47  Travis Matthews       8986072      54     16
#      23      1  Joshua Hampton Jr.  1887311      52  Donald Garcia         8788188      55     16
#      24      1  Erika Carr          2138695      50  Tina Moran            9458784      56     16
#      25      1  Shannon Aguilar     4179639      44  Jacob Carson          9103585      57     16
#      26      1  Valerie Gallegos    6433181      42  Richard Torres        6192229      58     16
#      27      1  Denise Hernandez    1588501      38  Derek Braun           4382055      59     16
#      28      1  Mark Crane          2962691      35  Mary Barry            4518507      60     16
#      29      1  Courtney Salinas    8696131      48  Jason Jacobs          6894705      61     16
#      30      1  Debbie Woods        6096921      41  Maria Pollard         8333043      62     16
#      31      1  James White         6118794       3  John Martin           7543030      63      1
#      32      1  Susan Mcbride       8474571      51  Samuel Robinson       3428214      64     16
#
# ----- Round 3 -----
# Goodness of Fit: 15.53125
# Maximum GOF: 15.53125
# Frequencies: 16pts: 31, 1pts: 1
#
#       ID  Name                    Wins    Pod    Pod Rank
# -------  --------------------  ------  -----  ----------
# 8953992  Kimberly Stewart           2      1           2
# 6118794  James White                2      1           2
# 1482256  Linda Gonzales             2      1           2
# 7278224  Anthony Murillo            2      1           2
# 6551961  Catherine Knox             2      1           2
# 3825948  Colleen Bartlett           2      1           2
# 7094940  Amanda Franklin            2      1           2
# 9248926  Jacqueline Mcknight        2      1           2
# 3876005  Melissa Cardenas           2      1           2
# 3625027  Brandon Robles             2      1           2
# 3985861  Mark Kim                   2      1           2
# 5865079  John Beard                 2      1           2
# 5850845  Victor Clark               2      1           2
# 3056874  Hannah Bush                2      1           2
# 9835244  Kyle Lucas                 2      1           2
# 3407474  Amanda Berger              2      1           2
# 2486908  Derek Chambers             2      1           2
# 2962691  Mark Crane                 1      1           1
# 7934341  Alicia Moore               1      1           1
# 2994698  Daniel Lewis               1      1           1
# 7957778  Wayne Garcia               1      1           1
# 6179987  Zachary Hughes             1      1           1
# 1588501  Denise Hernandez           1      1           1
# 8054419  Kelly Graham               1      1           1
# 8980761  Aaron Johnson              1      1           1
# 3153945  Debra Calhoun              1      1           1
# 6433181  Valerie Gallegos           1      1           1
# 1276839  Matthew West               1      1           1
# 1451175  Carlos Luna                1      1           1
# 9020464  Amy Howard                 1      1           1
# 4179639  Shannon Aguilar            1      1           1
# 7335098  Dennis Carter              1      1           1
# 6172479  Tracey Richardson          1      1           1
# 7840580  Lindsay Harris             1      1           1
# 8696131  Courtney Salinas           1      1           1
# 9353287  Megan Aguilar              1      1           1
# 8474571  Susan Mcbride              1      1           1
# 8788188  Donald Garcia              1      1           1
# 9458784  Tina Moran                 1      1           1
# 1284066  Cynthia Moran              1      1           1
# 5112040  Jordan Rivera              1      1           1
# 5252460  Sergio Harrison            1      1           1
# 6057454  Jason Stevens              1      1           1
# 7245807  Priscilla Peterson         1      1           1
# 8333043  Maria Pollard              1      1           1
# 7952630  Stephanie Foley            1      1           1
# 6929021  Nicholas Olson DVM         1      1           1
#      -1  Bye                        1      1           1
# 7985280  Grant Clark                0      1           0
# 9577620  Patricia Davis             0      1           0
# 1106070  David Smith                0      1           0
# 6096921  Debbie Woods               0      1           0
# 5813185  Jennifer Giles             0      1           0
# 2138695  Erika Carr                 0      1           0
# 1887311  Joshua Hampton Jr.         0      1           0
# 8550868  Mr. Robert Moore DVM       0      1           0
# 8986072  Travis Matthews            0      1           0
# 9103585  Jacob Carson               0      1           0
# 6192229  Richard Torres             0      1           0
# 4382055  Derek Braun                0      1           0
# 4518507  Mary Barry                 0      1           0
# 6894705  Jason Jacobs               0      1           0
# 7543030  John Martin                0      1           0
# 3428214  Samuel Robinson            0      1           0
#
#
#    Table    Pod  Player 1 - Name           ID    Rank  Player 2 - Name            ID    Rank    GOF
# -------  -----  -------------------  -------  ------  --------------------  -------  ------  -----
#       1      1  Kimberly Stewart     8953992       1  Anthony Murillo       7278224       4     16
#       2      1  Colleen Bartlett     3825948       6  Amanda Franklin       7094940       7     16
#       3      1  Catherine Knox       6551961       5  Melissa Cardenas      3876005       9     16
#       4      1  Linda Gonzales       1482256       3  Brandon Robles        3625027      10     16
#       5      1  Jacqueline Mcknight  9248926       8  John Beard            5865079      12     16
#       6      1  James White          6118794       2  Hannah Bush           3056874      14     16
#       7      1  Mark Kim             3985861      11  Amanda Berger         3407474      16     16
#       8      1  Victor Clark         5850845      13  Derek Chambers        2486908      17     16
#       9      1  Alicia Moore         7934341      19  Zachary Hughes        6179987      22     16
#      10      1  Denise Hernandez     1588501      23  Kelly Graham          8054419      24     16
#      11      1  Aaron Johnson        8980761      25  Debra Calhoun         3153945      26     16
#      12      1  Mark Crane           2962691      18  Carlos Luna           1451175      29     16
#      13      1  Dennis Carter        7335098      32  Lindsay Harris        7840580      34     16
#      14      1  Daniel Lewis         2994698      20  Susan Mcbride         8474571      37     16
#      15      1  Amy Howard           9020464      30  Tina Moran            9458784      39     16
#      16      1  Tracey Richardson    6172479      33  Cynthia Moran         1284066      40     16
#      17      1  Donald Garcia        8788188      38  Jordan Rivera         5112040      41     16
#      18      1  Valerie Gallegos     6433181      27  Sergio Harrison       5252460      42     16
#      19      1  Shannon Aguilar      4179639      31  Jason Stevens         6057454      43     16
#      20      1  Wayne Garcia         7957778      21  Priscilla Peterson    7245807      44     16
#      21      1  Matthew West         1276839      28  Maria Pollard         8333043      45     16
#      22      1  Courtney Salinas     8696131      35  Stephanie Foley       7952630      46     16
#      23      1  Megan Aguilar        9353287      36  Nicholas Olson DVM    6929021      47     16
#      24      1  Kyle Lucas           9835244      15  Bye                        -1      48      1
#      25      1  Patricia Davis       9577620      50  Debbie Woods          6096921      52     16
#      26      1  Grant Clark          7985280      49  Erika Carr            2138695      54     16
#      27      1  David Smith          1106070      51  Mr. Robert Moore DVM  8550868      56     16
#      28      1  Jennifer Giles       5813185      53  Travis Matthews       8986072      57     16
#      29      1  Joshua Hampton Jr.   1887311      55  Derek Braun           4382055      60     16
#      30      1  Richard Torres       6192229      59  Mary Barry            4518507      61     16
#      31      1  Jason Jacobs         6894705      62  John Martin           7543030      63     16
#      32      1  Jacob Carson         9103585      58  Samuel Robinson       3428214      64     16
#
# ----- Round 4 -----
# Goodness of Fit: 16.0
# Maximum GOF: 16.0
# Frequencies: 16pts: 32
#
#       ID  Name                    Wins    Pod    Pod Rank
# -------  --------------------  ------  -----  ----------
# 6118794  James White                3      1           0
# 1482256  Linda Gonzales             3      1           0
# 7278224  Anthony Murillo            3      1           0
# 7094940  Amanda Franklin            3      1           0
# 9248926  Jacqueline Mcknight        3      1           0
# 3876005  Melissa Cardenas           3      1           0
# 5850845  Victor Clark               3      1           0
# 9835244  Kyle Lucas                 3      1           0
# 3407474  Amanda Berger              3      2           0
# 2962691  Mark Crane                 2      2           0
# 7934341  Alicia Moore               2      2           0
# 8953992  Kimberly Stewart           2      2           0
# 2994698  Daniel Lewis               2      2           0
# 7957778  Wayne Garcia               2      2           0
# 1588501  Denise Hernandez           2      2           0
# 6551961  Catherine Knox             2      2           0
# 3825948  Colleen Bartlett           2      3           0
# 3153945  Debra Calhoun              2      3           0
# 6433181  Valerie Gallegos           2      3           0
# 4179639  Shannon Aguilar            2      3           0
# 7335098  Dennis Carter              2      3           0
# 3625027  Brandon Robles             2      3           0
# 3985861  Mark Kim                   2      3           0
# 8696131  Courtney Salinas           2      3           0
# 9353287  Megan Aguilar              2      4           0
# 5865079  John Beard                 2      4           0
# 9458784  Tina Moran                 2      4           0
# 1284066  Cynthia Moran              2      4           0
# 5112040  Jordan Rivera              2      4           0
# 3056874  Hannah Bush                2      4           0
# 8333043  Maria Pollard              2      4           0
# 2486908  Derek Chambers             2      4           0
# 7985280  Grant Clark                1      5           0
# 6179987  Zachary Hughes             1      5           0
# 8054419  Kelly Graham               1      5           0
# 1106070  David Smith                1      5           0
# 6096921  Debbie Woods               1      5           0
# 8980761  Aaron Johnson              1      5           0
# 1276839  Matthew West               1      5           0
# 1451175  Carlos Luna                1      5           0
# 9020464  Amy Howard                 1      6           0
# 6172479  Tracey Richardson          1      6           0
# 7840580  Lindsay Harris             1      6           0
# 8474571  Susan Mcbride              1      6           0
# 1887311  Joshua Hampton Jr.         1      6           0
# 8986072  Travis Matthews            1      6           0
# 8788188  Donald Garcia              1      6           0
# 6192229  Richard Torres             1      6           0
# 5252460  Sergio Harrison            1      7           0
# 6057454  Jason Stevens              1      7           0
# 7245807  Priscilla Peterson         1      7           0
# 7952630  Stephanie Foley            1      7           0
# 7543030  John Martin                1      7           0
# 3428214  Samuel Robinson            1      7           0
# 6929021  Nicholas Olson DVM         1      7           0
# 9577620  Patricia Davis             0      7           0
# 5813185  Jennifer Giles             0      8           0
# 2138695  Erika Carr                 0      8           0
# 8550868  Mr. Robert Moore DVM       0      8           0
# 9103585  Jacob Carson               0      8           0
# 4382055  Derek Braun                0      8           0
# 4518507  Mary Barry                 0      8           0
# 6894705  Jason Jacobs               0      8           0
#      -8  Bye                        0      8           0
#
#
#    Table    Pod  Player 1 - Name            ID    Rank  Player 2 - Name           ID    Rank    GOF
# -------  -----  --------------------  -------  ------  -------------------  -------  ------  -----
#       1      1  Anthony Murillo       7278224       3  Amanda Franklin      7094940       4     16
#       2      1  Linda Gonzales        1482256       2  Jacqueline Mcknight  9248926       5     16
#       3      1  James White           6118794       1  Victor Clark         5850845       7     16
#       4      1  Melissa Cardenas      3876005       6  Kyle Lucas           9835244       8     16
#       5      2  Amanda Berger         3407474       9  Alicia Moore         7934341      11     16
#       6      2  Kimberly Stewart      8953992      12  Wayne Garcia         7957778      14     16
#       7      2  Mark Crane            2962691      10  Denise Hernandez     1588501      15     16
#       8      2  Daniel Lewis          2994698      13  Catherine Knox       6551961      16     16
#       9      3  Valerie Gallegos      6433181      19  Shannon Aguilar      4179639      20     16
#      10      3  Dennis Carter         7335098      21  Brandon Robles       3625027      22     16
#      11      3  Debra Calhoun         3153945      18  Mark Kim             3985861      23     16
#      12      3  Colleen Bartlett      3825948      17  Courtney Salinas     8696131      24     16
#      13      4  Tina Moran            9458784      27  Jordan Rivera        5112040      29     16
#      14      4  Megan Aguilar         9353287      25  Hannah Bush          3056874      30     16
#      15      4  Cynthia Moran         1284066      28  Maria Pollard        8333043      31     16
#      16      4  John Beard            5865079      26  Derek Chambers       2486908      32     16
#      17      5  Grant Clark           7985280      33  Zachary Hughes       6179987      34     16
#      18      5  David Smith           1106070      36  Debbie Woods         6096921      37     16
#      19      5  Kelly Graham          8054419      35  Matthew West         1276839      39     16
#      20      5  Aaron Johnson         8980761      38  Carlos Luna          1451175      40     16
#      21      6  Tracey Richardson     6172479      42  Lindsay Harris       7840580      43     16
#      22      6  Susan Mcbride         8474571      44  Joshua Hampton Jr.   1887311      45     16
#      23      6  Travis Matthews       8986072      46  Donald Garcia        8788188      47     16
#      24      6  Amy Howard            9020464      41  Richard Torres       6192229      48     16
#      25      7  Jason Stevens         6057454      50  Stephanie Foley      7952630      52     16
#      26      7  Sergio Harrison       5252460      49  John Martin          7543030      53     16
#      27      7  Samuel Robinson       3428214      54  Nicholas Olson DVM   6929021      55     16
#      28      7  Priscilla Peterson    7245807      51  Patricia Davis       9577620      56     16
#      29      8  Erika Carr            2138695      58  Jacob Carson         9103585      60     16
#      30      8  Mr. Robert Moore DVM  8550868      59  Mary Barry           4518507      62     16
#      31      8  Jennifer Giles        5813185      57  Jason Jacobs         6894705      63     16
#      32      8  Derek Braun           4382055      61  Bye                       -8      64     16
#
# ----- Round 5 -----
# Goodness of Fit: 15.53125
# Maximum GOF: 15.53125
# Frequencies: 16pts: 31, 1pts: 1
#
#       ID  Name                    Wins    Pod    Pod Rank
# -------  --------------------  ------  -----  ----------
# 6118794  James White                4      1           1
# 7278224  Anthony Murillo            4      1           1
# 9248926  Jacqueline Mcknight        4      1           1
# 9835244  Kyle Lucas                 4      1           1
# 1482256  Linda Gonzales             3      1           0
# 7094940  Amanda Franklin            3      1           0
# 3876005  Melissa Cardenas           3      1           0
# 5850845  Victor Clark               3      1           0
# 3407474  Amanda Berger              4      2           1
# 2962691  Mark Crane                 3      2           1
# 8953992  Kimberly Stewart           3      2           1
# 6551961  Catherine Knox             3      2           1
# 7934341  Alicia Moore               2      2           0
# 2994698  Daniel Lewis               2      2           0
# 7957778  Wayne Garcia               2      2           0
# 1588501  Denise Hernandez           2      2           0
# 6433181  Valerie Gallegos           3      3           1
# 7335098  Dennis Carter              3      3           1
# 3985861  Mark Kim                   3      3           1
# 8696131  Courtney Salinas           3      3           1
# 3825948  Colleen Bartlett           2      3           0
# 3153945  Debra Calhoun              2      3           0
# 4179639  Shannon Aguilar            2      3           0
# 3625027  Brandon Robles             2      3           0
# 9353287  Megan Aguilar              3      4           1
# 5112040  Jordan Rivera              3      4           1
# 8333043  Maria Pollard              3      4           1
# 2486908  Derek Chambers             3      4           1
# 5865079  John Beard                 2      4           0
# 9458784  Tina Moran                 2      4           0
# 1284066  Cynthia Moran              2      4           0
# 3056874  Hannah Bush                2      4           0
# 6179987  Zachary Hughes             2      5           1
# 6096921  Debbie Woods               2      5           1
# 8980761  Aaron Johnson              2      5           1
# 1276839  Matthew West               2      5           1
# 7985280  Grant Clark                1      5           0
# 8054419  Kelly Graham               1      5           0
# 1106070  David Smith                1      5           0
# 1451175  Carlos Luna                1      5           0
# 9020464  Amy Howard                 2      6           1
# 7840580  Lindsay Harris             2      6           1
# 8474571  Susan Mcbride              2      6           1
# 8788188  Donald Garcia              2      6           1
# 6172479  Tracey Richardson          1      6           0
# 1887311  Joshua Hampton Jr.         1      6           0
# 8986072  Travis Matthews            1      6           0
# 6192229  Richard Torres             1      6           0
# 5252460  Sergio Harrison            2      7           1
# 6057454  Jason Stevens              2      7           1
# 3428214  Samuel Robinson            2      7           1
# 9577620  Patricia Davis             1      7           1
# 7245807  Priscilla Peterson         1      7           0
# 7952630  Stephanie Foley            1      7           0
# 7543030  John Martin                1      7           0
# 6929021  Nicholas Olson DVM         1      7           0
# 8550868  Mr. Robert Moore DVM       1      8           1
# 9103585  Jacob Carson               1      8           1
# 4382055  Derek Braun                1      8           1
# 6894705  Jason Jacobs               1      8           1
#      -8  Bye                        1      8           1
# 5813185  Jennifer Giles             0      8           0
# 2138695  Erika Carr                 0      8           0
# 4518507  Mary Barry                 0      8           0
#
#
#    Table    Pod  Player 1 - Name            ID    Rank  Player 2 - Name          ID    Rank    GOF
# -------  -----  --------------------  -------  ------  ------------------  -------  ------  -----
#       1      1  James White           6118794       1  Anthony Murillo     7278224       2     16
#       2      1  Jacqueline Mcknight   9248926       3  Kyle Lucas          9835244       4     16
#       3      1  Amanda Franklin       7094940       6  Melissa Cardenas    3876005       7     16
#       4      1  Linda Gonzales        1482256       5  Victor Clark        5850845       8     16
#       5      2  Amanda Berger         3407474       9  Mark Crane          2962691      10     16
#       6      2  Kimberly Stewart      8953992      11  Catherine Knox      6551961      12     16
#       7      2  Daniel Lewis          2994698      14  Wayne Garcia        7957778      15     16
#       8      2  Alicia Moore          7934341      13  Denise Hernandez    1588501      16     16
#       9      3  Valerie Gallegos      6433181      17  Dennis Carter       7335098      18     16
#      10      3  Mark Kim              3985861      19  Courtney Salinas    8696131      20     16
#      11      3  Colleen Bartlett      3825948      21  Shannon Aguilar     4179639      23     16
#      12      3  Debra Calhoun         3153945      22  Brandon Robles      3625027      24     16
#      13      4  Megan Aguilar         9353287      25  Jordan Rivera       5112040      26     16
#      14      4  Maria Pollard         8333043      27  Derek Chambers      2486908      28     16
#      15      4  John Beard            5865079      29  Cynthia Moran       1284066      31     16
#      16      4  Tina Moran            9458784      30  Hannah Bush         3056874      32     16
#      17      5  Zachary Hughes        6179987      33  Debbie Woods        6096921      34     16
#      18      5  Aaron Johnson         8980761      35  Matthew West        1276839      36     16
#      19      5  Kelly Graham          8054419      38  David Smith         1106070      39     16
#      20      5  Grant Clark           7985280      37  Carlos Luna         1451175      40     16
#      21      6  Amy Howard            9020464      41  Susan Mcbride       8474571      43     16
#      22      6  Lindsay Harris        7840580      42  Donald Garcia       8788188      44     16
#      23      6  Tracey Richardson     6172479      45  Travis Matthews     8986072      47     16
#      24      6  Joshua Hampton Jr.    1887311      46  Richard Torres      6192229      48     16
#      25      7  Sergio Harrison       5252460      49  Jason Stevens       6057454      50     16
#      26      7  Samuel Robinson       3428214      51  Patricia Davis      9577620      52     16
#      27      7  Priscilla Peterson    7245807      53  John Martin         7543030      55     16
#      28      7  Stephanie Foley       7952630      54  Nicholas Olson DVM  6929021      56     16
#      29      8  Mr. Robert Moore DVM  8550868      57  Jacob Carson        9103585      58     16
#      30      8  Jason Jacobs          6894705      60  Bye                      -8      61     16
#      31      8  Derek Braun           4382055      59  Erika Carr          2138695      63      1
#      32      8  Jennifer Giles        5813185      62  Mary Barry          4518507      64     16
#
# ----- Round 6 -----
# Goodness of Fit: 16.0
# Maximum GOF: 16.0
# Frequencies: 16pts: 32
#
#       ID  Name                    Wins    Pod    Pod Rank
# -------  --------------------  ------  -----  ----------
# 7278224  Anthony Murillo            5      1           2
# 9835244  Kyle Lucas                 5      1           2
# 6118794  James White                4      1           1
# 7094940  Amanda Franklin            4      1           1
# 9248926  Jacqueline Mcknight        4      1           1
# 5850845  Victor Clark               4      1           1
# 1482256  Linda Gonzales             3      1           0
# 3876005  Melissa Cardenas           3      1           0
# 3407474  Amanda Berger              5      2           2
# 6551961  Catherine Knox             4      2           2
# 2962691  Mark Crane                 3      2           1
# 7934341  Alicia Moore               3      2           1
# 8953992  Kimberly Stewart           3      2           1
# 7957778  Wayne Garcia               3      2           1
# 2994698  Daniel Lewis               2      2           0
# 1588501  Denise Hernandez           2      2           0
# 6433181  Valerie Gallegos           4      3           2
# 3985861  Mark Kim                   4      3           2
# 3825948  Colleen Bartlett           3      3           1
# 7335098  Dennis Carter              3      3           1
# 3625027  Brandon Robles             3      3           1
# 8696131  Courtney Salinas           3      3           1
# 3153945  Debra Calhoun              2      3           0
# 4179639  Shannon Aguilar            2      3           0
# 5112040  Jordan Rivera              4      4           2
# 2486908  Derek Chambers             4      4           2
# 9353287  Megan Aguilar              3      4           1
# 9458784  Tina Moran                 3      4           1
# 1284066  Cynthia Moran              3      4           1
# 8333043  Maria Pollard              3      4           1
# 5865079  John Beard                 2      4           0
# 3056874  Hannah Bush                2      4           0
# 6179987  Zachary Hughes             3      5           2
# 1276839  Matthew West               3      5           2
# 8054419  Kelly Graham               2      5           1
# 6096921  Debbie Woods               2      5           1
# 8980761  Aaron Johnson              2      5           1
# 1451175  Carlos Luna                2      5           1
# 7985280  Grant Clark                1      5           0
# 1106070  David Smith                1      5           0
# 7840580  Lindsay Harris             3      6           2
# 8474571  Susan Mcbride              3      6           2
# 9020464  Amy Howard                 2      6           1
# 8986072  Travis Matthews            2      6           1
# 8788188  Donald Garcia              2      6           1
# 6192229  Richard Torres             2      6           1
# 6172479  Tracey Richardson          1      6           0
# 1887311  Joshua Hampton Jr.         1      6           0
# 5252460  Sergio Harrison            3      7           2
# 3428214  Samuel Robinson            3      7           2
# 6057454  Jason Stevens              2      7           1
# 7245807  Priscilla Peterson         2      7           1
# 7952630  Stephanie Foley            2      7           1
# 9577620  Patricia Davis             1      7           1
# 7543030  John Martin                1      7           0
# 6929021  Nicholas Olson DVM         1      7           0
# 9103585  Jacob Carson               2      8           2
# 4382055  Derek Braun                2      8           2
# 6894705  Jason Jacobs               2      8           2
#      -8  Bye                        2      8           2
# 5813185  Jennifer Giles             1      8           1
# 8550868  Mr. Robert Moore DVM       1      8           1
# 2138695  Erika Carr                 0      8           0
# 4518507  Mary Barry                 0      8           0
#
#
#    Table    Pod  Player 1 - Name           ID    Rank  Player 2 - Name            ID    Rank    GOF
# -------  -----  -------------------  -------  ------  --------------------  -------  ------  -----
#       1      1  Anthony Murillo      7278224       1  Kyle Lucas            9835244       2     16
#       2      1  James White          6118794       3  Amanda Franklin       7094940       4     16
#       3      1  Jacqueline Mcknight  9248926       5  Victor Clark          5850845       6     16
#       4      1  Linda Gonzales       1482256       7  Melissa Cardenas      3876005       8     16
#       5      2  Amanda Berger        3407474       9  Catherine Knox        6551961      10     16
#       6      2  Alicia Moore         7934341      12  Kimberly Stewart      8953992      13     16
#       7      2  Mark Crane           2962691      11  Wayne Garcia          7957778      14     16
#       8      2  Daniel Lewis         2994698      15  Denise Hernandez      1588501      16     16
#       9      3  Valerie Gallegos     6433181      17  Mark Kim              3985861      18     16
#      10      3  Colleen Bartlett     3825948      19  Brandon Robles        3625027      21     16
#      11      3  Dennis Carter        7335098      20  Courtney Salinas      8696131      22     16
#      12      3  Debra Calhoun        3153945      23  Shannon Aguilar       4179639      24     16
#      13      4  Jordan Rivera        5112040      25  Derek Chambers        2486908      26     16
#      14      4  Megan Aguilar        9353287      27  Cynthia Moran         1284066      29     16
#      15      4  Tina Moran           9458784      28  Maria Pollard         8333043      30     16
#      16      4  John Beard           5865079      31  Hannah Bush           3056874      32     16
#      17      5  Zachary Hughes       6179987      33  Matthew West          1276839      34     16
#      18      5  Debbie Woods         6096921      36  Aaron Johnson         8980761      37     16
#      19      5  Kelly Graham         8054419      35  Carlos Luna           1451175      38     16
#      20      5  Grant Clark          7985280      39  David Smith           1106070      40     16
#      21      6  Lindsay Harris       7840580      41  Susan Mcbride         8474571      42     16
#      22      6  Amy Howard           9020464      43  Donald Garcia         8788188      45     16
#      23      6  Travis Matthews      8986072      44  Richard Torres        6192229      46     16
#      24      6  Tracey Richardson    6172479      47  Joshua Hampton Jr.    1887311      48     16
#      25      7  Sergio Harrison      5252460      49  Samuel Robinson       3428214      50     16
#      26      7  Jason Stevens        6057454      51  Priscilla Peterson    7245807      52     16
#      27      7  Stephanie Foley      7952630      53  Patricia Davis        9577620      54     16
#      28      7  John Martin          7543030      55  Nicholas Olson DVM    6929021      56     16
#      29      8  Derek Braun          4382055      58  Jason Jacobs          6894705      59     16
#      30      8  Jacob Carson         9103585      57  Bye                        -8      60     16
#      31      8  Jennifer Giles       5813185      61  Mr. Robert Moore DVM  8550868      62     16
#      32      8  Erika Carr           2138695      63  Mary Barry            4518507      64     16
#
# ----- Round 7 -----
# Goodness of Fit: 16.0
# Maximum GOF: 16.0
# Frequencies: 16pts: 32
#
#       ID  Name                    Wins    Pod    Pod Rank
# -------  --------------------  ------  -----  ----------
# 9835244  Kyle Lucas                 6      1           0
# 3407474  Amanda Berger              6      1           0
# 6118794  James White                5      1           0
# 7278224  Anthony Murillo            5      1           0
# 9248926  Jacqueline Mcknight        5      1           0
# 6433181  Valerie Gallegos           5      1           0
# 5112040  Jordan Rivera              5      1           0
# 2962691  Mark Crane                 4      1           0
# 7934341  Alicia Moore               4      2           0
# 1482256  Linda Gonzales             4      2           0
# 6179987  Zachary Hughes             4      2           0
# 6551961  Catherine Knox             4      2           0
# 7094940  Amanda Franklin            4      2           0
# 3625027  Brandon Robles             4      2           0
# 7840580  Lindsay Harris             4      2           0
# 3985861  Mark Kim                   4      2           0
# 8696131  Courtney Salinas           4      3           0
# 5850845  Victor Clark               4      3           0
# 9458784  Tina Moran                 4      3           0
# 1284066  Cynthia Moran              4      3           0
# 5252460  Sergio Harrison            4      3           0
# 2486908  Derek Chambers             4      3           0
# 8953992  Kimberly Stewart           3      3           0
# 7957778  Wayne Garcia               3      3           0
# 1588501  Denise Hernandez           3      4           0
# 8054419  Kelly Graham               3      4           0
# 8980761  Aaron Johnson              3      4           0
# 3825948  Colleen Bartlett           3      4           0
# 3153945  Debra Calhoun              3      4           0
# 3876005  Melissa Cardenas           3      4           0
# 1276839  Matthew West               3      4           0
# 7335098  Dennis Carter              3      4           0
# 9353287  Megan Aguilar              3      5           0
# 5865079  John Beard                 3      5           0
# 8474571  Susan Mcbride              3      5           0
# 8788188  Donald Garcia              3      5           0
# 9103585  Jacob Carson               3      5           0
# 6192229  Richard Torres             3      5           0
# 7245807  Priscilla Peterson         3      5           0
# 6894705  Jason Jacobs               3      5           0
# 8333043  Maria Pollard              3      6           0
# 3428214  Samuel Robinson            3      6           0
# 7985280  Grant Clark                2      6           0
# 2994698  Daniel Lewis               2      6           0
# 9577620  Patricia Davis             2      6           0
# 6096921  Debbie Woods               2      6           0
# 1451175  Carlos Luna                2      6           0
# 9020464  Amy Howard                 2      6           0
# 4179639  Shannon Aguilar            2      7           0
# 6172479  Tracey Richardson          2      7           0
# 8550868  Mr. Robert Moore DVM       2      7           0
# 8986072  Travis Matthews            2      7           0
# 4382055  Derek Braun                2      7           0
# 3056874  Hannah Bush                2      7           0
# 6057454  Jason Stevens              2      7           0
# 7952630  Stephanie Foley            2      7           0
# 7543030  John Martin                2      8           0
# 1106070  David Smith                1      8           0
# 5813185  Jennifer Giles             1      8           0
# 1887311  Joshua Hampton Jr.         1      8           0
# 4518507  Mary Barry                 1      8           0
# 6929021  Nicholas Olson DVM         1      8           0
# 2138695  Erika Carr                 0      8           0
#      -8  Bye                        1      8           0
#
#
#    Table    Pod  Player 1 - Name            ID    Rank  Player 2 - Name          ID    Rank    GOF
# -------  -----  --------------------  -------  ------  ------------------  -------  ------  -----
#       1      1  Amanda Berger         3407474       2  Anthony Murillo     7278224       4     16
#       2      1  Kyle Lucas            9835244       1  Valerie Gallegos    6433181       6     16
#       3      1  James White           6118794       3  Jordan Rivera       5112040       7     16
#       4      1  Jacqueline Mcknight   9248926       5  Mark Crane          2962691       8     16
#       5      2  Catherine Knox        6551961      12  Amanda Franklin     7094940      13     16
#       6      2  Alicia Moore          7934341       9  Brandon Robles      3625027      14     16
#       7      2  Zachary Hughes        6179987      11  Lindsay Harris      7840580      15     16
# ...
#      20      5  Donald Garcia         8788188      36  Jason Jacobs        6894705      40     16
#      21      6  Samuel Robinson       3428214      42  Daniel Lewis        2994698      44     16
#      22      6  Grant Clark           7985280      43  Debbie Woods        6096921      46     16
#      23      6  Maria Pollard         8333043      41  Carlos Luna         1451175      47     16
#      24      6  Patricia Davis        9577620      45  Amy Howard          9020464      48     16
#      25      7  Tracey Richardson     6172479      50  Derek Braun         4382055      53     16
#      26      7  Travis Matthews       8986072      52  Hannah Bush         3056874      54     16
#      27      7  Mr. Robert Moore DVM  8550868      51  Jason Stevens       6057454      55     16
#      28      7  Shannon Aguilar       4179639      49  Stephanie Foley     7952630      56     16
#      29      8  Jennifer Giles        5813185      59  Joshua Hampton Jr.  1887311      60     16
#      30      8  John Martin           7543030      57  Mary Barry          4518507      61     16
#      31      8  David Smith           1106070      58  Erika Carr          2138695      63     16
#      32      8  Nicholas Olson DVM    6929021      62  Bye                      -8      64     16
#
# ----- Round 8 -----
# Goodness of Fit: 15.53125
# Maximum GOF: 15.53125
# Frequencies: 16pts: 31, 1pts: 1
#
#       ID  Name                    Wins    Pod    Pod Rank
# -------  --------------------  ------  -----  ----------
# 3407474  Amanda Berger              7      1           1
# 6118794  James White                6      1           1
# 6433181  Valerie Gallegos           6      1           1
# 2962691  Mark Crane                 5      1           1
# 9835244  Kyle Lucas                 6      1           0
# 7278224  Anthony Murillo            5      1           0
# 9248926  Jacqueline Mcknight        5      1           0
# 5112040  Jordan Rivera              5      1           0
# 7934341  Alicia Moore               5      2           1
# 1482256  Linda Gonzales             5      2           1
# 7094940  Amanda Franklin            5      2           1
# 7840580  Lindsay Harris             5      2           1
# 6179987  Zachary Hughes             4      2           0
# 6551961  Catherine Knox             4      2           0
# 3625027  Brandon Robles             4      2           0
# 3985861  Mark Kim                   4      2           0
# 9458784  Tina Moran                 5      3           1
# 2486908  Derek Chambers             5      3           1
# 8953992  Kimberly Stewart           4      3           1
# 7957778  Wayne Garcia               4      3           1
# 8696131  Courtney Salinas           4      3           0
# 5850845  Victor Clark               4      3           0
# 1284066  Cynthia Moran              4      3           0
# 5252460  Sergio Harrison            4      3           0
# 1588501  Denise Hernandez           4      4           1
# 3825948  Colleen Bartlett           4      4           1
# 1276839  Matthew West               4      4           1
# 7335098  Dennis Carter              4      4           1
# 8054419  Kelly Graham               3      4           0
# 8980761  Aaron Johnson              3      4           0
# 3153945  Debra Calhoun              3      4           0
# 3876005  Melissa Cardenas           3      4           0
# 9103585  Jacob Carson               4      5           1
# 6192229  Richard Torres             4      5           1
# 7245807  Priscilla Peterson         4      5           1
# 6894705  Jason Jacobs               4      5           1
# 9353287  Megan Aguilar              3      5           0
# 5865079  John Beard                 3      5           0
# 8474571  Susan Mcbride              3      5           0
# 8788188  Donald Garcia              3      5           0
# 8333043  Maria Pollard              4      6           1
# 7985280  Grant Clark                3      6           1
# 2994698  Daniel Lewis               3      6           1
# 9020464  Amy Howard                 3      6           1
# 3428214  Samuel Robinson            3      6           0
# 9577620  Patricia Davis             2      6           0
# 6096921  Debbie Woods               2      6           0
# 1451175  Carlos Luna                2      6           0
# 8986072  Travis Matthews            3      7           1
# 4382055  Derek Braun                3      7           1
# 6057454  Jason Stevens              3      7           1
# 7952630  Stephanie Foley            3      7           1
# 4179639  Shannon Aguilar            2      7           0
# 6172479  Tracey Richardson          2      7           0
# 8550868  Mr. Robert Moore DVM       2      7           0
# 3056874  Hannah Bush                2      7           0
# 7543030  John Martin                3      8           1
# 1106070  David Smith                2      8           1
# 5813185  Jennifer Giles             2      8           1
# 6929021  Nicholas Olson DVM         2      8           1
#      -8  Bye                        2      8           1
# 1887311  Joshua Hampton Jr.         1      8           0
# 4518507  Mary Barry                 1      8           0
# 2138695  Erika Carr                 0      8           0
#
#
#    Table    Pod  Player 1 - Name            ID    Rank  Player 2 - Name           ID    Rank    GOF
# -------  -----  --------------------  -------  ------  -------------------  -------  ------  -----
#       1      1  Amanda Berger         3407474       1  Valerie Gallegos     6433181       3     16
#       2      1  James White           6118794       2  Mark Crane           2962691       4     16
#       3      1  Anthony Murillo       7278224       6  Jacqueline Mcknight  9248926       7     16
#       4      1  Kyle Lucas            9835244       5  Jordan Rivera        5112040       8     16
#       5      2  Alicia Moore          7934341       9  Linda Gonzales       1482256      10     16
#       6      2  Amanda Franklin       7094940      11  Lindsay Harris       7840580      12     16
#       7      2  Catherine Knox        6551961      14  Brandon Robles       3625027      15     16
#       8      2  Zachary Hughes        6179987      13  Mark Kim             3985861      16     16
#       9      3  Derek Chambers        2486908      18  Kimberly Stewart     8953992      19     16
#      10      3  Tina Moran            9458784      17  Wayne Garcia         7957778      20     16
#      11      3  Courtney Salinas      8696131      21  Victor Clark         5850845      22     16
#      12      3  Cynthia Moran         1284066      23  Sergio Harrison      5252460      24     16
#      13      4  Denise Hernandez      1588501      25  Colleen Bartlett     3825948      26     16
#      14      4  Matthew West          1276839      27  Dennis Carter        7335098      28     16
#      15      4  Kelly Graham          8054419      29  Aaron Johnson        8980761      30     16
#      16      4  Debra Calhoun         3153945      31  Melissa Cardenas     3876005      32     16
#      17      5  Richard Torres        6192229      34  Priscilla Peterson   7245807      35     16
#      18      5  Jacob Carson          9103585      33  Jason Jacobs         6894705      36     16
#      19      5  John Beard            5865079      38  Susan Mcbride        8474571      39     16
#      20      5  Megan Aguilar         9353287      37  Donald Garcia        8788188      40     16
#      21      6  Maria Pollard         8333043      41  Daniel Lewis         2994698      43     16
#      22      6  Grant Clark           7985280      42  Amy Howard           9020464      44     16
#      23      6  Samuel Robinson       3428214      45  Debbie Woods         6096921      47     16
#      24      6  Patricia Davis        9577620      46  Carlos Luna          1451175      48     16
#      25      7  Travis Matthews       8986072      49  Jason Stevens        6057454      51     16
#      26      7  Derek Braun           4382055      50  Stephanie Foley      7952630      52     16
#      27      7  Shannon Aguilar       4179639      53  Tracey Richardson    6172479      54     16
#      28      7  Mr. Robert Moore DVM  8550868      55  Hannah Bush          3056874      56     16
#      29      8  David Smith           1106070      58  Nicholas Olson DVM   6929021      60     16
#      30      8  Jennifer Giles        5813185      59  Bye                       -8      61     16
#      31      8  Joshua Hampton Jr.    1887311      62  Mary Barry           4518507      63     16
#      32      8  John Martin           7543030      57  Erika Carr           2138695      64      1
#
# ----- Round 9 -----
# Goodness of Fit: 15.25
# Maximum GOF: 16.0
# Frequencies: 12pts: 6, 16pts: 26
#
#       ID  Name                    Wins    Pod    Pod Rank
# -------  --------------------  ------  -----  ----------
# 3407474  Amanda Berger              8      1           2
# 2962691  Mark Crane                 6      1           2
# 9835244  Kyle Lucas                 7      1           1
# 6118794  James White                6      1           1
# 7278224  Anthony Murillo            6      1           1
# 6433181  Valerie Gallegos           6      1           1
# 9248926  Jacqueline Mcknight        5      1           0
# 5112040  Jordan Rivera              5      1           0
# 1482256  Linda Gonzales             6      2           2
# 7840580  Lindsay Harris             6      2           2
# 7934341  Alicia Moore               5      2           1
# 6179987  Zachary Hughes             5      2           1
# 7094940  Amanda Franklin            5      2           1
# 3625027  Brandon Robles             5      2           1
# 6551961  Catherine Knox             4      2           0
# 3985861  Mark Kim                   4      2           0
# 8953992  Kimberly Stewart           5      3           2
# 7957778  Wayne Garcia               5      3           2
# 8696131  Courtney Salinas           5      3           1
# 9458784  Tina Moran                 5      3           1
# 1284066  Cynthia Moran              5      3           1
# 2486908  Derek Chambers             5      3           1
# 5850845  Victor Clark               4      3           0
# 5252460  Sergio Harrison            4      3           0
# 3825948  Colleen Bartlett           5      4           2
# 1276839  Matthew West               5      4           2
# 1588501  Denise Hernandez           4      4           1
# 8980761  Aaron Johnson              4      4           1
# 3153945  Debra Calhoun              4      4           1
# 7335098  Dennis Carter              4      4           1
# 8054419  Kelly Graham               3      4           0
# 3876005  Melissa Cardenas           3      4           0
# 6192229  Richard Torres             5      5           2
# 6894705  Jason Jacobs               5      5           2
# 9353287  Megan Aguilar              4      5           1
# 5865079  John Beard                 4      5           1
# 9103585  Jacob Carson               4      5           1
# 7245807  Priscilla Peterson         4      5           1
# 8474571  Susan Mcbride              3      5           0
# 8788188  Donald Garcia              3      5           0
# 8333043  Maria Pollard              5      6           2
# 9020464  Amy Howard                 4      6           2
# 7985280  Grant Clark                3      6           1
# 2994698  Daniel Lewis               3      6           1
# 6096921  Debbie Woods               3      6           1
# 1451175  Carlos Luna                3      6           1
# 3428214  Samuel Robinson            3      6           0
# 9577620  Patricia Davis             2      6           0
# 8986072  Travis Matthews            4      7           2
# 7952630  Stephanie Foley            4      7           2
# 4179639  Shannon Aguilar            3      7           1
# 8550868  Mr. Robert Moore DVM       3      7           1
# 4382055  Derek Braun                3      7           1
# 6057454  Jason Stevens              3      7           1
# 6172479  Tracey Richardson          2      7           0
# 3056874  Hannah Bush                2      7           0
# 7543030  John Martin                4      8           2
# 1106070  David Smith                3      8           2
# 5813185  Jennifer Giles             3      8           2
#      -8  Bye                        2      8           2
# 1887311  Joshua Hampton Jr.         2      8           1
# 6929021  Nicholas Olson DVM         2      8           1
# 4518507  Mary Barry                 1      8           0
# 2138695  Erika Carr                 0      8           0
#
#
#    Table    Pod  Player 1 - Name           ID    Rank  Player 2 - Name            ID    Rank    GOF
# -------  -----  -------------------  -------  ------  --------------------  -------  ------  -----
#       1      1  Amanda Berger        3407474       1  Mark Crane            2962691       2     12
#       2      1  Kyle Lucas           9835244       3  James White           6118794       4     16
#       3      1  Anthony Murillo      7278224       5  Valerie Gallegos      6433181       6     16
#       4      1  Jacqueline Mcknight  9248926       7  Jordan Rivera         5112040       8     16
#       5      2  Linda Gonzales       1482256       9  Lindsay Harris        7840580      10     16
#       6      2  Alicia Moore         7934341      11  Amanda Franklin       7094940      13     16
#       7      2  Zachary Hughes       6179987      12  Brandon Robles        3625027      14     12
#       8      2  Catherine Knox       6551961      15  Mark Kim              3985861      16     16
#       9      3  Kimberly Stewart     8953992      17  Wayne Garcia          7957778      18     12
#      10      3  Courtney Salinas     8696131      19  Tina Moran            9458784      20     16
#      11      3  Cynthia Moran        1284066      21  Derek Chambers        2486908      22     16
#      12      3  Victor Clark         5850845      23  Sergio Harrison       5252460      24     16
#      13      4  Colleen Bartlett     3825948      25  Matthew West          1276839      26     16
#      14      4  Denise Hernandez     1588501      27  Debra Calhoun         3153945      29     16
#      15      4  Aaron Johnson        8980761      28  Dennis Carter         7335098      30     16
#      16      4  Kelly Graham         8054419      31  Melissa Cardenas      3876005      32     16
#      17      5  Richard Torres       6192229      33  Jason Jacobs          6894705      34     16
#      18      5  Megan Aguilar        9353287      35  John Beard            5865079      36     16
#      19      5  Jacob Carson         9103585      37  Priscilla Peterson    7245807      38     16
#      20      5  Susan Mcbride        8474571      39  Donald Garcia         8788188      40     16
#      21      6  Maria Pollard        8333043      41  Amy Howard            9020464      42     16
#      22      6  Grant Clark          7985280      43  Debbie Woods          6096921      45     12
#      23      6  Daniel Lewis         2994698      44  Carlos Luna           1451175      46     16
#      24      6  Samuel Robinson      3428214      47  Patricia Davis        9577620      48     12
#      25      7  Travis Matthews      8986072      49  Stephanie Foley       7952630      50     16
#      26      7  Shannon Aguilar      4179639      51  Mr. Robert Moore DVM  8550868      52     16
#      27      7  Derek Braun          4382055      53  Jason Stevens         6057454      54     16
#      28      7  Tracey Richardson    6172479      55  Hannah Bush           3056874      56     16
#      29      8  John Martin          7543030      57  Jennifer Giles        5813185      59     16
#      30      8  David Smith          1106070      58  Bye                        -8      60     16
#      31      8  Joshua Hampton Jr.   1887311      61  Nicholas Olson DVM    6929021      62     16
#      32      8  Mary Barry           4518507      63  Erika Carr            2138695      64     12
#
# Overall Pairing Score Frequency:  16pts: 278, 1pts: 4, 12pts: 6
# ----- BYES -----
# Byes :  9
# 7934341 :  1
# 3985861 :  1
# 9835244 :  1
# 4382055 :  1
# 6894705 :  1
# 9103585 :  1
# 6929021 :  1
# 5813185 :  1
# 1106070 :  1
