# %%
import numpy as np
from collections import defaultdict, Counter
from faker import Faker
from tabulate import tabulate

fake = Faker()

# %% [markdown]
# ## Draw Simulation Methods

# %%
def init_players(num_players):
    """
    Create a collection of players in the form [player_id, player_name, player_ranking]
    Arguments:
        num_players: Number of players to add to the draw
    Returns:
        players: Array of player details
            (n x 3) list containing [player_id, player_name, player_ranking]
    """
    players = []
    id_to_name, id_to_rank = defaultdict(lambda: 'Bye'), defaultdict(lambda: 1600)
    for n in range(num_players):
        p_id, p_name, p_rank = np.random.randint(1000000, 9999999), fake.name(), np.random.randint(1600, 2000)
        players.append([p_id, p_name, p_rank])
        id_to_name[p_id] = p_name
        id_to_rank[p_id] = p_rank
    return players, id_to_name, id_to_rank

# %%
def init_pairings(players):
    """
    Randomly create results for the first round
    Arguments:
        players: (n x 3) numpy array containing [player_id, player_name, player_ranking]
    Returns:
        results: Randomly generated results table
            (n x 3) list containing [player_a_id, player_b_id, match_winner_id]
    """
    results = []
    for n in range(0, len(players), 2):
        a, b = players[n][0], players[n+1][0]
        result = [a, b, np.random.choice([a, b, None], 1, p=(0.45, 0.45, 0.1))[0]]
        results.append(result)
    return results

# %%
def run_round(pairings, rnd, p_draw=0):
    """
    Randomly create results for a round
    Arguments:
        pairings: List of pairings for the round to be simulated
            (n x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    Returns:
        results: Randomly generated results table
            (n x 3) list containing [player_a_id, player_b_id, match_winner_id]
    """
    results = []
    p_win = (1 - p_draw) / 2
    BYE = 0
    for pairing in pairings:
        a, b, pod = pairing[0][1], pairing[1][1], pairing[2]
        if a <= BYE:
            result = [a,b,b]
        elif b <= BYE:
            result = [a,b,a]
        else:
            result = [a, b, np.random.choice([a, b, None], 1, p=(p_win, p_win, p_draw))[0]]
        results.append(result + [rnd, pod])
        
    return results

# %% [markdown]
# ## Draw Calculation Methods

# %%
def create_draw(players, results, rounds):
    """
    Create draw for the round
    Arguments:
        players: Array of player details
            (n x 3) list containing [player_id, player_name, player_ranking]
        results: List of pairings and results for all rounds to date
            (m x 5) list containing [player_a_id, player_b_id, winner_id, round_id, pod_id]
    Returns:
        standings: List of standings for all players still in the tournament
            (n x 2) list containing [player_id, player_wins]
        splits: List of index points where each points bracket finishes
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
        alloc: The matrix form pairing allocations
            (n x n) matrix of integers
        pairings: The list form of pairing allocations
            (n / 2 x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    """
    n_players = len(players)
    
    standings       = get_standings(players, results, rounds)
    scores, splits  = get_scores(standings, results)
    alloc, pairings = get_allocations(standings, scores)
    
    return standings, splits, scores, alloc, pairings

# %%
def get_standings(players, results, rounds):
    """
    Calculate player standings at start of round
    Arguments:
        results: List of pairings and results for all rounds to date
            (m x 5) list containing [player_a_id, player_b_id, winner_id, round_id, pod_id]
    Returns:
        standings: List of standings for all players still in the tournament
            (n x 3) list containing [player_id, player_wins, player_pod]
    """
    standings, rankings, pods = defaultdict(int), defaultdict(int), defaultdict(lambda: 1)
    active_players  = set([player[0] for player in players])
    this_round = 0 if len(results) == 0 else np.array(results)[:,3].max() + 1
    last_round = this_round - 1
    
    # Use all rounds for ranking if 'swiss', or just pod results if 'pod'
    if rounds[this_round] == 'swiss':
        ranked_rounds = set(range(this_round))
    else:
        ranked_rounds = set([n for n, rnd in enumerate(rounds) if rnd == rounds[this_round]])
        
    # Calculate player standings
    if len(results) > 0:
        for a, b, winner, rnd, pod in results:
            standings[a] += (a == winner)
            standings[b] += (b == winner)
            if rnd in ranked_rounds:
                rankings[a] += (a == winner)
                rankings[b] += (b == winner)
            if rnd == last_round:
                if a in active_players: pods[a] = pod
                if b in active_players: pods[b] = pod
    
    standings = [[p, standings[p]] for p in active_players]
    standings = sorted(standings, key=lambda x: x[1], reverse=True)
    
    # Determine whether to create, reuse or ignore pods
    if rounds[this_round][:3] == 'pod':
        if this_round == 0 or rounds[this_round] != rounds[last_round]:
            method = 'create pod'
        else:
            method = 'reuse pod'
    else:
        method = 'bracket'
        
    # Allocate players to pods
    for pos, standing in enumerate(standings):
        if method == 'create pod':
            standing += [pos // 8 + 1]
        elif method == 'reuse pod':
            standing += [pods[standing[0]]]
        else:
            standing += [1]
        standing += [rankings[standing[0]]]
    
    standings = np.array(standings)
            
    # Add byes into the largest bracket in each of the pods
    pod_sizes = Counter(standings[:,2])
    byes = []
    for pod_num in range(1, len(pod_sizes) + 1):
        if pod_sizes[pod_num] % 2 == 1:
            mode_ranking  = np.bincount(standings[standings[:,2]==pod_num][:,1]).argmax()
            mode_standing = np.bincount(standings[standings[:,2]==pod_num][:,3]).argmax()
            byes.append([-pod_num, mode_ranking, pod_num, mode_standing])
    
    if len(byes) > 0:
        standings = np.vstack([standings, byes])
        standings = sorted(standings, key=lambda x: x[3], reverse=True)
        standings = sorted(standings, key=lambda x: x[2])
        standings = np.array(standings)

    return standings

# %%
def get_scores(standings, results):
    """
    Assign scores to each possible pairing
    A higher score means that the pairing is more strongly preferred
    Arguments:
        standings: List of standings for all players still in the tournament
            (n x 2) list containing [player_id, player_wins]
        results: List of pairings and results for all rounds to date
            (m x 5) list containing [player_a_id, player_b_id, winner_id, round_id, pod_id]
    Returns:
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
        splits: List of index points where each points bracket finishes
    """
    n_players = len(standings)
    ix = {player_id: pos for pos, player_id in enumerate(standings[:,0])}
    active_players = set(ix.keys())
    splits = get_splits(standings)
    
    # Calculate scores for pairings
    scores = np.full((n_players, n_players), -100)
    
    split_1, split_2 = 0, 0
    for split in splits + [n_players]:
        # Assign points for players in same bracket
        scores[split_1:split, split_1:split] = 16
        # Assign points for pull-up bracket
        if split_1 %2 == 1:
            scores[split_2:split_1, split_1:split] = 1
            scores[split_1:split, split_2:split_1] = 1
        split_1, split_2 = split, split_1
    
    # Reset self vs self to -inf
    np.fill_diagonal(scores, -100)

    # Subtract points for prior matchup
    BYE = 0
    for result in results:
        if result[0] in active_players and result[1] in active_players:
            a, b = ix[result[0]], ix[result[1]]
            penalty = 32 if min(result) < BYE else 4
            scores[a,b] -= penalty
            scores[b,a] -= penalty
        
    return scores, splits

# %%
def swap_pairs(pair_1, pair_2, alloc):
    """
    Helper function to swap players between two pairings
    Original pairing of (a,b) and (c,d) becomes (a,c) and (b,d)
    Arguments:
        pair_1: Tuple containing first pair to swap (a,b)
        pair_2: Tuple containing first pair to swap (c,d)
        alloc: The matrix form pairing allocations
            (n x n) matrix of integers
    Returns:
        alloc: The matrix form pairing allocations with [(a,b), (c,d)] -> [(a,c), (b,d)]
            (n x n) matrix of integers        
    """
    a, b = pair_1
    c, d = pair_2

    alloc[a, b] = 0
    alloc[b, a] = 0
    alloc[c, d] = 0
    alloc[d, c] = 0
    alloc[a, c] = 1
    alloc[c, a] = 1
    alloc[b, d] = 1
    alloc[d, b] = 1
    
    return alloc

# %%
def get_splits(standings):
    """
    Helper method to find the points at which the brackets split
    Arguments:
        standings: List of standings for all players still in the tournament
            (n x 4) list containing [player_id, player_wins, pod_id, player_wins_in_pod]
    """
    n_players = len(standings)
    
    # Sort standings by bracket and player wins
    standings = sorted(standings, key=lambda x: x[3], reverse=True)
    standings = sorted(standings, key=lambda x: x[2])
    standings = np.array(standings)
    
    # Calculate splits
    splits = [n for n in range(n_players) if (standings[n,[3,2]] != standings[n-1,[3,2]]).any()] + [n_players]

    return splits

# %%
def get_allocations(standings, scores):
    """
    Split table down into even length brackets and sub-allocate
    Arguments:
        standings: List of standings for all players still in the tournament
            (n x 4) list containing [player_id, player_wins, pod_id, player_wins_in_pod]
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
    Returns:
        alloc: The matrix form pairing allocations
            (n x n) matrix of integers
        pairs: The list form of pairing allocations
            (n / 2 x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    """
    n_players = len(standings)
    splits = get_splits(standings)

    # Allocate entire table if there is no split
    if len(splits) == 1:
        return _get_allocations(standings, scores)

    allocs = np.zeros((n_players, n_players))
    pairs = []

    # Split into sub-tables at even numbered index split points
    ixs = np.array(splits)
    ixs = ixs[ixs % 2 == 0]
    for ix1, ix2 in zip(ixs[:-1], ixs[1:]):
        alloc, pair = _get_allocations(standings[ix1:ix2], scores[ix1:ix2,ix1:ix2], start=ix1)

        allocs[ix1:ix2,ix1:ix2] = alloc
        pairs += pair

    return allocs, pairs

def _get_allocations(standings, scores, start=0):
    """
    Allocate player pairings
    Arguments:
        standings: List of standings for all players still in the tournament
            (n x 4) list containing [player_id, player_wins, pod_id, player_wins_in_pod]
        scores: Matrix containing the scores for all possible pairings
            (n x n) matrix of floats
    Returns:
        alloc: The matrix form pairing allocations
            (n x n) matrix of integers
        pairs: The list form of pairing allocations
            (n / 2 x 2 x 2) list containing [(player_a_standing, player_a_id), (player_b_standing, player_b_id)]
    """
    n_players = len(standings)
    ix = {pos+start: player_id for pos, player_id in enumerate(standings[:,0])}
    alloc = np.zeros((n_players, n_players), dtype=int)
    splits = get_splits(standings)
    pods = {player[0]: player[2] for player in standings}

    # Construct initial draw
    for _ in range(int(n_players / 2)):
        mask = (1 - alloc.sum(axis=1))
        # Choose Player A
        p = scores.max() - scores.mean(axis=1)
        p = p * mask
        a = p.argmax()
        # Choose Player B
        p = np.exp(scores[a])
        p = np.maximum(p * mask, 0)
        b = np.random.choice(range(n_players),p=p/p.sum())
        
        alloc[a, b] = 1
        alloc[b, a] = 1

    score_q = [(alloc*scores).sum()/len(scores)]
    max_score = 16 - 15 * (np.array(splits) % 2).sum() * 2 / len(scores)
    
    # Run Metropolis-Hastings to iteratively improve draw
    if score_q[0] != max_score:
        prob = np.exp(scores)
        prob /= prob.sum(axis=1, keepdims=True)

        best_alloc = alloc.copy()
        while len(score_q) < 10 or np.mean(score_q[-5:]) > np.mean(score_q[-10:-5]):        
            if max(score_q) == max_score:
                break
            for a, p in enumerate(prob):
                b = alloc[a].argmax()
                c = np.random.choice(range(len(p)),p=p)
                d = alloc[c].argmax()
                p_change = prob[a,c]*prob[b,d]/(prob[a,b]*prob[c,d] + prob[a,c]*prob[b,d])
                if np.random.random() < p_change:
                    alloc = swap_pairs((a,b), (c,d), alloc)

            score = (alloc*scores).sum()/len(prob)
            if score > max(score_q):
                best_alloc = alloc.copy()
            score_q.append(score)

        alloc = best_alloc
        del(best_alloc)
    
    # Create list form of pairings
    alloc_ = alloc * np.tri(*alloc.shape)

    pairs = []
    for n in range(n_players):
        if alloc_[n].max() == 1:
            a, b = n + start, alloc_[n].argmax() + start
            pairs.append([(a, ix[a]), (b, ix[b]), pods[ix[a]]])
            
    return alloc, pairs

# %% [markdown]
# ## Draw Printing Methods

# %%
def print_standings(standings, id_to_name):
    """
    Print standings for the round in table form
    """
    table = []
    for rank, player in enumerate(standings):
        table.append([int(player[0]), id_to_name[player[0]], player[1], rank+1, player[2], player[3]])
    print('\n', tabulate(table, headers=['ID', 'Name', 'Wins', 'Standing', 'Pod', 'Rank']), '\n')
    

def print_pairings(pairs, id_to_name, scores):
    """
    Print pairings for the round in table form
    """
    table = []
    for table_num, pair in enumerate(pairs):
        b, a, pod = pair[0], pair[1], pair[2]
        score = scores[b[0], a[0]]
        row = [table_num+1, pod, id_to_name[a[1]], int(a[1]), int(a[0])+1, id_to_name[b[1]], int(b[1]), int(b[0])+1, score]
        table.append(row)
    headers = ['Table', 'Pod', 'Player 1 - Name', 'ID', 'Rank', 'Player 2 - Name', 'ID', 'Rank', 'GOF']
    print('\n', tabulate(table, headers=headers), '\n')

def print_byes(pairs):
    byes = []
    for pairs in pairs_h:
        for pair in pairs:
            a, b = pair[0][1], pair[1][1]
            if min(a, b) < 0:
                byes += [max(a, -1), max(b, -1)]
    byes = Counter(np.reshape(byes, -1))

    print('----- BYES -----')
    for k, v in byes.items():
        if k < 0:
            print('Byes', ': ', v)
        else:
            print(k, ': ', v)

# %% [markdown]
# ## Run a sample Tournament
# Create a list of players then run through a multi-round tournament and print the results
# Each round prints:
# - Goodness of fit score: Score for the pairings allocated in the round. The maximum possible score is 4. If a number < 0 comes out, something has probably gone wrong
# - Standings: A table of standings of the players (based only on # of wins, no accounting for draws, op wins etc)
# - Pairings: A table of pairings for the following round (including player name and standing so you can check if players are being paired with others nearby)
#
# To show all the standings and pairings at once, make sure to select the cell, click on the "Cell" menu, select -> "Current Outputs" and then select "Toggle Scrolling"
#
# The entire history of "standings", "splits", "scores", "allocations", and "pairs" is recorded in the lists *standings_h, splits_h, scores_h, alloc_h, pairs_h*
#
# Note: Early stage demo only. This does not support:
# - Odd numbers of players and byes [Done]
# - Allocating pods [Done]
# - Iterative sampling methods to improve draw quality [Done]
# - Balancing tail end pod sizes
# - Variable size pods
# - etc

# %%
NUMBER_OF_PLAYERS = 31
ROUNDS  = ['swiss', 'swiss', 'swiss',
           'pod1', 'pod1', 'pod1',
           'pod2', 'pod2', 'pod2',
           'swiss', 'swiss', 'swiss']
NUMBER_OF_ROUNDS = len(ROUNDS)
PROBABILITY_OF_DRAW = 0.0001

# %%
# Create players
players, id_to_name, id_to_rank = init_players(NUMBER_OF_PLAYERS)

# %%
results = []
standings_h, splits_h, scores_h, alloc_h, pairs_h = [], [], [], [], []
number_of_players = NUMBER_OF_PLAYERS + NUMBER_OF_PLAYERS % 2

for rnd in range(NUMBER_OF_ROUNDS):
    standings, splits, scores, alloc, pairs = create_draw(players, results, ROUNDS)
    for collection, value in zip([standings_h, splits_h, scores_h, alloc_h, pairs_h],
                                 [standings,   splits,   scores,   alloc,   pairs]):
        collection.append(value)
    print('----- Round', rnd + 1, '-----', )
    print('Goodness of Fit:', (scores * alloc).sum() / number_of_players)
    print('Maximum GOF:', 16 - 15 * (np.array(splits) % 2).sum() * 2 / number_of_players)
    print("Frequencies: " + ', '.join([str(int(k)) + "pts: " + str(int(v / 2)) 
                                 for k, v in Counter((scores * alloc).reshape(-1)).items() if k != 0]) )
    print_standings(standings, id_to_name, )
    print_pairings(pairs, id_to_name, scores)
    result = run_round(pairs, rnd, p_draw=PROBABILITY_OF_DRAW)
    results += result

print('Overall Pairing Score Frequency: ', ', '.join([str(int(k)) + "pts: " + str(int(v / 2))
   for k, v in Counter((np.array(scores_h)*np.array(alloc_h))[-NUMBER_OF_ROUNDS:].reshape(-1)).items() if k != 0]))
print_byes(pairs_h)
# Out:
# ----- Round 1 -----
# Goodness of Fit: 16.0
# Maximum GOF: 16.0
# Frequencies: 16pts: 16
#
#       ID  Name                  Wins    Standing    Pod    Rank
# -------  ------------------  ------  ----------  -----  ------
# 1834753  Wanda Meyer              0           1      1       0
# 4729990  Jennifer Benitez         0           2      1       0
# 3057926  William Long             0           3      1       0
# 8855816  Cory Henry               0           4      1       0
# 8272394  Pamela Hernandez         0           5      1       0
# 2475531  Jason Lambert            0           6      1       0
# 4247574  Kelly Willis             0           7      1       0
# 5442457  Shelley Murray           0           8      1       0
# 7290779  Miranda Coleman          0           9      1       0
# 7825183  Nathan Walters           0          10      1       0
# 4059553  William Hogan            0          11      1       0
# 3797795  Randy Baker              0          12      1       0
# 8814507  Zachary Simon            0          13      1       0
# 2574776  Jeffrey Weaver           0          14      1       0
# 1061048  Bethany Weaver           0          15      1       0
# 4053948  Michael Villa            0          16      1       0
# 8311617  Lisa Ellis               0          17      1       0
# 3108164  Stephanie Arellano       0          18      1       0
# 8735686  Matthew Martinez         0          19      1       0
# 1770440  Cynthia Cole             0          20      1       0
# 6857290  Anthony Faulkner         0          21      1       0
# 3798736  Donna Miller             0          22      1       0
# 3010001  Thomas Stevenson         0          23      1       0
# 2883286  Jennifer Velasquez       0          24      1       0
# 6763994  William Pena             0          25      1       0
# 7691617  Terry Martin             0          26      1       0
# 6215143  Jacqueline Lester        0          27      1       0
# 8707433  Jerry Smith              0          28      1       0
# 7923564  Kathleen Walsh           0          29      1       0
# 3737204  Loretta Sloan            0          30      1       0
# 5461623  Mary Green               0          31      1       0
#      -1  Bye                      0          32      1       0
#
#
#    Table    Pod  Player 1 - Name          ID    Rank  Player 2 - Name          ID    Rank    GOF
# -------  -----  ------------------  -------  ------  ------------------  -------  ------  -----
#       1      1  Pamela Hernandez    8272394       5  William Hogan       4059553      11     16
#       2      1  Jennifer Benitez    4729990       2  Zachary Simon       8814507      13     16
#       3      1  Wanda Meyer         1834753       1  Jeffrey Weaver      2574776      14     16
#       4      1  Kelly Willis        4247574       7  Bethany Weaver      1061048      15     16
#       5      1  Nathan Walters      7825183      10  Lisa Ellis          8311617      17     16
#       6      1  Jason Lambert       2475531       6  Stephanie Arellano  3108164      18     16
#       7      1  Shelley Murray      5442457       8  Cynthia Cole        1770440      20     16
#       8      1  Miranda Coleman     7290779       9  Donna Miller        3798736      22     16
#       9      1  Michael Villa       4053948      16  Thomas Stevenson    3010001      23     16
#      10      1  Matthew Martinez    8735686      19  William Pena        6763994      25     16
#      11      1  Randy Baker         3797795      12  Terry Martin        7691617      26     16
#      12      1  Cory Henry          8855816       4  Jacqueline Lester   6215143      27     16
#      13      1  Anthony Faulkner    6857290      21  Kathleen Walsh      7923564      29     16
#      14      1  Jennifer Velasquez  2883286      24  Loretta Sloan       3737204      30     16
#      15      1  Jerry Smith         8707433      28  Mary Green          5461623      31     16
#      16      1  William Long        3057926       3  Bye                      -1      32     16
#
# ----- Round 2 -----
# Goodness of Fit: 15.0625
# Maximum GOF: 15.0625
# Frequencies: 16pts: 15, 1pts: 1
#
#       ID  Name                  Wins    Standing    Pod    Rank
# -------  ------------------  ------  ----------  -----  ------
# 4729990  Jennifer Benitez         1           1      1       1
# 3057926  William Long             1           2      1       1
# 8855816  Cory Henry               1           3      1       1
# 8272394  Pamela Hernandez         1           4      1       1
# 2475531  Jason Lambert            1           5      1       1
# 4247574  Kelly Willis             1           6      1       1
# 2574776  Jeffrey Weaver           1           7      1       1
# 8311617  Lisa Ellis               1           8      1       1
# 1770440  Cynthia Cole             1           9      1       1
# 3798736  Donna Miller             1          10      1       1
# 3010001  Thomas Stevenson         1          11      1       1
# 6763994  William Pena             1          12      1       1
# 7691617  Terry Martin             1          13      1       1
# 7923564  Kathleen Walsh           1          14      1       1
# 3737204  Loretta Sloan            1          15      1       1
# 5461623  Mary Green               1          16      1       1
#      -1  Bye                      1          17      1       1
# 1834753  Wanda Meyer              0          18      1       0
# 5442457  Shelley Murray           0          19      1       0
# 7290779  Miranda Coleman          0          20      1       0
# 7825183  Nathan Walters           0          21      1       0
# 4059553  William Hogan            0          22      1       0
# 3797795  Randy Baker              0          23      1       0
# 8814507  Zachary Simon            0          24      1       0
# 1061048  Bethany Weaver           0          25      1       0
# 4053948  Michael Villa            0          26      1       0
# 3108164  Stephanie Arellano       0          27      1       0
# 8735686  Matthew Martinez         0          28      1       0
# 6857290  Anthony Faulkner         0          29      1       0
# 2883286  Jennifer Velasquez       0          30      1       0
# 6215143  Jacqueline Lester        0          31      1       0
# 8707433  Jerry Smith              0          32      1       0
#
#
#    Table    Pod  Player 1 - Name         ID    Rank  Player 2 - Name          ID    Rank    GOF
# -------  -----  -----------------  -------  ------  ------------------  -------  ------  -----
#       1      1  Kelly Willis       4247574       6  Lisa Ellis          8311617       8     16
#       2      1  Jason Lambert      2475531       5  Donna Miller        3798736      10     16
#       3      1  Cory Henry         8855816       3  Thomas Stevenson    3010001      11     16
#       4      1  Cynthia Cole       1770440       9  William Pena        6763994      12     16
#       5      1  Jeffrey Weaver     2574776       7  Terry Martin        7691617      13     16
#       6      1  William Long       3057926       2  Kathleen Walsh      7923564      14     16
#       7      1  Jennifer Benitez   4729990       1  Loretta Sloan       3737204      15     16
#       8      1  Pamela Hernandez   8272394       4  Bye                      -1      17     16
#       9      1  Zachary Simon      8814507      24  Bethany Weaver      1061048      25     16
#      10      1  William Hogan      4059553      22  Michael Villa       4053948      26     16
#      11      1  Randy Baker        3797795      23  Stephanie Arellano  3108164      27     16
#      12      1  Mary Green         5461623      16  Matthew Martinez    8735686      28      1
#      13      1  Shelley Murray     5442457      19  Anthony Faulkner    6857290      29     16
#      14      1  Miranda Coleman    7290779      20  Jennifer Velasquez  2883286      30     16
#      15      1  Wanda Meyer        1834753      18  Jacqueline Lester   6215143      31     16
#      16      1  Nathan Walters     7825183      21  Jerry Smith         8707433      32     16
#
# ----- Round 3 -----
# Goodness of Fit: 15.0625
# Maximum GOF: 15.0625
# Frequencies: 16pts: 15, 1pts: 1
#
#       ID  Name                  Wins    Standing    Pod    Rank
# -------  ------------------  ------  ----------  -----  ------
# 4729990  Jennifer Benitez         2           1      1       2
# 8272394  Pamela Hernandez         2           2      1       2
# 2475531  Jason Lambert            2           3      1       2
# 4247574  Kelly Willis             2           4      1       2
# 1770440  Cynthia Cole             2           5      1       2
# 3010001  Thomas Stevenson         2           6      1       2
# 7691617  Terry Martin             2           7      1       2
# 7923564  Kathleen Walsh           2           8      1       2
# 1834753  Wanda Meyer              1           9      1       1
# 3057926  William Long             1          10      1       1
# 8855816  Cory Henry               1          11      1       1
# 5442457  Shelley Murray           1          12      1       1
# 2574776  Jeffrey Weaver           1          13      1       1
# 1061048  Bethany Weaver           1          14      1       1
# 4053948  Michael Villa            1          15      1       1
# 8311617  Lisa Ellis               1          16      1       1
# 3108164  Stephanie Arellano       1          17      1       1
# 8735686  Matthew Martinez         1          18      1       1
# 3798736  Donna Miller             1          19      1       1
# 2883286  Jennifer Velasquez       1          20      1       1
# 6763994  William Pena             1          21      1       1
# 8707433  Jerry Smith              1          22      1       1
# 3737204  Loretta Sloan            1          23      1       1
# 5461623  Mary Green               1          24      1       1
#      -1  Bye                      1          25      1       1
# 7290779  Miranda Coleman          0          26      1       0
# 7825183  Nathan Walters           0          27      1       0
# 4059553  William Hogan            0          28      1       0
# 3797795  Randy Baker              0          29      1       0
# 8814507  Zachary Simon            0          30      1       0
# 6857290  Anthony Faulkner         0          31      1       0
# 6215143  Jacqueline Lester        0          32      1       0
#
#
#    Table    Pod  Player 1 - Name          ID    Rank  Player 2 - Name          ID    Rank    GOF
# -------  -----  ------------------  -------  ------  ------------------  -------  ------  -----
#       1      1  Jason Lambert       2475531       3  Kelly Willis        4247574       4     16
#       2      1  Jennifer Benitez    4729990       1  Cynthia Cole        1770440       5     16
#       3      1  Pamela Hernandez    8272394       2  Thomas Stevenson    3010001       6     16
#       4      1  Terry Martin        7691617       7  Kathleen Walsh      7923564       8     16
#       5      1  Cory Henry          8855816      11  Shelley Murray      5442457      12     16
#       6      1  Wanda Meyer         1834753       9  Michael Villa       4053948      15     16
#       7      1  Jeffrey Weaver      2574776      13  Donna Miller        3798736      19     16
#       8      1  Matthew Martinez    8735686      18  Jennifer Velasquez  2883286      20     16
#       9      1  Bethany Weaver      1061048      14  William Pena        6763994      21     16
#      10      1  William Long        3057926      10  Jerry Smith         8707433      22     16
#      11      1  Stephanie Arellano  3108164      17  Loretta Sloan       3737204      23     16
#      12      1  Lisa Ellis          8311617      16  Bye                      -1      25     16
#      13      1  Miranda Coleman     7290779      26  Nathan Walters      7825183      27     16
#      14      1  Randy Baker         3797795      29  Zachary Simon       8814507      30     16
#      15      1  Mary Green          5461623      24  Anthony Faulkner    6857290      31      1
#      16      1  William Hogan       4059553      28  Jacqueline Lester   6215143      32     16
#
# ----- Round 4 -----
# Goodness of Fit: 16.0
# Maximum GOF: 16.0
# Frequencies: 16pts: 16
#
#       ID  Name                  Wins    Standing    Pod    Rank
# -------  ------------------  ------  ----------  -----  ------
# 4729990  Jennifer Benitez         3           1      1       0
# 2475531  Jason Lambert            3           2      1       0
# 3010001  Thomas Stevenson         3           3      1       0
# 7691617  Terry Martin             3           4      1       0
# 1834753  Wanda Meyer              2           5      1       0
# 8272394  Pamela Hernandez         2           6      1       0
# 4247574  Kelly Willis             2           7      1       0
# 5442457  Shelley Murray           2           8      1       0
# 2574776  Jeffrey Weaver           2           9      2       0
# 8311617  Lisa Ellis               2          10      2       0
# 8735686  Matthew Martinez         2          11      2       0
# 1770440  Cynthia Cole             2          12      2       0
# 6763994  William Pena             2          13      2       0
# 8707433  Jerry Smith              2          14      2       0
# 7923564  Kathleen Walsh           2          15      2       0
# 3737204  Loretta Sloan            2          16      2       0
# 3057926  William Long             1          17      3       0
# 8855816  Cory Henry               1          18      3       0
# 7825183  Nathan Walters           1          19      3       0
# 4059553  William Hogan            1          20      3       0
# 8814507  Zachary Simon            1          21      3       0
# 1061048  Bethany Weaver           1          22      3       0
# 4053948  Michael Villa            1          23      3       0
# 3108164  Stephanie Arellano       1          24      3       0
# 6857290  Anthony Faulkner         1          25      4       0
# 3798736  Donna Miller             1          26      4       0
# 2883286  Jennifer Velasquez       1          27      4       0
# 5461623  Mary Green               1          28      4       0
# 7290779  Miranda Coleman          0          29      4       0
# 3797795  Randy Baker              0          30      4       0
# 6215143  Jacqueline Lester        0          31      4       0
#      -4  Bye                      1          32      4       0
#
#
#    Table    Pod  Player 1 - Name          ID    Rank  Player 2 - Name          ID    Rank    GOF
# -------  -----  ------------------  -------  ------  ------------------  -------  ------  -----
#       1      1  Jennifer Benitez    4729990       1  Jason Lambert       2475531       2     16
#       2      1  Thomas Stevenson    3010001       3  Wanda Meyer         1834753       5     16
#       3      1  Terry Martin        7691617       4  Pamela Hernandez    8272394       6     16
#       4      1  Kelly Willis        4247574       7  Shelley Murray      5442457       8     16
#       5      2  Jeffrey Weaver      2574776       9  Matthew Martinez    8735686      11     16
#       6      2  Lisa Ellis          8311617      10  William Pena        6763994      13     16
#       7      2  Cynthia Cole        1770440      12  Jerry Smith         8707433      14     16
#       8      2  Kathleen Walsh      7923564      15  Loretta Sloan       3737204      16     16
#       9      3  William Long        3057926      17  Cory Henry          8855816      18     16
#      10      3  William Hogan       4059553      20  Bethany Weaver      1061048      22     16
#      11      3  Nathan Walters      7825183      19  Michael Villa       4053948      23     16
#      12      3  Zachary Simon       8814507      21  Stephanie Arellano  3108164      24     16
#      13      4  Anthony Faulkner    6857290      25  Donna Miller        3798736      26     16
#      14      4  Mary Green          5461623      28  Randy Baker         3797795      30     16
#      15      4  Jennifer Velasquez  2883286      27  Jacqueline Lester   6215143      31     16
#      16      4  Miranda Coleman     7290779      29  Bye                      -4      32     16
#
# ----- Round 5 -----
# Goodness of Fit: 15.0625
# Maximum GOF: 15.0625
# Frequencies: 16pts: 15, 1pts: 1
#
#       ID  Name                  Wins    Standing    Pod    Rank
# -------  ------------------  ------  ----------  -----  ------
# 4729990  Jennifer Benitez         4           1      1       1
# 3010001  Thomas Stevenson         4           2      1       1
# 8272394  Pamela Hernandez         3           3      1       1
# 4247574  Kelly Willis             3           4      1       1
# 2475531  Jason Lambert            3           5      1       0
# 7691617  Terry Martin             3           6      1       0
# 1834753  Wanda Meyer              2           7      1       0
# 5442457  Shelley Murray           2           8      1       0
# 2574776  Jeffrey Weaver           3           9      2       1
# 8311617  Lisa Ellis               3          10      2       1
# 8707433  Jerry Smith              3          11      2       1
# 7923564  Kathleen Walsh           3          12      2       1
# 8735686  Matthew Martinez         2          13      2       0
# 1770440  Cynthia Cole             2          14      2       0
# 6763994  William Pena             2          15      2       0
# 3737204  Loretta Sloan            2          16      2       0
# 8855816  Cory Henry               2          17      3       1
# 4059553  William Hogan            2          18      3       1
# 4053948  Michael Villa            2          19      3       1
# 3108164  Stephanie Arellano       2          20      3       1
# 3057926  William Long             1          21      3       0
# 7825183  Nathan Walters           1          22      3       0
# 8814507  Zachary Simon            1          23      3       0
# 1061048  Bethany Weaver           1          24      3       0
# 6857290  Anthony Faulkner         2          25      4       1
# 5461623  Mary Green               2          26      4       1
# 7290779  Miranda Coleman          1          27      4       1
# 6215143  Jacqueline Lester        1          28      4       1
#      -4  Bye                      1          29      4       1
# 3798736  Donna Miller             1          30      4       0
# 2883286  Jennifer Velasquez       1          31      4       0
# 3797795  Randy Baker              0          32      4       0
#
#
#    Table    Pod  Player 1 - Name         ID    Rank  Player 2 - Name          ID    Rank    GOF
# -------  -----  -----------------  -------  ------  ------------------  -------  ------  -----
#       1      1  Jennifer Benitez   4729990       1  Thomas Stevenson    3010001       2     16
#       2      1  Pamela Hernandez   8272394       3  Kelly Willis        4247574       4     16
#       3      1  Terry Martin       7691617       6  Wanda Meyer         1834753       7     16
#       4      1  Jason Lambert      2475531       5  Shelley Murray      5442457       8     16
#       5      2  Jeffrey Weaver     2574776       9  Lisa Ellis          8311617      10     16
#       6      2  Jerry Smith        8707433      11  Kathleen Walsh      7923564      12     16
#       7      2  Matthew Martinez   8735686      13  Cynthia Cole        1770440      14     16
#       8      2  William Pena       6763994      15  Loretta Sloan       3737204      16     16
#       9      3  Cory Henry         8855816      17  William Hogan       4059553      18     16
#      10      3  Michael Villa      4053948      19  Stephanie Arellano  3108164      20     16
#      11      3  Nathan Walters     7825183      22  Zachary Simon       8814507      23     16
#      12      3  William Long       3057926      21  Bethany Weaver      1061048      24     16
#      13      4  Anthony Faulkner   6857290      25  Miranda Coleman     7290779      27     16
#      14      4  Mary Green         5461623      26  Bye                      -4      29     16
#      15      4  Donna Miller       3798736      30  Jennifer Velasquez  2883286      31     16
#      16      4  Jacqueline Lester  6215143      28  Randy Baker         3797795      32      1
#
# ----- Round 6 -----
# Goodness of Fit: 15.0
# Maximum GOF: 16.0
# Frequencies: 12pts: 4, 16pts: 12
#
#       ID  Name                  Wins    Standing    Pod    Rank
# -------  ------------------  ------  ----------  -----  ------
# 3010001  Thomas Stevenson         5           1      1       2
# 8272394  Pamela Hernandez         4           2      1       2
# 4729990  Jennifer Benitez         4           3      1       1
# 7691617  Terry Martin             4           4      1       1
# 4247574  Kelly Willis             3           5      1       1
# 5442457  Shelley Murray           3           6      1       1
# 2475531  Jason Lambert            3           7      1       0
# 1834753  Wanda Meyer              2           8      1       0
# 8311617  Lisa Ellis               4           9      2       2
# 8707433  Jerry Smith              4          10      2       2
# 2574776  Jeffrey Weaver           3          11      2       1
# 8735686  Matthew Martinez         3          12      2       1
# 7923564  Kathleen Walsh           3          13      2       1
# 3737204  Loretta Sloan            3          14      2       1
# 1770440  Cynthia Cole             2          15      2       0
# 6763994  William Pena             2          16      2       0
# 4059553  William Hogan            3          17      3       2
# 4053948  Michael Villa            3          18      3       2
# 8855816  Cory Henry               2          19      3       1
# 7825183  Nathan Walters           2          20      3       1
# 1061048  Bethany Weaver           2          21      3       1
# 3108164  Stephanie Arellano       2          22      3       1
# 3057926  William Long             1          23      3       0
# 8814507  Zachary Simon            1          24      3       0
# 5461623  Mary Green               3          25      4       2
# 7290779  Miranda Coleman          2          26      4       2
# 6215143  Jacqueline Lester        2          27      4       2
#      -4  Bye                      2          28      4       2
# 6857290  Anthony Faulkner         2          29      4       1
# 3798736  Donna Miller             2          30      4       1
# 2883286  Jennifer Velasquez       1          31      4       0
# 3797795  Randy Baker              0          32      4       0
#
#
#    Table    Pod  Player 1 - Name          ID    Rank  Player 2 - Name          ID    Rank    GOF
# -------  -----  ------------------  -------  ------  ------------------  -------  ------  -----
#       1      1  Thomas Stevenson    3010001       1  Pamela Hernandez    8272394       2     12
#       2      1  Jennifer Benitez    4729990       3  Kelly Willis        4247574       5     16
#       3      1  Terry Martin        7691617       4  Shelley Murray      5442457       6     16
#       4      1  Jason Lambert       2475531       7  Wanda Meyer         1834753       8     16
#       5      2  Lisa Ellis          8311617       9  Jerry Smith         8707433      10     16
#       6      2  Matthew Martinez    8735686      12  Kathleen Walsh      7923564      13     16
#       7      2  Jeffrey Weaver      2574776      11  Loretta Sloan       3737204      14     16
#       8      2  Cynthia Cole        1770440      15  William Pena        6763994      16     12
#       9      3  William Hogan       4059553      17  Michael Villa       4053948      18     12
#      10      3  Nathan Walters      7825183      20  Bethany Weaver      1061048      21     16
#      11      3  Cory Henry          8855816      19  Stephanie Arellano  3108164      22     16
#      12      3  William Long        3057926      23  Zachary Simon       8814507      24     16
#      13      4  Mary Green          5461623      25  Miranda Coleman     7290779      26     16
#      14      4  Jacqueline Lester   6215143      27  Bye                      -4      28     16
#      15      4  Anthony Faulkner    6857290      29  Donna Miller        3798736      30     12
#      16      4  Jennifer Velasquez  2883286      31  Randy Baker         3797795      32     16
#
# ----- Round 7 -----
# Goodness of Fit: 16.0
# Maximum GOF: 16.0
# Frequencies: 16pts: 16
#
#       ID  Name                  Wins    Standing    Pod    Rank
# -------  ------------------  ------  ----------  -----  ------
# 4729990  Jennifer Benitez         5           1      1       0
# 8272394  Pamela Hernandez         5           2      1       0
# 3010001  Thomas Stevenson         5           3      1       0
# 8707433  Jerry Smith              5           4      1       0
# 5442457  Shelley Murray           4           5      1       0
# 4053948  Michael Villa            4           6      1       0
# 8311617  Lisa Ellis               4           7      1       0
# 7691617  Terry Martin             4           8      1       0
# 7923564  Kathleen Walsh           4           9      2       0
# 3737204  Loretta Sloan            4          10      2       0
# 1834753  Wanda Meyer              3          11      2       0
# 8855816  Cory Henry               3          12      2       0
# 2475531  Jason Lambert            3          13      2       0
# 4247574  Kelly Willis             3          14      2       0
# 7290779  Miranda Coleman          3          15      2       0
# 4059553  William Hogan            3          16      2       0
# 2574776  Jeffrey Weaver           3          17      3       0
# 1061048  Bethany Weaver           3          18      3       0
# 8735686  Matthew Martinez         3          19      3       0
# 1770440  Cynthia Cole             3          20      3       0
# 6857290  Anthony Faulkner         3          21      3       0
# 6215143  Jacqueline Lester        3          22      3       0
# 5461623  Mary Green               3          23      3       0
# 3057926  William Long             2          24      3       0
# 7825183  Nathan Walters           2          25      4       0
# 3108164  Stephanie Arellano       2          26      4       0
# 3798736  Donna Miller             2          27      4       0
# 2883286  Jennifer Velasquez       2          28      4       0
# 6763994  William Pena             2          29      4       0
# 8814507  Zachary Simon            1          30      4       0
# 3797795  Randy Baker              0          31      4       0
#      -4  Bye                      2          32      4       0
#
#
#    Table    Pod  Player 1 - Name          ID    Rank  Player 2 - Name          ID    Rank    GOF
# -------  -----  ------------------  -------  ------  ------------------  -------  ------  -----
#       1      1  Thomas Stevenson    3010001       3  Shelley Murray      5442457       5     16
#       2      1  Pamela Hernandez    8272394       2  Michael Villa       4053948       6     16
#       3      1  Jennifer Benitez    4729990       1  Lisa Ellis          8311617       7     16
#       4      1  Jerry Smith         8707433       4  Terry Martin        7691617       8     16
#       5      2  Kathleen Walsh      7923564       9  Wanda Meyer         1834753      11     16
#       6      2  Loretta Sloan       3737204      10  Cory Henry          8855816      12     16
#       7      2  Jason Lambert       2475531      13  Miranda Coleman     7290779      15     16
#       8      2  Kelly Willis        4247574      14  William Hogan       4059553      16     16
#       9      3  Matthew Martinez    8735686      19  Anthony Faulkner    6857290      21     16
#      10      3  Cynthia Cole        1770440      20  Jacqueline Lester   6215143      22     16
#      11      3  Bethany Weaver      1061048      18  Mary Green          5461623      23     16
#      12      3  Jeffrey Weaver      2574776      17  William Long        3057926      24     16
#      13      4  Stephanie Arellano  3108164      26  Jennifer Velasquez  2883286      28     16
#      14      4  William Pena        6763994      29  Zachary Simon       8814507      30     16
#      15      4  Nathan Walters      7825183      25  Randy Baker         3797795      31     16
#      16      4  Donna Miller        3798736      27  Bye                      -4      32     16
#
# ----- Round 8 -----
# Goodness of Fit: 15.0625
# Maximum GOF: 15.0625
# Frequencies: 16pts: 15, 1pts: 1
#
#       ID  Name                  Wins    Standing    Pod    Rank
# -------  ------------------  ------  ----------  -----  ------
# 5442457  Shelley Murray           5           1      1       1
# 4053948  Michael Villa            5           2      1       1
# 8311617  Lisa Ellis               5           3      1       1
# 7691617  Terry Martin             5           4      1       1
# 4729990  Jennifer Benitez         5           5      1       0
# 8272394  Pamela Hernandez         5           6      1       0
# 3010001  Thomas Stevenson         5           7      1       0
# 8707433  Jerry Smith              5           8      1       0
# 7923564  Kathleen Walsh           5           9      2       1
# 3737204  Loretta Sloan            5          10      2       1
# 2475531  Jason Lambert            4          11      2       1
# 4059553  William Hogan            4          12      2       1
# 1834753  Wanda Meyer              3          13      2       0
# 8855816  Cory Henry               3          14      2       0
# 4247574  Kelly Willis             3          15      2       0
# 7290779  Miranda Coleman          3          16      2       0
# 2574776  Jeffrey Weaver           4          17      3       1
# 1061048  Bethany Weaver           4          18      3       1
# 8735686  Matthew Martinez         4          19      3       1
# 6215143  Jacqueline Lester        4          20      3       1
# 1770440  Cynthia Cole             3          21      3       0
# 6857290  Anthony Faulkner         3          22      3       0
# 5461623  Mary Green               3          23      3       0
# 3057926  William Long             2          24      3       0
# 3108164  Stephanie Arellano       3          25      4       1
# 3798736  Donna Miller             3          26      4       1
# 6763994  William Pena             3          27      4       1
# 3797795  Randy Baker              1          28      4       1
#      -4  Bye                      3          29      4       1
# 7825183  Nathan Walters           2          30      4       0
# 2883286  Jennifer Velasquez       2          31      4       0
# 8814507  Zachary Simon            1          32      4       0
#
#
#    Table    Pod  Player 1 - Name          ID    Rank  Player 2 - Name         ID    Rank    GOF
# -------  -----  ------------------  -------  ------  -----------------  -------  ------  -----
#       1      1  Shelley Murray      5442457       1  Michael Villa      4053948       2     16
#       2      1  Lisa Ellis          8311617       3  Terry Martin       7691617       4     16
#       3      1  Jennifer Benitez    4729990       5  Pamela Hernandez   8272394       6     16
#       4      1  Thomas Stevenson    3010001       7  Jerry Smith        8707433       8     16
#       5      2  Kathleen Walsh      7923564       9  Jason Lambert      2475531      11     16
#       6      2  Loretta Sloan       3737204      10  William Hogan      4059553      12     16
#       7      2  Wanda Meyer         1834753      13  Cory Henry         8855816      14     16
#       8      2  Kelly Willis        4247574      15  Miranda Coleman    7290779      16     16
#       9      3  Bethany Weaver      1061048      18  Matthew Martinez   8735686      19     16
#      10      3  Jeffrey Weaver      2574776      17  Jacqueline Lester  6215143      20     16
#      11      3  Cynthia Cole        1770440      21  Anthony Faulkner   6857290      22     16
#      12      3  Mary Green          5461623      23  William Long       3057926      24     16
#      13      4  Stephanie Arellano  3108164      25  Donna Miller       3798736      26     16
#      14      4  Randy Baker         3797795      28  Bye                     -4      29     16
#      15      4  William Pena        6763994      27  Nathan Walters     7825183      30      1
#      16      4  Jennifer Velasquez  2883286      31  Zachary Simon      8814507      32     16
#
# ----- Round 9 -----
# Goodness of Fit: 14.75
# Maximum GOF: 16.0
# Frequencies: 16pts: 11, 12pts: 5
#       ID  Name                  Wins    Standing    Pod    Rank
# -------  ------------------  ------  ----------  -----  ------
# 4053948  Michael Villa            6           1      1       2
# 7691617  Terry Martin             6           2      1       2
# 8272394  Pamela Hernandez         6           3      1       1
# 8707433  Jerry Smith              6           4      1       1
# 5442457  Shelley Murray           5           5      1       1
# 8311617  Lisa Ellis               5           6      1       1
# 4729990  Jennifer Benitez         5           7      1       0
# 3010001  Thomas Stevenson         5           8      1       0
# 7923564  Kathleen Walsh           6           9      2       2
# 3737204  Loretta Sloan            6          10      2       2
# 8855816  Cory Henry               4          11      2       1
# 2475531  Jason Lambert            4          12      2       1
# 7290779  Miranda Coleman          4          13      2       1
# 4059553  William Hogan            4          14      2       1
# 1834753  Wanda Meyer              3          15      2       0
# 4247574  Kelly Willis             3          16      2       0
# 2574776  Jeffrey Weaver           5          17      3       2
# 8735686  Matthew Martinez         5          18      3       2
# 1061048  Bethany Weaver           4          19      3       1
# 6857290  Anthony Faulkner         4          20      3       1
# 6215143  Jacqueline Lester        4          21      3       1
# 5461623  Mary Green               4          22      3       1
# 1770440  Cynthia Cole             3          23      3       0
# 3057926  William Long             2          24      3       0
# 3798736  Donna Miller             4          25      4       2
# 6763994  William Pena             4          26      4       2
# 3797795  Randy Baker              2          27      4       2
#      -4  Bye                      2          28      4       2
# 3108164  Stephanie Arellano       3          29      4       1
# 2883286  Jennifer Velasquez       3          30      4       1
# 7825183  Nathan Walters           2          31      4       0
# 8814507  Zachary Simon            1          32      4       0
#
#
#    Table    Pod  Player 1 - Name          ID    Rank  Player 2 - Name          ID    Rank    GOF
# -------  -----  ------------------  -------  ------  ------------------  -------  ------  -----
#       1      1  Michael Villa       4053948       1  Terry Martin        7691617       2     16
#       2      1  Pamela Hernandez    8272394       3  Jerry Smith         8707433       4     16
#       3      1  Shelley Murray      5442457       5  Lisa Ellis          8311617       6     16
#       4      1  Jennifer Benitez    4729990       7  Thomas Stevenson    3010001       8     12
#       5      2  Kathleen Walsh      7923564       9  Loretta Sloan       3737204      10     12
#       6      2  Cory Henry          8855816      11  Jason Lambert       2475531      12     16
#       7      2  Miranda Coleman     7290779      13  William Hogan       4059553      14     16
#       8      2  Wanda Meyer         1834753      15  Kelly Willis        4247574      16     16
#       9      3  Jeffrey Weaver      2574776      17  Matthew Martinez    8735686      18     12
#      10      3  Bethany Weaver      1061048      19  Anthony Faulkner    6857290      20     16
#      11      3  Jacqueline Lester   6215143      21  Mary Green          5461623      22     16
#      12      3  Cynthia Cole        1770440      23  William Long        3057926      24     16
#      13      4  Donna Miller        3798736      25  Randy Baker         3797795      27     16
#      14      4  William Pena        6763994      26  Bye                      -4      28     16
#      15      4  Stephanie Arellano  3108164      29  Jennifer Velasquez  2883286      30     12
#      16      4  Nathan Walters      7825183      31  Zachary Simon       8814507      32     12
#
# ----- Round 10 -----
# Goodness of Fit: 11.0625
# Maximum GOF: 11.3125
# Frequencies: 16pts: 10, 1pts: 5, 12pts: 1
#
#       ID  Name                  Wins    Standing    Pod    Rank
# -------  ------------------  ------  ----------  -----  ------
# 7691617  Terry Martin             7           1      1       7
# 8707433  Jerry Smith              7           2      1       7
# 3737204  Loretta Sloan            7           3      1       7
# 8272394  Pamela Hernandez         6           4      1       6
# 4053948  Michael Villa            6           5      1       6
# 8311617  Lisa Ellis               6           6      1       6
# 8735686  Matthew Martinez         6           7      1       6
# 3010001  Thomas Stevenson         6           8      1       6
# 7923564  Kathleen Walsh           6           9      1       6
# 4729990  Jennifer Benitez         5          10      1       5
# 8855816  Cory Henry               5          11      1       5
# 5442457  Shelley Murray           5          12      1       5
# 7290779  Miranda Coleman          5          13      1       5
# 2574776  Jeffrey Weaver           5          14      1       5
# 1061048  Bethany Weaver           5          15      1       5
# 3798736  Donna Miller             5          16      1       5
# 6763994  William Pena             5          17      1       5
# 6215143  Jacqueline Lester        5          18      1       5
#      -1  Bye                      5          19      1       5
# 1834753  Wanda Meyer              4          20      1       4
# 2475531  Jason Lambert            4          21      1       4
# 4059553  William Hogan            4          22      1       4
# 3108164  Stephanie Arellano       4          23      1       4
# 6857290  Anthony Faulkner         4          24      1       4
# 5461623  Mary Green               4          25      1       4
# 3057926  William Long             3          26      1       3
# 4247574  Kelly Willis             3          27      1       3
# 1770440  Cynthia Cole             3          28      1       3
# 2883286  Jennifer Velasquez       3          29      1       3
# 7825183  Nathan Walters           2          30      1       2
# 3797795  Randy Baker              2          31      1       2
# 8814507  Zachary Simon            2          32      1       2
#
#
#    Table    Pod  Player 1 - Name         ID    Rank  Player 2 - Name          ID    Rank    GOF
# -------  -----  -----------------  -------  ------  ------------------  -------  ------  -----
#       1      1  Terry Martin       7691617       1  Loretta Sloan       3737204       3     16
#       2      1  Jerry Smith        8707433       2  Michael Villa       4053948       5      1
#       3      1  Lisa Ellis         8311617       6  Thomas Stevenson    3010001       8     16
#       4      1  Pamela Hernandez   8272394       4  Kathleen Walsh      7923564       9     16
#       5      1  Matthew Martinez   8735686       7  Miranda Coleman     7290779      13      1
#       6      1  Cory Henry         8855816      11  Bethany Weaver      1061048      15     16
#       7      1  Shelley Murray     5442457      12  Donna Miller        3798736      16     16
#       8      1  Jeffrey Weaver     2574776      14  William Pena        6763994      17     16
#       9      1  Jennifer Benitez   4729990      10  Bye                      -1      19     16
#      10      1  Wanda Meyer        1834753      20  Stephanie Arellano  3108164      23     16
#      11      1  Jacqueline Lester  6215143      18  Anthony Faulkner    6857290      24      1
#      12      1  Jason Lambert      2475531      21  Mary Green          5461623      25     16
#      13      1  William Long       3057926      26  Kelly Willis        4247574      27     16
#      14      1  William Hogan      4059553      22  Jennifer Velasquez  2883286      29      1
#      15      1  Nathan Walters     7825183      30  Randy Baker         3797795      31     12
#      16      1  Cynthia Cole       1770440      28  Zachary Simon       8814507      32      1
#
# ----- Round 11 -----
# Goodness of Fit: 13.625
# Maximum GOF: 14.125
# Frequencies: 1pts: 2, 16pts: 13, 8pts: 1
#
#       ID  Name                  Wins    Standing    Pod    Rank
# -------  ------------------  ------  ----------  -----  ------
# 7691617  Terry Martin             8           1      1       8
# 4053948  Michael Villa            7           2      1       7
# 3010001  Thomas Stevenson         7           3      1       7
# 8707433  Jerry Smith              7           4      1       7
# 7923564  Kathleen Walsh           7           5      1       7
# 3737204  Loretta Sloan            7           6      1       7
# 4729990  Jennifer Benitez         6           7      1       6
# 8855816  Cory Henry               6           8      1       6
# 8272394  Pamela Hernandez         6           9      1       6
# 7290779  Miranda Coleman          6          10      1       6
# 8311617  Lisa Ellis               6          11      1       6
# 8735686  Matthew Martinez         6          12      1       6
# 3798736  Donna Miller             6          13      1       6
# 6763994  William Pena             6          14      1       6
#      -1  Bye                      6          15      1       6
# 1834753  Wanda Meyer              5          16      1       5
# 2475531  Jason Lambert            5          17      1       5
# 5442457  Shelley Murray           5          18      1       5
# 2574776  Jeffrey Weaver           5          19      1       5
# 1061048  Bethany Weaver           5          20      1       5
# 6857290  Anthony Faulkner         5          21      1       5
# 6215143  Jacqueline Lester        5          22      1       5
# 3057926  William Long             4          23      1       4
# 4059553  William Hogan            4          24      1       4
# 3108164  Stephanie Arellano       4          25      1       4
# 1770440  Cynthia Cole             4          26      1       4
# 2883286  Jennifer Velasquez       4          27      1       4
# 5461623  Mary Green               4          28      1       4
# 4247574  Kelly Willis             3          29      1       3
# 3797795  Randy Baker              3          30      1       3
# 7825183  Nathan Walters           2          31      1       2
# 8814507  Zachary Simon            2          32      1       2
#
#
#    Table    Pod  Player 1 - Name          ID    Rank  Player 2 - Name          ID    Rank    GOF
# -------  -----  ------------------  -------  ------  ------------------  -------  ------  -----
#       1      1  Terry Martin        7691617       1  Thomas Stevenson    3010001       3      1
#       2      1  Michael Villa       4053948       2  Kathleen Walsh      7923564       5     16
#       3      1  Jerry Smith         8707433       4  Loretta Sloan       3737204       6     16
#       4      1  Cory Henry          8855816       8  Pamela Hernandez    8272394       9     16
#       5      1  Lisa Ellis          8311617      11  Matthew Martinez    8735686      12     16
#       6      1  Donna Miller        3798736      13  William Pena        6763994      14     16
#       7      1  Miranda Coleman     7290779      10  Bye                      -1      15     16
#       8      1  Shelley Murray      5442457      18  Jeffrey Weaver      2574776      19     16
#       9      1  Jason Lambert       2475531      17  Bethany Weaver      1061048      20     16
#      10      1  Wanda Meyer         1834753      16  Anthony Faulkner    6857290      21     16
#      11      1  Jennifer Benitez    4729990       7  Jacqueline Lester   6215143      22      1
#      12      1  Stephanie Arellano  3108164      25  Cynthia Cole        1770440      26     16
#      13      1  William Long        3057926      23  Jennifer Velasquez  2883286      27     16
#      14      1  William Hogan       4059553      24  Mary Green          5461623      28     16
#      15      1  Kelly Willis        4247574      29  Randy Baker         3797795      30     16
#      16      1  Nathan Walters      7825183      31  Zachary Simon       8814507      32      8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-40fff39091d8> in <module>
#       4
#       5 for rnd in range(NUMBER_OF_ROUNDS):
# ----> 6     standings, splits, scores, alloc, pairs = create_draw(players, results, ROUNDS)
#       7     for collection, value in zip([standings_h, splits_h, scores_h, alloc_h, pairs_h],
#       8                                  [standings,   splits,   scores,   alloc,   pairs]):
#
# <ipython-input-5-7fda4ecdeae0> in create_draw(players, results, rounds)
#      21
#      22     standings       = get_standings(players, results, rounds)
# ---> 23     scores, splits  = get_scores(standings, results)
#      24     alloc, pairings = get_allocations(standings, scores)
#      25
#
# <ipython-input-7-5e4e80a703db> in get_scores(standings, results)
#      39         if result[0] in active_players and result[1] in active_players:
#      40             a, b = ix[result[0]], ix[result[1]]
# ---> 41             penalty = 32 if min(result) < BYE else 4
#      42             scores[a,b] -= penalty
#      43             scores[b,a] -= penalty
#
# TypeError: '>' not supported between instances of 'int' and 'NoneType'
